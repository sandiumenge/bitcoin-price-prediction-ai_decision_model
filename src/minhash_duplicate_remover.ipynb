# %%
import pandas as pd
from datasketch import MinHash, MinHashLSH
import re
import csv
import string
from tqdm import tqdm
tqdm.pandas(mininterval=1.0)
from TweetNormalizer import normalizeTweet
import spacy

# %%
df = pd.read_csv('sample_200k-130k_text.csv')  # Assuming the texts are in a column named 'text'
original_df = pd.read_csv('sample_200k-130k_full.csv')
# Check the first few rows to inspect the data and find the column with texts
df["text"].to_list()
# Out:
# ['📊Interesting chart: we can clearly see how long-term holders been accumulating Bitcoins during the Summer-Autumn dump.   At the moment total supply held by holders is at almost All Time High.#Btc #100xgem #cryptocurrencies #HODL #ToTheMoon https://t.co/NusqceFbnv',
#  "Bitcoin's 'Elon Musk pump' rally to $48K was exclusively driven by whales https://t.co/F6zGnXnBh0 Laranjal do Elon",
#  "#Bitcoin over $50K this morning...is this the #DeadCatBounce that will go parabolic? Yesterday, $SQ announced they purchased Bitcoin...did #TSLA buy more in the 40s too? I continue to be bullish on Bitcoin which is why I'm bullish on $MARA, $RIOT, $MSTR, and $TSLA.",
#  'Who cares about China’s ban on #Bitcoin.   Can’t ban crypto - moving on....',
#  'bitcoin tries to take direction again. ⬆️⬇️ I think after some correction it will be up again. $btc #btc 💬',
#  'The # Skyllz crew is creating the blockchain based and distributed skill validation platform to showcase track and boost human talents acro',
#  'Saying #Bitcoin isn’t real because it’s not tangible is like saying the internet isn’t real because you can’t hold it..   $btc',
#  '@gate_io $shib the money making machineMoney- Also a doge killer #shibarmy #doge #uniswap #cryptocurrencies #ethereum #bitcoin  #DeFi #ID #shibaswap',
#  'This is a great project and good team @canhgiesu36 @AnhTuye22768823 @tuyetle45106585 @xuka74479873 @canh26411723',
#  '@BTC_Archive #Bitcoin getting really loud**  5*87* million transactions (size-able [41k-47.9k+up]) in the last 4 days.  #USA news.',
#  '# Xapo refused to consider original # BTC as real # bitcoin http://amp.gs/lAYCpic.twitter.com/AvUUWJ9RAL',
#  '#blockchain #btc #crypto #cryptocurrency #bitcoin #Ethereum #ETH 11   The first blockchain platform to power sports bets via Ethereum smart contracts. No book, no accounts, no odds. Just P2P bets between fans of sports and crypto.https://cryptosportz.com/\xa0',
#  'RT @BTC_Archive: 💥USA needs to catch up to world on #Bitcoin and crypto regulation  - Shark Tank’s Kevin O’Leary',
#  '#fomo is going to eat ppl alive. #doge #dogecoin #btc #Bitcoin https://t.co/slaaJgtEl1',
#  'In my opinion it is the best project 2018, very strong team, big prospects, good luck to team. #VITA #VITATOKEN #ICO #bitcoin #btc and #cryptocurrency.',
#  'Every day I become more and more a #bitcoin maxi.',
#  "It is extremely hard to see the truth when you rule the World. You're just too busy.",
#  '-  BTC price: $34,694 / £25,592   28.82 Naks per USD 39.07 Naks per GBP   &lt;going UP!&gt;   One #Bitcoin = one million #Naks. Simple as that!   #Bitcoinprice #SatoshiNakamoto  22/01/2022  18:25:00 GMT https://t.co/TifT9WUTMK',
#  'on the 08/04/2021 at 04:02 1BTC was worth $37936.00 #Bitcoin #Crypto #BotcoinUSD #Bitfinex',
#  'Saquon Barkley, Star of New York Giants Switched Endorsement Payment to Bitcoin https://t.co/pNvUv9W4DK https://t.co/JPxP4DDV3f',
#  'current #bitcoin price (bitstamp) is $222.00, last changed Sat, 18 Apr 2015 10:22:33 GMT.  queried at: 10:22:40',
#  'Top 1 #Signals  $SNT - Possible Decrease VC: 122.04% P: 0.0000030300   To see more visit https://t.co/mfcT6cyBbr #altcoins #trading #TradingView #crypto #pump #signal $BTC $ETH $XRP $TRX $EOS https://t.co/rGneEFK4sQ',
#  'BSV better hold $140 - $145 this week  #BSV #BitcoinSV #Bitcoin #BTC https://t.co/I1sAo8HVjF',
#  'RT @AirdropDet: 🔍 New #Airdrop: Swords of Blood   💲 Reward: Up to 222 SWDTKN (~$10) + 111K SWDTKN (~$5K) referral pool  🔴 Start the airdrop…',
#  "@vinarmani @APompliano He's right about the valuation model though 🧐those applying old-world financial models to bitcoin will crash and burn.",
#  '@MustacheTommy Because we believe in #btc',
#  'New DCG Report highlights confidence in asset #Tokenization and #Bitcoin as ‘store of value’ reported by https://t.co/ODltDSjsiM ---- #Blockchain #BTC #Companies #Digital_Currency_Group #Payments',
#  'Another China FUD? 🐕  The State Council of China: Crack down on Bitcoin mining and trading, and prevent individual risks transmitted to the social field.  https://t.co/MBXoWaUyUN',
#  '@ShillingStation @bluesparrownews @BlueSparrowETH You cannot stop phenomena like #bluesparrow #bluesparrow will take over the world The world and governments must adapt themselves with #bluesparrow #bluesparrow  🔥🚀 #Charity #bitcoin #KYC #Renounce @BlueSparrowETH  💯 https://t.co/nSdu5juJGD',
#  '@TrustWallet Apollo Coin APX. Listen to the CEO explain why Apollo Coin is going to exceed all expectations in the coming months!!',
#  "Hellosaurus engineering extraordinaire @JaredSilver wrote a fantastic article about monkeys, bitcoin millionaires, workplace motivation, and more. It's a must-read ⬇️⬇️⬇️ https://t.co/sWpn9WtZ4j",
#  "@Cryptic_Oz @Bitcoin_ator It's an amazing feeling to have lightning transactions from my phone controlling my own lightning node. Add to that cold storage and .. sorry what are banks for ? Cheap debt is about all I can think of",
#  'How to get paid in #Bitcoin http://bit.ly/2t4WNTN\xa0 via @CryptoComparepic.twitter.com/VaV47k2x1o',
#  'They have fear because #Bitcoin is already going to make them obsolete. https://t.co/fimg97Buit https://t.co/CkZBYAw2ET',
#  '@Tazoshi1 I mentioned this earlier. If all you have access to is a disk drive containing the blockchain. How can you verify it is the valid one? With Bitcoin, a fork would be noticed in a huge drop in Hash power. But an entirely fake blockchain would be noticed by a very low hash power',
#  'Blockchain Browsers — How DLT Could Affect Web Surfing https://t.co/Ggj3R3uOVk #Blockchain, #Android, #IOS, #API, #wallet, #Internet, #Opera, #Ethereum, #cryptocurrencies, #bitcoin',
#  'Use my referral link https://t.co/Au3UDvDrJj to sign up for https://t.co/UBVudfB43u and we both get $25 USD :) #crypto #crypto.com #bitcoin',
#  "https://t.co/zE0DCkP3az #xrp #ripple #trx #btc #We toured Disneyland's new Star Wars park. Here's what we learned. - #Cricket   #CricketWorldCup2019 - https://t.co/K7Nm9tiPn8 #",
#  'Teenage homeschooler leverages # bitcoin millions to transform higher ed. # homeschooling # cryptocurrencyhttp://bitcoinist.com/teenage-bitc',
#  "@Reddit_BTC : Trezor stopped working on CashAddr... Because it's done! CashAddr code is ready for the next release! http://zpr.io/nuFbJ\xa0",
#  'STOP THE WAITING NOW PEOPLE ARE GETTING PAID, DM US TODAY TO LEARN HOW TO INVEST IN BITCOUN AND BINARY OPTIONS TRADE 📩 24HOURS TRADING 99.9% WINNING RATE. #bitcoin #investing #invest #binarytrading #optiontrading  #love #instagood #me #dubai #hongkong #cute #pioneer #GoodEvening https://t.co/Qtk0cZ2v07',
#  'TREZOR Silicone Protective cases in 5 colors. They have Free Worldwide Shipping http://ift.tt/2kDAH7n # reddit # bitcoin',
#  '#xeraexchange verifies personal profiles and listings by blockchain technology, to put in the amount of the system is customers , Referrers and friends can be made as reliable #exchange #crypto #cryptocurrency #btc #eth #blockchain #altcoins #technologyli]',
#  '@btc_vladimir Everyone see that  BTC is  bullish again .  I know  private source with  market analytics . And it is free for one week !  Look --&gt; https://t.co/XaYXUMxWg7 ⭕ 257355235',
#  '# Bitcoin Current bitcoin price is 0.00043152 BTC for $1 USD # GoldCoinJar',
#  "Bullish news is that Bitcoin has reached Wall Street.  #Bitcoin Futures exchange #Bakkt will launch $BTC custody for institutional clients on Sept 6 &amp; trading on Sept 23.  Bakkt is founded by Ice, parent company of New York Stock Exchange. Can't get bigger than that",
#  'Well done and thanks for this great opportunity. This is an amazing project with good community am looking forward to.  @The_Adamsho  @nulawlaw  @Lakeside391   #Airdrops #Bitcoin #LOTTRADE #AirdropDet #crypto #Blockchain $lott https://t.co/KfNxPKHUBf',
#  'The current price of Bitcoin is $59722.00. The current price of BCash is $589.28, or 0.00986705 BTC. The current price of BCashSV is $161.22, or 0.27358811 BCash.',
#  'RT @Hoshi_kik: @tbktw Check us out! @tbktw #TRUMP2024 Love him or Hate him..these #NFTs will be PRICELESS Don’t Miss Out! #TRUMPBACKONTWITT…',
#  "15/ And for a broad, historical ranking in table format, for the entirety of Bitcoin's history since 2009, that information is here. https://t.co/qLwLHmEgXx",
#  '@rpg0103 @apyswap @tapascrypto @iam_Beast_ @cryptogeek_yash @bitcoin_brown @KumarManoj26398 I think it will definitely do 100X',
#  '@patrickbatemanv @jack And shake off your Peruvian hallucinogens. Crypto is bigger than Bitcoin.',
#  "@xd_Jio @IlyaIvanou @LemorSoled @elonmusk @TechInsider Lol, he can't do shit, all he can do is to sell his #Bitcoin but he doesn't have the balls!",
#  "I'm exasperated that my friends and family seem to have no better understanding of bitcoin than they did in 2017. Honestly don't know if this is bearish or bullish.",
#  '⏰ LIQUIDATION on BTC-PERPETUAL ☠️️   Bought $20 of #BTC @ $8737.00  2 Jun 2019 22:36:45 UTC Trade ID: 22962811',
#  'BIT FUN. Play games, have fun, earn bitcoin!. http://bitfun.co/?ref=D8DB14D5C52F\xa0… #bitcoin #faucet via @bitfunfaucet',
#  '$BTC retested the 38,600 support and quickly recovered 💪 #Bitcoin $BTC $ETH #Crypto #Cryptocurrency #Altcoins #TechnicalAnalysis #DeFi #ビットコイン #биткойн #比特币 https://t.co/KiclO9QOok',
#  '@7eemu1 @CryptoQand @MMCrypto Bitcoin was created to revolutionize currency.   You use it as a currency.   Start accepting it at your business if you have one.   I offer my customers and tenants to pay with Bitcoin usually at a discount relative to USD.  https://t.co/ZjasR43URS',
#  "Tesla can be bought with #Bitcoin Hoping we'd be able to buy this car with crypto too. Speaking of cryptocurrency, earn a free share of 4K $TRB tokens on #LATOKEN https://t.co/ZcfduoRzcR",
#  "It is extremely hard to see the truth when you rule the World. You're just too busy.",
#  '@AyoRay07 @LassenNPS @bitninjasupply https://t.co/EX43PJTcYO is a great place to start!! Watch @aantonop YouTube videos. What questions do you have?',
#  'Here go #bitcoin, another game changer https://t.co/Wwcv1adfHW',
#  'FINALLY OUR EBOOK IS ONLINE 😱🎉  Download it now on https://t.co/PGR2GCU2fe and take your investments to the next level 👏  $BTC #alts #bullrunpreparation https://t.co/ZrLMDlh3ze',
#  '@TheBlock__ When will we be able to buy and sell @apenftorg and @DogelonMars on @binance?  #cz_binance #BNB #BTC #Ethereum #vitalik @VitalikButerin #ElonMusk #mayemusk @Eljaboom @ElonTrades #MATIC #polygon @10Ronaldinho',
#  "It is extremely hard to see the truth when you rule the World. You're just too busy.",
#  'I want a book to read. Help me!  What will it be? The Big Reset or The Great Reset? Willem vs Klaus @wmiddelkoop @ProfKlausSchwab @MMCrypto #thebigreset #TheGreatReset #Covid_19 #gold #bitcoin #books #quote https://t.co/NB1uCWyEsJ',
#  '@Bitcoin_Vending @MagneticDisrup1 @Rhythmtrader Yep. Tell me the partnerships Bitcoin has with major players in the world of finance.',
#  'What percentage should you invest in each cryptocurrency to become a millionaire? A winning index strategy https://t.co/rRTNm5auwi #Bitcoin #Crypto #Ethereum #Litecoin #Ripple #EOS https://t.co/eAk5Ml7HvA',
#  'DASH/USD and LTC/USD Technical Analysis May 30 2017 https://goo.gl/fb/1CX3vU # bitcoin',
#  '@Bizniz203 Learned myself today as well. Tried to get my feet wet in the market with $60 and failed. But I have never failed with bitcoin. #decrentralization for the win.',
#  'This zesty faucet from @_bitcoiner is making me tweet this to claim my free Lightning sats. ⚡  @boltcoiner unlock me eb5fd996-376e-42cc-b7fa-ac10a9758c67  #Bitcoin #BTC #LN #LightningNetwork #boltcoiner https://t.co/yhUCntm6M0',
#  'Bitcoin (btc) and Ethereum (eth) morning price ! ———————————————————————— 📊Top 17 Altcoin price ! 📊————————————————————————- 🏦 Market Cap. / Bitcoin dominance / 24 hours volume ! 🏦 ————————————————————————- 🏛 Top 6… https://t.co/HSm6uHjRki',
#  '@VentuaryDAO @wavesplatform @wavescommunity @waveslabs This is the best offer to make money on cryptocurrency @WhiteBit6 #Crypto #Bitcoin #USDT #Exchange https://t.co/rMfISIDPdF',
#  'Bitcoin slides in worst weekly drop since March amid\xa0selloff https://t.co/CN9T2JTNzf',
#  'FBI Requests New Funding To Investigate Use Of Virtual Currencies https://goo.gl/juJ4A6 # Bitcoin # currencies # fundingpic.twitter.com/SDtO',
#  '*LONG POSITION SUGGESTED FOR #BITCOIN* CURRENT PRICE: $4.608 ALGO NAME: $0.5S TRACKER ALGO GROUP: https://t.co/0OU2TbL7ja ACCURACY: 80% DATE: 2021-10-14 09:43:13.077395 TRADE NOW: https://t.co/mKowzpQKDl https://t.co/Ut3djUgl28',
#  "But why on earth a country as this sheattle can go to the length of blocking its citizen way of hustling and meeting ends meet ......When they can't produce anything for its citizen....Dem no want make we dey sucessfull in this part of the world ...ajeh #Bitcoin",
#  'My Crypto Strategy on ICONOMI just outperformed BTC. Check it out here: https://t.co/WEnAYLhivM #trading #forextrader #bitcoin #cryptocurrencies https://t.co/Ar1zHiX1Tg',
#  '#Binance Buyer Volume Alert Stage 1/3: Ignition 🔥  Name: #Bitcoin Cash ABC Symbol: $BCHABC Pair: $BTC Price: ₿0.05295000  TradingView: https://t.co/2JLGlUJljc Hodloo: https://t.co/ojy6ngwN3w https://t.co/R8n4vMk0Qk',
#  '#NUSD #kucoin #Arbitrage Opportunity 🚀! 1) Sell $USDT for $DAI. 2) Convert $DAI to $NUSD @ https://t.co/vnFMUCRCag. 3) Sell $NUSD for $BTC. 4) Sell $BTC for $USDT.  Potential 0.61% profit (#kucoin and @neutral_project fees included)! 2019-06-27 23:02:37 +0000',
#  'I pay in bitcoin. DM ya wallet I’ll send ya $10 @PEP0MINT',
#  "@ExtraVOD_ Twisted scenario?   The original XRP will die and stay dead.  They'll release a new type of #XRP token tied to #BTC ENERGY &amp; PRECIOUS METALS   Buttt... I don't know if y'all are ready to hear that full story so I'll keep it short &amp; simple 🤣🤣🤣",
#  "@CoinDesk @NYDIG_BTC @bottlepay @mikeybellusci #Bitcoin\xa0 \xa0 is still sitting at the $60k resistance building up for another push, bears can't seem to get hold to push it down. Now I think 70k is a more likely target  Everyone should follow @rachelwolfson_ tips and tweets I have been doing superb following her",
#  '@claireallenkent UNV is digital gold on the exchange. You can trade $KBC- UNV, $BTC-UNV, $ETH-UNV, and USD-UNV pairs.',
#  "@bitcoinluka @gladstein @benekcj @bunsen Dude the claim being made is that bitcoin fixes NK by magical trojan horse 12D chess. It doesn't - it helps the current regime. What you said doesn't strengthen a case that bitcoin fixes NK, you're just agreeing that it doesn't.",
#  '#Altcoin #Bitcoin #Crypto #News Over $30 Billion Worth of ADA Now Staked on Cardano https://t.co/QiMzQpmkV6',
#  'Invest in bitcoin and earn tremendous profits💰💳💸💸💸💯 https://t.co/4IRyblzP5z',
#  '@PeterMcCormack Damn @nayibbukele knows how to buy the dip #bitcoin',
#  'Local ou virtuel largent change de visage http://paper.li/yvesmeyer02/1491813973?read=http%3A%2F%2Fwww.24heures.ch%2Fvaud%2Dregions%2Flocal',
#  'Bitcoin Mining Could Use More Energy Than All of Italy by 2024 - VICE https://t.co/NMbbcSKcKP',
#  "@cex_io @iraklosvani Just don't buy bitcoin becouse I am sure that bitcoin is not going to hit 10x soon,buy $KISHU this token have chance to hit 1000x or more 💸🚀🚀🚀📈📈📈",
#  'BTC Price: 4551.03$,  BTC Today High : 4559.39$,  BTC All Time High : 4742.42$ ETH Price: 312.52$ #bitcoin #BTC $BTC #ETH $ETHpic.twitter.com/uxIPGIMMO8',
#  '@1changamire @EcoCashZW Have you looked into getting bitcoin or litecoin',
#  'ALERT: Bitcoin (BTC) at Euro 9764.59 decrease by 4.88% during the past hour.  Price: Euro 9764.59  Timestamp: 18:42:03 27-06-2019 (Malta/Europe)  This is not financial advice. Do your own research.',
#  'From Parabolic Price to ‘Ban Bitcoin’ Politicians: Past Week’s Top Stories ➡️https://t.co/HO3pXBOy5H 🗺️ ▶️https://t.co/vdnO18c8ZC #newsoftheweek #Bitcoin #blockchain #crypto https://t.co/prBDDigKJ0',
#  'Have gotten my girlfriend into this “virtual money” followed by her father and her 14yr old sister. My girlfriend and her father now 1 month later are now DCA with @BitarooExchange. All started with sending $1 on lightning and watching it #Bitcoin',
#  'No wonder why it is hard to own a full #Bitcoin nowadays… 1 $BTC would be the average net worth of American millennials.  https://t.co/l167xEtvsO',
#  '“If Libra takes off we get a billion new crypto users that will eventually migrate somewhat into Bitcoin and grow the whole ecosystem. If Libra gets shut down… boom! Now we know why Bitcoin is so powerful as a global reserve currency.” — Brad Stephens',
#  "3LwZf9osJSTTANrqDfkWxA6PjirkUnrbmgtp6eox3Fcg  #EidMubarak2022 #Crypto #cryptocurrency #BTC #SOL #SolanaGiveaway #AirdropCrypto #Trending #BULLS  I'm a Christian and this is my roomie and my best buddy though(I posted his Eid pictures instead). One love y'all 💪💯❤️ https://t.co/2zJrkc9otp https://t.co/AK8mYfXHs4",
#  'Bitcoin hits new high as Tesla reveals $1.5bn investment https://t.co/U52nLwRBkF https://t.co/bEU02i1UPl',
#  '#linkedin #twitter #facebook #instagram #tiktok #giftshop #socialmedia #pinterest #dogecoin #deal #gift #gifts #giftideas #shop #shopping #affiliatemarketing #bitcoin Up to 15% off New Products from #Amazon #Brands https://t.co/rzTTICY6nX',
#  'Can someone make a list about Bollinger bands or some other technical analysis stuff that seems to never matter? It humors me. #bitcoin',
#  'I know #BTC #Bitcoin is going Hyper Parabolic any time now to 20K+     So every time I look at BTC this is what I see   #DigitalGold #DigitalAssets #Crypto #Coinbase #Binance #Fidelity #China #XRPtheStandard #Bitstamp #Bitmex #XRP #Ripple #XRPcommunity https://t.co/kzBuDDNfMs',
#  'Get any of these for only 8,500 naira  Size: 37-41   Kindly retweet   To order send a DM/ call/ WhatsApp on 08082744728   #BBNajia2019 #nationalboyfriendsday #EuropaLeague #WorldAthleticsChamps #JokerMovie #bitcoin #BamLisaxAIS https://t.co/zeN5ziMwN3',
#  'RT @AirdropDet: 🔍 New #Airdrop: BrightyPad  🏆 Airdrop Pool: 4,5 Million BYP [~$36,000]  🔴 Start the airdrop bot https://t.co/eRV7c5W9ns  🔘…',
#  '#Bitcoin Market Alert! 🚨  Order Balance: 32.59% (Buy)  Buy 66.30% | Sell 33.70% Bid: $55354.318 Ask: $55354.91 Spread: $0.592',
#  '@DanielPiraino @liquigate @JamesGRickards @Frank_Giustra @michael_saylor I actually earn my bitcoin at this point. I could hold oranges, cars, houses but instead I hold bitcoin. I do this because its inf easier to secure my coins than it is to protect my wealth by storing it in houses or anything else.',
#  'Are you a newbie on the Binary bitcoin mining network or you already have Bitcoin?  Do you know that you can mine Bitcoin with the  Help of the BITMAIN MINING Hardware?  Yes your Bitcoin can mine Up to $2000 worth Bitcoin in a day for 2weeks of connection',
#  'Top 3 candidates for reversal for May 16 on @binance (1) BCHABC (2) NPXS (3) EOS #altcoins #bitcoin #BCHABC #NPXS #EOS',
#  "@deezeecrypto They just don't see it our way yet, they will, in due course, learn to love Waifu NFT's. I mean Bitcoin, Bitcoin for sure.",
#  'I believe we are just in a re-accumulation phase and it could take some time to break to new yearly highs. More time and opportunities to #stacksats😁😁  #bitcoin $BTC https://t.co/ILFW8FNOJo',
#  'Dont let # FUD Make your investment decisions. Now is the time to # buythedip if youre investing for the long haul. Stick to your portfolio',
#  'Current price of $ BTC is $1251.59 via Chain # bitcoin # btc',
#  '#Bitcoin price tags $50K for the first time since May 📈  https://t.co/yhaoabFnd7  #BTC #crypto #cryptocurrency @RoseonFinance https://t.co/MrhpstVXNX',
#  '6Father raised his voice, You allowed your Greed and Sloth to waste the precious rewards, the devotion of others, wasted for many blocks! Your unfairness is what causes those with Envy and Lust pursue you! #mod88Block #Bitcoin Block:578248',
#  'There’re number of ways to start a business  For instance you can Buy &amp; Sell #bitcoin using top payment methods including #PayPal in Ghana. Receive and Send physical or digital cash with over 7 million people just like you.  Sign up here: https://t.co/taUxMmBupk &amp; start trading https://t.co/fBZPrIHTQr',
#  'Buy Bitcoin? Trump Says US ‘Should Match’ China’s Money Printing\xa0Game https://t.co/HVeZ6S1xTW https://t.co/oL1tQu3AXd',
#  'Duplicate successful traders automatically with Bitcoin!   I copy "wangzai888". Do you?   https://1broker.com/?r=25023\xa0   Talk about a great & simple \'set-and-forget\' income!  $IOST | $TRX | $WTC | $ELF | $OCN | $GNT | $STEEM | $LTC | $NXT | $EOSpic.twitter.com/pxHoge30aZ',
#  'New post: "GOLDMAN SACHS: Bitcoin and other cryptocurrencies tend to be locked together — and that’s a big problem" http://ift.tt/2BXZKIX\xa0',
#  'Praise #Satoshi another 10 #Bitcoin blocks have been found! Be thankful for EVERY Block! Block #: 579230 Hash: 00000000000000000023e27e0dfb88a883c7128ded02ddb897077b439ff391e5 https://t.co/c7HsBLLZwz',
#  '@michael_saylor @Frank_Giustra This was solid ....notes from the Vallis/Saylor podcast.   “GOLD is a corruptible monetary system because its centralized. Its corruptible because it’s an open system. It’s a counter party risk because it’s OPEN.” - Saylor   “Bitcoin is a decentralized, closed system.” -Saylor',
#  '@APompliano Why is Bitcoin in decline then??',
#  'RT @deficonnect: #Defipays Bug hunting is ongoing! Sign up, help clear the bugs and also get rewarded.  Sign up to check for bugs here: htt…',
#  '@BscGemSniper $BORING of  @TheBoringDAO This project could allow any blockchain with smart contracts like Ethereum to become a #Layer2 solution for Bitcoin and make $BTC and other assets programmable. #BORING  #BoringDAO  @TheBoringDAO',
#  "worth adding, I'm not an expert in trading, but I use mathematics and numerology, numbers are not charts, numbers are more accurate. #bitcoin",
#  '#Bitcoin in a local Head &amp; Shoulders  BTC has always corrected within 7 days of the technical setup created by the last pump (by the 13th). But whatever happenes, we end Uptober way UP ⬆️ https://t.co/y3245C4lB5',
#  'US Lawmaker Questions Facebook’s Real Intentions With Libra ➡️https://t.co/e6YIjWJzRx 🗺️ ▶️https://t.co/vdnO18c8ZC #newsoftheweek #Bitcoin #blockchain #crypto https://t.co/hr3HWnnc1W',
#  'So-I now have bitcoin! What a process but glad I have it! The only thing is, there’s a waiting period or a limit on what you can spend. I’ve learned quite a bit today!   I’m a naughty student though;I would love to show you my school girl naughtiness.  https://t.co/dSnG3Z3j7P https://t.co/J8U8GiCJTb',
#  'Call: 10/21/19 12:00AM Type: CX-Day Pair: #BTC.X | $BTC.X Broker: CoinBase  Candle: 1H Expectation: Long/Buy  https://t.co/KBgTqllmFe  Follow me for more free #MAXSignals and join us in the live room',
#  'BTC has no overseer.   Bitcoin carries all the same advantages / disadvantages and dangers of cash + many other features outlined elsewhere.Treat it with the same care and caution. #PayItForward',
#  'Disaster Response Training Program- Students, New Graduates - [ ➡ https://t.co/NYqptQjBi2 ] #Agile #Scrum #Agile #Kanban #ProjectMangement #jobs #Hiring #Careers  #Cryptocurrency #Blockchain #BTC #BitCoin #ETH #crypto https://t.co/DyQg0S9XFG',
#  'Are you seriously not using the Fold Card/app yet?  Why the fuck are you turning down free Sats!?  Get with the program.   Sign up for the first Bitcoin rewards card and get 5,000 sats for using my referral link to sign up for Fold! https://t.co/pJ6bwKj5oF',
#  'Great Analysis crypto currency Channel!  join =&gt; https://t.co/LJgIxXylR3  $BTC $XRP $LTC $ETH $ADA $XLM $XVG $TRX $OCN $IOST $NCASH $STORM $EOS $NEO $IOTA $CDT $DASH $XEM $VEN $ETC $GVT $LISK $OMG $APPC $MOD $NEBL $ENJ  5',
#  '#Bitcoin Last Price $21512 #BTC 🚀 Daily Indicators: •Variation since 00h00(UTC): +0.1% •MACD:  -MACD Line: -2331  -Signal Line: -2525  #Ethereum Last Price $1246 #ETH •Variation: +0.27% •MACD:  -MACD Line: -178  -Signal Line: -213  #Crypto #Web3 (2/3) 131878',
#  'Bitmain Antminer T15 23 TH/s Bitcoin Miner BTC BCH + PSU In Hand Ready ship https://t.co/t25sN9Cbt2 #bitcoin #crypto #antminer #bitmain',
#  "@PeterParadoxGG @BitcoinUndisc @GhostOfBekka #bitcoin will always stand for the best in/of humanity.  CBDC's and shitcoins (eth) will always be known for scams and surveillance of of its users.",
#  'Out of trade long back. Will wait and watch the BTC move before re-entering.',
#  'https://t.co/iOquysESrx be at the start to secure you future',
#  'Everything you need to know about #BITCOIN and #CRYPTOCURRENCY in Hong Kong is here in @BitcoinHK   https://t.co/Q24TRizen8',
#  'You can do Cloud Mining using this site https://t.co/wqopSGWNBe   #mining #dogemining #trxmining #btcmining #money #earnmoney #register #bitcoin #ethereum #btc #eth 8098',
#  'One click to start mining cryptocurrencies together with >45K people. # bitcoin https://minergate.com/a/ce567d08f1f74179d3875b13 # IT',
#  'Time to sell XLM for : 0.00041749 BTC in HitBTC Date: 2019-11-10 12:15:57',
#  '#Customer Service Positions - #Entry Level - #New Office Opening - [ ➡ https://t.co/LwMYZ2iktI ] #Agile #Scrum #Agile #Kanban #ProjectMangement #jobs #Hiring #Careers  #Cryptocurrency #Blockchain #BTC https://t.co/D3Ox1fJ6mL',
#  'Wel wel, i just saw Dr. L. Baird explaining the evolution on BTC to come. Also the opinion today where C. Lagarde (ECB, former ITF) states that bitcoin is not so out of the woods on regulations as a majority seems to assume. I have zero doubt on XRP, both prefer that technology.',
#  'I will get acquainted at this ICO-project and I will consider supporting them. I more than one hundred per cent sure that they will become successful! #Shato',
#  'Is it safe to go straight from Bittrex to Bitpay when buying a game from Steam? http://ift.tt/2ymciZp # reddit # bitcoin',
#  'Shoppers Can Now Use Bitcoin and Crypto to Purchase Personal Care Goods and Medicine at Pharmacy Chain in Venezuela https://t.co/LZNeKUpKwv',
#  'RT @ashwsbreal: I shorted #BTC before going to sleep https://t.co/JR3FMQQ29U',
#  'Just watched the Khan Academy video on Proof of Work http://ift.tt/2oz2qGs # reddit # bitcoin',
#  'Everyone knows the wife should get all the # Bitcoin too.',
#  "This team offers conditions at a first-class level. Best product I've ever experienced! #Shato",
#  'In terms of the NVT Signal, $BTC has worked out its contradiction and reached the relative value of the network. Watching!👀  $BTCUSD $XBT $XBTUSD #btc #bitcoin #crypto #blockchain #onchain #barovirtual #baro_virtual https://t.co/Lu7UOlveH8',
#  'You should be taking this technology as seriously as you should have been taking the development of the Internet in the early 1990’s #crypto #btc #bitcoin #bnb #bsc #cryptocurrency #altcoins  #eth',
#  'Check out #blockchain events all over the world and get tickets with #crypto on @zillatoken! https://t.co/A1ICSx018J #event #conference $BTC $ETH',
#  "The #MONEY in your #bank account doesn't really belong to you...  #bitcoin #Crypto #decoupling #markets #Dollar https://t.co/3vznosvIxW",
#  "MAN I'm so tired of #bitcoin just wiping out all growth regularly",
#  'New Crypto Coins and Tokens Released. July 2021 https://t.co/hwyvTDu3J4 via @YouTube   #bitcoin #cryptocurrency #blockchain  Best Crypto Earning Sites: https://t.co/ZJxruJSm8h',
#  'Analyst Who Predicted Bitcoin Bottom Says It Won’t Find New Lows https://t.co/VnSmCb96Tz #BTC, #Market, #Trading, #Business',
#  'HiveEx Cryptocurrency Landscape Report Declares Bitcoin’s Winter is Finally Over, Here’s Why https://t.co/qtBtoWfuaC via @bitcoinsguide',
#  'Yes! God Plays Dice and thats the only thing he does https://t.co/lqGie2AkCZ | #chille #perth #crowdfunding #softbank #equity #neworleans #ITOs #stlouis #miami #Moscow #ardor #minneapolis #stlouis #london #melbourne #bitcoin #deals #preicosale #campaign #abraaj #ITOs #forthworth https://t.co/2C3CaTuJpC',
#  'Bitcoin [BTC] smashes $8000 on the back of Bakkt’s Bitcoin Futures contract launch in July - https://t.co/Uv6EYRByAN',
#  '@VufiFinance Wonderful project, this project is very good and this projector has a lot of attractions, so hopefully the project will be better in the future. @ArafatAhad5  @MdNayee20077599  @SakirAh53983233   #Airdrops #BSC  #Crypto #Bitcoin  #VufiFonance',
#  'IMF Warns Against Adoption of Crypto as National Currency #crypto #bitcoin #cryptopostio https://t.co/TZ32g6p4j3',
#  'If only he had bought yahoo as early on as we are buying #Bitcoin https://t.co/59NrjtTvDM',
#  '# bitcoin # miner New Bitmain Antminer T9 miner 11.5Th in-hand - batch 1 $1650.00 http://ift.tt/2j1QOZkpic.twitter.com/CRsh3dtzRM',
#  '$NEXCF Signs AR University Deal with Leading Brand "Mr. Steak” https://t.co/Ryyz3GkK75  #ad #wsj #nytimes #reuters #bloomberg #thestreet #forbes #nasdaq #IHub_StockPosts #newyork #business  #bitcoin #cannabis #weed #marijuana #CBD #Colorado #latimes #Dispensary #robbreport #MAGA https://t.co/SeU5YWfzAc',
#  '@Parabolic_Matt @YasinZeyd @TechDev_52 Isn’t it price of Bitcoin times total supply, which is 18.8M? How could that supply get thinner?',
#  '⚠️ MICRO-BREAKOUT! ⚠️  MICRO-PUMP!!  BYBIT: BTCUSD  Price: 35720.5 ----  • LIVE Streaming 24/7 🚀 • ONLY Trade the Breakouts! • Try it in Tradingview with a FREE Trial  https://t.co/hpd4MhJZCZ  #Bitcoin #Ethereum $BTC $ETH #Crypto',
#  '@TheMirageSaloon @EvidenceTroll @1NewsNZ Oh look an antivax bitcoin boy , what a surprise',
#  'Bitcoin SV’s Community Experiences Sour Anniversary as Death Cross Forms on BSV/USD https://t.co/gPoY1zR9ao https://t.co/UjSyUq8Tpl',
#  '# bitcoin : # bitcoin CASH Update-10-13 # cryptoCurrency Technical Analysis http://cur.lv/16x7ve # cryptocurrency # breaking # news # discus',
#  "Some screenshots of today's payouts sent directly to my investors bitcoin wallets. Dm for more information on bitcoin mining.  #BitcoinCash https://t.co/rqH4pDlVqv",
#  "@0xD0N0 Happy New year! 🎉🎉🎉 🚀 Don't miss this really cool project!  @LinkSync_Tech    #SyncArny #SYNC #BinanceSmartChain #btc #Crypto #DeFi #altcoin #HAPPYNEWYEAR2022",
#  'Imagine learning 12 words and taking your wealth away from the greedy claws of apparatchiks forever.  Crazy? Certainly.  Possible? Already for many years.',
#  '# Bitcoin Current bitcoin price is 0.00039822 BTC for $1 USD # GoldCoinJar # bitcoin # cryptocurrency # ethereum',
#  '$BTC Latest Block Info: Block 673560 holds 2,125 transactions for a total of 3,551.81564 #Bitcoin including Block Reward. Block Size 1,419,892 Bytes',
#  '#platinumcryptoacademy #bitcoin #cryptocurrency #pancakeswap #defi GAIN PROTOCOL ANNOUNCES CHANGES IN RESPONSE TO BOT TRADING DURING PRE-SALE https://t.co/NRr9mOTZdj',
#  'Bitcoin Daily: Head Of Bitcoin Escrow Firm Charged With Stealing $7M https://t.co/ojTMluQG2Q https://t.co/fxsu6Re5Za',
#  'Simply, the only thing I bought or sold today was purchasing more bitcoin. $BTC',
#  '#Bitcoin attacking the H1 EMA30 again. It has been rejected from this EMA ever since we hit $52,000. A close above could finally mean we look to break out of the HTF channel again  You should Follow @cryptocharts_M he knows his stuff when it comes to #BTC &amp; #cryptocurrency 👍',
#  'Bitcoin Cash Acceptance and Community Growth Ramp Up https://t.co/3gBI5Pcy3N',
#  'Some of my friends still haven’t bought bitcoin 🤷🏼\u200d♂️ https://t.co/stjIzkts7B',
#  'Join us and earn 4X your # Bitcoin with # bitcoinx4 https://goo.gl/1cmsnohttps://goo.gl/1cmsno',
#  '# cryptocurrencies were supposed to replace the finance industry and instead they have replicated it. # bitcoin # tezos',
#  'The #Bitcoin inflation rate briefly fell to 0.71% on 27-June, the lowest level in history.  Blocks will be mined slower when large volumes of hash-power come off the network, and prior to the difficulty adjusting down (estimated to be -27.6% on 3-July).  Live Chart',
#  'The cocksuckers @Google built a cocksucking quantm computer, @realDonaldTrump and the elite gimps want to use it to break ALL proof of work crypto. Bye bye #BTC :(',
#  "Bitcoin is beta version gold; revolting against precious metals a bad idea, claims Crescat Capital's Otavio Costa  https://t.co/0NHJfOvsed  #Bitcoin #BTC #CryptoNews #Cryptocurrency #Gold",
#  '@TheEconomist Hahahaha sucked into the shitcoin vortex. See you in a few years when you realise Bitcoin is the only way.',
#  'Doxxed wrote a page about https://t.co/hjThQ0HT6L! 🤩  Did you already read jt?  If not, check it out here 👉  https://t.co/N1RGQAQCnn 🚀  #SYA #BNB\xa0\xa0#Flooztrade #SYAHumanizeCrypto $SYA #Bitcoin\xa0\xa0\xa0\xa0 #Crypto',
#  '3761.60 #BTC has been transfered to an unknown address             𝗦𝗲𝗻𝗱𝗲𝗿: 3EnqNQgygQ1BJfRQEJZLZMz13jWcFxpYTG                  Balance: 0.00 BTC            𝗥𝗲𝗰𝗶𝗲𝘃𝗲𝗿: 3D8pWW4tFyhxsT3tLcKf5RU9rJFxgNT63k                  Balance: 3761.60 BTC',
#  '#bitcoin #forex #crypto #cryptocurrency #deals  #affiliatemarketing #gift #shopping #gifts #onlineshopping #bitcoin free shipping on purchases over $25 at #Amazon https://t.co/N4zGZzAgvt',
#  '@xtblockio This project looks very interesting. I am shohid123 interested and I will support this project until it is successful according to the plan Good project  @Abir0459  @Nur0459A  @Rafi04599  #Bitcoin #Airdrops #AirdropCrypto',
#  'ByBit $BTC Whale: $400,000 worth of #BTCUSD bought at $10,515.0 15:39:07 2019/07/15 | 💴💴💴💴💴💴💴💴💴💴 Wait until Wall street gets in! To the moon!',
#  '@Bipolar53643675 @hashamadeus @BrianAgrees @AlexPickard Your unregistered security master Calvin literally told people to mine bitcoin and buy his unregistered security token with the profit. Likely no miner took that advice because it’s incredibly retarded.',
#  '@AlizainOfficial @elonmusk True but everyone thought bitcoin was a joke at $0.06 too... someone used 10,000 bitcoins to buy a pizza 10 years ago. Poor soul.. I’ll gladly let a few thousand dollars sit in $doge. The potential reward outweighs the risk imo. Crypto is the future.',
#  '#BTC ⬆️️ 0.58% to AUD$ 41,458  RSI 3: 😟 Overbought RSI 14: 🐻 Bearish  Trajectory: $41,142 in 3 days $41,233 in 14 days $41,367 in 30 days https://t.co/t6aRjZpKPp',
#  '@kurtwuckertjr Why not just buy bitcoin in large amounts then? They can buy like the rest of the whales...   Pssht.',
#  "Despite Bitcoin Price Growth, Queen's Bank Laughs Off Bitcoin http://crwd.fr/2j7C94Y\xa0",
#  '#Bitcoin is trading at a sweet price for those who want to long it. Earn free crypto on @latokens $ELCASH airdrop and later use it to trade tokens: https://t.co/NsIRgiL26P #Ethereum #LATOKEN #LatokenApp',
#  "@manowar1995 @PushpendraTech Playing Litecoin is stupid. Privacy is messed up, can't rise, fall faster than anyone else?  Fans of Litecoin also comforted themselves by saying that it was a dishwashing, Bitcoin Gold Wright Silver.  What kind of cock stuff.  Cultists",
#  'Most meaningful notes from all my scribbles today:  “...to believe things not because she *should* but because she understands.”  Thank you for bridging #Bitcoin with the Western Canon @allenf32   #Bitcoin2021',
#  'Canadas SecureKey to Build a Blockchain Digital Identity Network with US Grant https://goo.gl/MeFEaU http://ohiobitcoin.com/buybitcoin # bit',
#  '@robustus #Bitcoin\xa0 bulls have had a good run so far during this uptober watching $60k-62k as the new resistance support   @10Ethbtc  is a super underrated bitcoiner I’ve been taking her tweets and tips seriously &amp; I’ve  been doing extremely great  Follow her for more TA tips',
#  'Grab yourself a 25% discount on all @ cryptopay Bitcoin Debit cards. https://cryptopay.me/join/2f447084 # Bitcoin # cryptocurrencies',
#  'RT bitcoinagile "Red Stag Casino $21 No Deposit Bonus Code - # bitcoin Casino No Deposit Bonus  pic.twitter.com/c8h6l194V8"',
#  'Block 596630 Hash: 0x...00cd21bbba5106bec963f06334bc6044aa5d1c6263b3f4 Size: 0.22MB, 726761 WU, 18% full Txs: 512 SegWit spends: 46% 921 in → 1,627 out Out/In Ratio: 1.77 Out Value: $5,715,760 | 680 btc https://t.co/aBGOOUhui5',
#  "Check out Defender Of The Blockchain's video! #TikTok https://t.co/6wY9ER55sU #cryptoart #crypto #bitcoinnews #bitcoin #Cryptocurency",
#  'What a weak dump, you got any more? $btc $ltc $eth $link https://t.co/9bStQjdNxN',
#  "Full thanks to @Tradecrypto11 as they have analysed this #Bitcoin crash so my funds doesn't affected and I have not faced any type of losses  They are absolutely amazing in tips,advices and everything😌 #BTC #Crypto #Metaverse #NFT p",
#  'Listen to this interesting interview with Ian Dawson CEO of @zbx_com Exchange.   The future is now with ZBX Exchange.  #crypto #Bitcoin #exchange  https://t.co/KgxyZm7sxC',
#  '$NEO is now worth $13.36 (-0.46%) and 0.00141062 BTC (-1.06%) #NEO  ➡️ https://t.co/IfL7bEdSRV',
#  '#bitcoin #iota #chartanalysis  As #undervaluedIOTA still is a slave of the bitcoin Price here is a bitcoin analysis. Hopefully we see a stable bitcoin price going up to pull IOTA to break out of his neutral sideways trend. https://t.co/tqBzzjaj8K',
#  'https://t.co/UmT9NkTrTx give a free nft, so take it fast bro 🔥🔥🔥  0xf8f96CdfAF6BC8f00c24d091CfA0389f65130052',
#  'Sign up on the best crypto gambling website in the world! You will get a daily, weekly and monthly bonus!  #casino #slots #crypto #betting #eth #btc #gambling #dice  https://t.co/g3f3I7rEmD https://t.co/rysdEaTMXu',
#  'Bear Signal $ATVI ($56.0) in market trading on https://t.co/Lm6Zrpq2pL RSI:54.0, ATR:1.5 #trade #stocks #bitcoin',
#  'Buy Crypto With Your Credit Card / Fast Crypto Exchange   https://t.co/GwaCvQyQbc   #Bitcoin #BTC #ETH #XRP #Crypto 07:36 https://t.co/qWqBG6q2Gc',
#  '# Bitcoin # News: Coinbase Deems European Market Insufficiently Healthy to Trade Bitcoin Cash https://45h.it/v.3/0cyGZpic.twitter.com/fPQLmq',
#  "suddenly your views on BTC become an excellent predictor of your views on $TLRY or $TSLA or immigration.    how this coalesces is so chaotic and random as to defy prediction, but it does and it's all about in-group/outgroup and tight internal correlations.  this way, madness lies",
#  '@binance Adds 14 New Tokens and Multiple New Trading Pairs to the Convert &amp; OTC Portal #Crypto #cryptocurrency #cryptocurrencies #cryptotrading #Cryptocurency #cryptoworld #cryptotwitter #forex #Bitcoin #BTC #binance #invest #investing #BinanceSmartChain $BTC $BNB',
#  '@therealmrcrypto THE NEXT BIGGEST BSC PROJECT!! 👶 🚀   @BabyTripleBSC  👶 🚀 is the #1 baby themed hyper defiationary token based on the Binance smart chain.  ✅ 3 rewards ETH-BNB-BUSD (EVERY HOUR😮)  ✅Dev private Doxxed to marketing team ✅Telegram https://t.co/dZP93DcahF #BTC #BNB #crypto',
#  'Nice to catch up with crypto OGs today over dinner.  Watched the CPI data move $eth and #Bitcoin prices',
#  'Goldman Sachs sees more price pain ahead for bitcoin http://richinwriters.com/goldman-sachs-sees-more-price-pain-ahead-for-bitcoin/\xa0…',
#  '@Flip_3xx And he got a bitcoin',
#  '@elonmusk @occupymars42069 @CrootBall  Nice project and congratulations to the team for their efforts and dedication and highly appreciated the visionary thought of the projector and it will create history #CROOTBALL will go to moon🥰   @CrootBall #CROOTBALL #toto #aksu #infinixNote12 #football #bet #btc',
#  "strategy: 5010HL1h atr20d: 1927.33  26 May 2022 11:00:02 UTC 🔄 'None' 20:00:02 JST --- 30194.5  long_entry_trigger  &gt;  29097.0  last_price $BTC/USD --- 28605.5  short_entry_trigger  #BTC/USD perpetual contract on #BitMEX",
#  'See @CoinCornerMolly  no doubt our boys will be part of the #btc #financialrevolution #crypto https://t.co/pBLclko1B6',
#  'In the last 10 mins, there were arb opps spanning 19 exchange pair(s), yielding profits ranging between $0.00 and $345.71 #bitcoin #btc',
#  "We cheer @Tesla buying $1.5B #Bitcoin. Less so for #Nexon's ¥11B ($100M). Fair enough. But consider the enormity of non-USD currencies sitting on balance sheets globally being replaced by $BTC. Is it likely? Most have high inflation &amp;/or -ve rates.  A wall of money awaits. 🏦🌊💵 https://t.co/UtIu4ZATKy",
#  'DOGE/BTC Volume Advance - Dogecoin (DOGE) 24h volume advances above 30 day average - $DOGE $BTC #dogecoin #fintech #finance',
#  'I can add tennis scoring to that list, no idea how the how any of this works https://t.co/YfbIVkIsge',
#  '#Bitcoin Longs VS shorts  There we go again. https://t.co/1DgUaSjsmk',
#  '@Terri_Bsparrow Linking parallel worlds with 💥#bluesparrow 🌏🌎🪐  🔥 #bluesparrow🔥 for everyone #bluesparrow #bluesparrow  TO THE MOON🌙  #bluesparrow #bluesparrow #bluesparrow @BlueSparrowETH #bitcoin #crypto #Web3 😍😍😍🔥🔥3',
#  '🐂 📈 🚨 Ark Invest CEO Says Impossible to Shut Down Bitcoin — Regulators Will Become More Friendly Over Time – Regulation Bitcoin News - Bitcoin News #BTC  https://t.co/DyRTeqFj10',
#  '#Bitcoin Enters “Extreme Fear” Territory Following Recent Crash The Bitcoin (BTC) Fear and Greed Index, a measure of the general outlook on BTC, had entered “extreme fear” conditions for the first time since late June.',
#  'Join All  The Blockchains Together https://t.co/QOP5685i5L via @YouTube   #blockchain #interoperable #decentralized #autonomous #Libonomy #bitcoin',
#  '#BTC roaring,crypto is poised to change the financial system',
#  "@melikmanukyan @ToddHagopian Okay. Sell me on bitcoin. How do I know that it's value doesn't stem purely from market speculation? Specifically, given that there's no end-point consumption use, as there is with commodities like gold or even fiat currency (Use-case is taxes)?",
#  '@realDonaldTrump As you know, I am running for President. And to gain support, I have prepared an amazing promotion for you folks. The 500 Bitcoin and 5,000 Ethereum #McAfee crypto-extravaganza airdrop has just begun.  Read more: https://t.co/cG0vXe1xlf',
#  'Remember $25 fees to send BTC near the end of 2017.. Are we headed there again? https://t.co/5g8mg2GWmz',
#  '@ vice article from 3 years ago really puts things into perspective: http://bit.ly/2wd6pAR # bitcoin # crypto # throwback # perspective',
#  "@PeterSchiff Nope... Nobody wants boomer rocks when they can have Bitcoin.  It's just superior in every way.  Boomers are going to learn a hard lesson when they try to dump their gold and there are no buyers.",
#  "Full thanks toas they have analysed this #Bitcoin crash so my funds doesn't affected and I have not faced any type of lossesThey are absolutely amazing in tips,advices and everything😌 #BTC #Crypto #Metaverse #NFT😍😍",
#  'If Bip300 was integrated in 2014. Vitalik Buterin, Gavin Wood would of continued making impactful contributions to BTC. Bitcoin block size wars created by immoral lunatics severely stunted Bitcoin Layer 2, Layer 3, and sidechains. Bitcoin needs to soft fork. For endgame. #Bitcoin',
#  'Daily Dot: How DDoS attacks knock your favorite websites offline http://bit.ly/2w2J5Ez\xa0 #news #bitcoin #btc #bitcoin #crypto #news #finte…',
#  '@Shill_Ronin Over 101%+ Profits within 2 hours from #BTC signal for free. telegram link: https://t.co/RCq20YN2Wz https://t.co/vvVV9yxpvo',
#  '@CNBC Setup your FREE account Now : https://t.co/cHgCjBi8C0  Automatic Bitcome - Get Paid CASH Automatically From Businesses All Over The World Every 60 Minutes Even While You Sleep!!  Get Your Free Account Now : https://t.co/cHgCjBi8C0  #Crypto #Cryptocurrency #Bitcoin #BTC #btc',
#  'where am I &amp; where are you #BITCOIN ? https://t.co/IG31pwrZLu',
#  'Bitcoin: Is the bubble about to burst? https://youtu.be/2H6zzWIu7Vk\xa0',
#  'Bitcoin touches over $16,000 but most institutional investors believe it is an unsustainable bubble https://www.linkedin.com/pulse/bitcoin-touches-over-16000-most-institutional-believe-lucio-forgione/?published=t\xa0…',
#  'Currently on round #10697 with 84/100 participants (0.1006562 BTC each)',
#  '#Bitcoin binance cz  chinese mind set never change   for dumps',
#  "If you are not ready to suffer, then go away, don't expect to be a victorious general, to be successful, you must be ruthless! ——[US] Soros #cryptocurrency #bitcoin #Ethereum #investment #venture  #shib #future  #currency #metaverse #NFT #Polygon #PolygonNFT #doge https://t.co/9rokz87u65",
#  'Bitcoin is trading sideways above the key level of $11,000. The leading cryptocurrency is up 0.61% at $11,730 according to the latest data from COIN360 at ...Read more: https://t.co/5b8Ri1aFGg',
#  '@BluesparrowC @MELANIATRUMP @BlueSparrowETH Dogs cant fly but birds can🚀🚀 #bluesparrow 💥🔥 #crypto  #bitcoin #ETH #BlueSparrow #BlueSparrowtoken #BlueSparrowCommunity🤩 #Draw #BestDrawToken @BlueSparrowETH https://t.co/d4cRGW6eFY 1',
#  'Nice team good job',
#  'There is!🏆 I chose the lucky cell and won 0.000012155 ETH! My Username: Otkooooo #betfurysuccess #bitcoin #staking',
#  '@0xCiniz Wow 16M$ Only a fraction of that on #BSC : https://t.co/n4w3lzcSv5  #NFT #NFTs #CryptoArt #CryptoArtist #DigitalArt #DigitalArtist #Crypto #Art #Artist #ETH #GIVEAWAY  #NFTCommunity #BSC #Binancesmartchain #BTC #Binance #doge #dogecoin #ethereum #BSCGems',
#  'Forex Invest futures Bitcoin’s Surge Means Smaller Rivals May Be Due for Rallies https://t.co/5jCCVZDvn0 https://t.co/T83funQ6OA',
#  'My target 🎯 for #BTC is 30k now!!',
#  'Bitcoin: A Peer-to-Peer Electronic Cash System https://t.co/jCvnOs4CWi June 28, 2019 at 12:58PM #CryptoCurrency',
#  '#bitcoin emergence as digital gold could lift price to $146,000, says JPM https://t.co/h3UUDDZcQP https://t.co/6vadqVvc3r',
#  '$LTC performing as expected, In my opinion we are at wave C. Took profits at wave A, planning to short wave C. Chart keeps indicating bearish divergance. #LTC #BTC #BItMEX #XBT @zhijieg https://t.co/6E2A6wL9Tp',
#  'Currently on round #8348 with 79/100 participants (0.10355441 BTC each)',
#  "@RawMaterialNYC @francispouliot_ @Blockstream @Cyphernode_io IOU implies that it's like credit, but that's not what L-BTC is. if you hold funds on Liquid, they are cryptographically backed 1:1 with funds on the bitcoin network, but are in a smart contract.  users have a few ways to convert L-BTC to BTC, basic trade, atomic swap, or peg-out",
#  'There is Bitcoin and... there is Blockchain BS! http://dlvr.it/NTT6Ph # bitcoin # digitalnomadpic.twitter.com/cgyiAQ6Skj',
#  'Long/Short BTC changes with up to 100x Leverage at PrimeXBT! 💰🤩  Sign up immediately and trade your $50 into $5000:  ✅ https://t.co/ZuruGRDJ2w ✅  Earn money even when BTC is falling! 📉📉  $BLOC - $FAT - $LOOM - $EKT - $MCO - $KCS - $RSR - $INB - $NET - $BSV https://t.co/JX3NBCL2lq',
#  '@michael_saylor One can take #bitcoin to heaven but land is for generations to come . Private key is not operational in #Heaven',
#  '@HotcoinGlobal One of the strongest community’s! Pitmag announcement and pumping. We finish the zeros one by one. $PIT BscPitbull Don’t mis it again🚨Last change Thanks to the spirit of the Pitbull community. 🔥Pitbull Token @BscPitbull $PIT #Bitcoin #btc https://t.co/Rahjm3Jb5o',
#  '"Invest in binary options trade today and gain financial #cryptonews #bitcoinsallday #btcc #bitcoin #dashcoin #blockchain #bitcoinasia #bitcoinprogress #bitcoincharts #ether #bitcoinwallet #btcpics #btc #ico #bitcoinbillionaire #cryptocurrencies #coinbase #profit #millions https://t.co/31TM58519h',
#  '# VLB.IO is the 1st global vehicle lifecycle # blockchain. Stay tuned # ICO starts on November 27! http://vlb.io/ # ETH # BTC # ETHEREUM # b',
#  '@DnlKlr @iamtexture Most people in the developed and even a very large percentage of the underdeveloped world have equality of opportunity to get involved with Bitcoin. It is more nuanced than that, yes, but the argument stands regardless.',
#  '@PeterSchiff You got one thing right! Hodlers don’t want to spend their Bitcoin. But that issue is solved with anyone having education on how to manage assets. Hold the asset and borrow. Robert kiyosaki. But the main solution is the actual Bitcoin will never be spent.',
#  'I feel like #HODL is being misappropriated by equity &amp; meme coin groups. #Bitcoin',
#  'Going to buy a few more btc l just because it’ll be back at 10+ soon lol',
#  "@APompliano I'm willing to trade all my #bitcoin for a little more.",
#  'Bitcoin devours more electricity than many countries https://t.co/Fchar7Gcoi',
#  'Pick a team:  Team 🅰️             Team 🅱️ $BTC                   $ETH $SOL                   $ADA $XRP                   $AVAX',
#  'Video Shows $10M Chinese Bitcoin Mining Farm in Flames https://t.co/EfogGKlmXZ',
#  'June 10 $zil news: if I put a stoploss on I’ll get stopped out tonight/ If I hold over night $btc will dump and drag zil down/ If the news is not FB everyone will be disappointed and dump/ If it is FB then everyone will dump because FB is dying/ If I tether it will run hard.',
# ...
#  'How to buy bitcoin for $50 https://youtu.be/P-OjeielUmw\xa0 via @YouTube',
#  'Btc price is on the floor now!',
#  'GET 0,7% daily of ur invest though a AI bot of TELEGRAM =&gt; Bitcoin Arbitrage.  From 5 €/$ ONLY IN BTC Sing-up: https://t.co/hfvbewScvh    TaekookersGoingToJilParty TaekookersGoingToJalParty',
#  '@KuangTV @DATDropCSGO I would join your battles if i had etherium or bitcoin',
#  '@GoldTelegraph_ Prob going to peg it to Bitcoin',
#  '📣📣📣  1 BTC = 452,821,350 LBP  Be Your Own Bank #Bitcoin',
#  'Digital cash is the ‘killer feature’ in Satoshi white paper, says Bitcoin ABC’s Amaury Sechet (via @RealCoinGeek) #BCH #BitcoinCash https://buff.ly/2nNep4r\xa0pic.twitter.com/KoxCm9xoHW',
#  'New post in TA by Joy Bangla: The Bitcoin Buy/Sell Indicator V5.1.2 says to cover all SHORT position and open LONG position. It is receiving TD9 oversold on 1 hour timeframe for #bitcoin #XBTUSD $BTCUSD $BTC.  Disclaimer: Please read the disclaimer at th… https://t.co/AcSvYvr2Sf',
#  '#bitcoin could get a higher B, but ideally we see $9235 before a larger bounce. https://t.co/5nlmpHgl8r',
#  '@Wizardara @TurboXBT #Bitcoin #Ethereum   I am your active retweeter and liker to your tweets . I am hoping to be the winer. And I will claim it. Thank you for Continue to help others. Godbless you and more power. https://t.co/6YqEjshV0I',
#  '@RIshimatsu @JasonYanowitz You compared bitcoin to democracy but I disagree, a crypto currency would be for the people and by the people if everyone had an equal say or control over it, but the rich and powerful would have even more power over the financial system',
#  "This is what a leverage flush out looks like. Don't be so greedy !!! Just hodl !!!  #BTCUSDT $BTC #Ethereum #Chainlink $ETH #cryptocurrency #ETH  #BTC #Avalanche #AVAX #ETH #etherium  #Cardano  #Binance  #Holo  #holochai̇n #VeChain #Bitcoin #SHIB  #Solana #USDT #Crypto #sandbox https://t.co/6e5u4Us1dp",
#  '@ArutzSheva_En BITCOIN: The Future of Finance or Fool’s Gold? https://t.co/RFxNxTlrWj via @YouTube',
#  "@Andrew_J_Howard Aim for  .00021 .0021 .021 .21 2.1 21  This doesn't happen overnight Time is your friend #Bitcoin",
#  '💰 Join now for the latest stock market news and real time alerts. Link in bio 💰  #stocks #stockmarket #pennystocks #investing #stockstowatch #AMC #wallstreet #Investing #cryptocurrency #bitcoin $KXIN  $BIOC $NCTY $SGOC  $AMC https://t.co/1KioLFW78Y',
#  '#bitcoin Innovation For Traveling On Blockchain https://goo.gl/W4j6cf\xa0 http://ohiobitcoin.com/buybitcoin\xa0 #bitcoin',
#  'How does Bitcoin stack up against the world’s three largest GDPs? The market value of goods produced in China, the EU and the United States, respectively, are 75, 104 and 113 times Bitcoin’s market cap. https://t.co/kiDxRqiI5y',
#  'Misconception: Full blocks mean bitcoin is failing #bitcoin today! http://bit.ly/1IAb8e4\xa0',
#  'Crypto is my job and I take lots of time to investigate various projects. This project is the most top-drawer in my rating. #Shato',
#  '#Altcoins Top Gainers [Last 24 hrs]  1. $HOT #Holo 34.4%🚀🔥 2. $GRT #TheGraph 10.83% 3. $ZEC #Zcash 10.73%  Biggest losers [BTD] 1. $MANA #Decentraland -16.81% 2. $CHZ #Chiliz -14.78% 3. $ENJ #Enjin -13.53%  The market is Ranging  #CRYPTO #ALTS #Bitcoin',
#  '$HIVE is the Social #Bitcoin   Few understand this.',
#  'Bitcoin Vaults to 18-Month Highs on Growing\xa0Popularity https://t.co/A4eTMlgzUY',
#  "@Marijimfer @GoingParabolic Bro the S&amp;P 500 is only down like 18% from ATH  The S&amp;P 500 could retrace 60% worst case scenario IMO which would bring #BTC down to like 3k. Highly unlikely but possible. I'm personally expecting a bounce from 10-14k #BTC",
#  'i remember when twilight had us all fooled and had us thinking bella was dead then this btc opened her eyes and the damn movie ended.',
#  'BitBlockBarbeque #Bitcoin Meet up in #Dallas, #Texas.  https://t.co/zMxnGlBCe7  Scheduled for July 29th, see you there. https://t.co/2BWt9DnrIR',
#  '@EricSpracklen This is typical garbage that leads to trash leaving FOX to go to OAN or Newsmax lol. Hydroxychloroquine is still not verified to help normal symptoms of Covid or even passed basic scientific studies outside small control groups. Bitcoin story is sad tho. Griftors going to grift.',
#  '@Seasonal_Tokens #SeasonalTokens #CryptoMining #CyclicalInvesting #BTC Thanks to the well-coordinated and constructive work of the team of professionals.This is most valuable project and clear roadmap project. It’s very legit team work project.',
#  "Holding BTC has been terrifying for the longest time. I can't imagine holding it right now. Wow...  Luckily, I have ZERO.",
#  '#Volume Bot:  $XMR 0.00840200 8.81 BTC at Minute 26 1.7% of Daily Volume UTC Time: 11:26:15 Join us on Discord: https://t.co/WEl019K16x https://t.co/Ti1qm3CjD9',
#  'To buy pipemoon,download a trust wallet, https://t.co/CuiXQvzAYf … … get smart BNB #eth #btc #blockchain #bitcoin #crypto #ethereum #cryptocurrency #cripto #trading #criptomonedas #ico #ripple #cryptocurrencies #forex #emprendedores #dinero #litecoin #criptodivisas #bitcoincash https://t.co/wuUZGJNjAf',
#  'On Aquila we are seeing several # SMB small business # merchants liquidating their @ coinbase # bitcoin holdings past 3 days. More # blood?',
#  'MikEliseev..... can u do the #YFD #YFDFI community a solid and check out this gem....   #Bitcoin',
#  'Nothing to add but what Jack said! $BTCx @JC_BitcoinX @BitcoinXDC @BTCxTreasury @XinFin_Official @XDCFoundation #BitcoinX #BTCx #XDCNetwork $XDC #XDC #Bitcoin #BTC #Crypto #Cryptocurrency #Web3 #NFTCommunity #StakingRewards https://t.co/UugZ1KrjTs',
#  "John Paulson: â\x80\x9cDonâ\x80\x99t invest in Bitcoinâ\x80\x9d | CRYPTO The post John Paulson: “Don't invest in Bitcoin” appeared on https://t.co/MbpPOWGXOr. #crypto https://t.co/TBYr8zpgJD #cryptocurrency #crypto #altseason #defi #enrichedfeed #smartcontracts #furucombo #dex #cex",
#  'I like this nice project. He has good ideas, and people who are actively working together to achieve common goals.  #TeleFy  #DeFi #DEX #cryptocurrency #ETH #BSC #BTC #Airdrop #polkadot #MATIC $TELE #Cardano https://t.co/RMM4CKrOXs',
#  'IT Giant Fujitsu Is Planning to Deploy Multiple Blockchain Business Models - CoinDesk http://ift.tt/2frOTRY # blockchain # bitcoin',
#  'BUY THE DIP  Retweet and viral this post to pump it #dogecoin #moon #BTC #BitMart #BUY #buythedips #ADAcardano #Wink #ElonMusk #czbinance #JustinSun #TRX #cryptocurrency #Crypto #cryptocrash #EthereumClassic #ethereum #shiba #SAFEMOON #SAFESPACE #crash #Bitcoin #dogearmy #khansir https://t.co/sATDfKtKrc',
#  'Get FREE btc every day !! PTC + PTP + Bitcoin Cloud Mining + BTC Games # btc # bitcoin http://bit.ly/2oN39Hm 65pic.twitter.com/OEM2HTOPgG',
#  '#My partner has been physically and verbally abusive ever since he moved in https://t.co/xYDlzQuKg3 | SPONSORED BY: Browsermine .us - #New #Smart #Way #Get #Bitcoin #Free !',
#  'Daily #Bitcoin Thermometer:     MVRV-Z: Market Value to Real. Value Z-Score   SOPR: Spent Output Profit Ratio   MC/TC: Market Cap / Thermoc. Ratio   RHODL: Realized HODL Ratio   Adj S2F: Adj Stock-to-Flow     Follow to be informed about the upcoming tops.   #BTC #LTC #ETH https://t.co/8VgYwbxcMW',
#  '@chowcollection It would be so expensive I couldn’t even dream about affording a whole #Bitcoin. We’d be talking about sats',
#  'Is Bitcoin Poised For Further Losses After Its Recent Drop? - Forbes https://t.co/5vP1Ra5e5A',
#  'The Hardware Bitcoin Wallet. Get Trezor now for only $99 https://buytrezor.com?a=coinokbuytrezor.com/?a=coinok # btc # bitcoin 07 pic.twitte',
#  'Hope there will be a support about here #bitcoin https://t.co/WeSgZ0a4pg',
#  'Sword women series coming out in opensea! 1/7 #women #sword #warrior #procreate #fantasy #swordwoman #digitalpainting #oilpainting #illustration #nft #eth #btc #nftcollector #NFTcommuity #opensea #cryptoartist #nftcollector #cryptoart #NFTartists  https://t.co/LVhqKzQZh3',
#  'One Bitcoin now worth $10297.35@bitstamp. High $10383.200. Low $10258.490. Market Cap $184.696 Billion #bitcoin https://t.co/HhUwMXb6zd',
#  '#Bitcoin mining revenue jumps to its second-highest level ever, topping $1.72 billion in October  #Bitcoin $BTC $ETH #altcoin #NFTNYC #NFTCommunity #NFTGiveaway  #HODL #CryptoNews #cryptocurrency #Bitcoin #Polkastarter #Polkadot #Polkadex  #nftcollector #NFTcollectibles #nftart https://t.co/ValNosxK4c',
#  'ALL IN ONE for BITSTAMP:BTCUSD by LegendaryTrader1980 #BITCOIN https://t.co/RsTSq8Xvhp https://t.co/PYEHziVw1B',
#  "@btc_holder @EA But one thing I do wonder, why is LN good for Bitcoin, can't better digital cash systems, you know one's that are actually censorship resistant, like Monero, just use it and do away with the need for BTC at all?",
#  'Current Bitcoin $BTC price is ~$10,305. In the last 24 hours, the price has changed by -2.461%. For more information please visit our website https://t.co/Ohnctjhi3s | #CCInet',
#  'Singapore suspends crypto exchange over spat with K-pop group BTS https://t.co/r0iS844VpF #cryptocurrency #cryptonews #cryptocurrencynews #bitcoin',
#  '@elonmusk  new picture is a #silver fork  Also means "A Fork in the road".  By extension, the point at which one must make a decision between two or more drastically different choices or opportunities.   (#bitcoin vs #Doge)? https://t.co/pcVu7qJBjH',
#  'When will # bitcoins bloodletting cease? Fundstrats Lee turns to the Bitcoin Misery Index for answers https://www.marketwatch.com/story/when',
#  '@MagicbandM @pills_crypto @dogecoin @BTCTN A little Doge + A little Bitcoin =  1  AWESOME #cryptopill   #Cryptopills by @MichaKlein1',
#  '#XRP #XRPUSDT #XRPCommunity #XRPHolders #BTC\xa0   Do not trade based on these charts. These are study illustrations.  My expectation continues. https://t.co/d23axBTqFp https://t.co/NvsTuy5yUP',
#  'RT @NowRipple: RT @NowRipple: RT @facktorX: RT @Cryptonati2: Ripple Price Analysis: XRP Price is Set to Shoot Up  #XRPthestandard #XRP #XRPCommunity #eth #btc #bitcoin #Blockchain #eos #ltc #trx #xlm #neo #binance #BNB #ADA   https://t.co/cTAE1vhmlz',
#  'Thanks for continuing to talk about and educate others on # bitcoin pic.twitter.com/nMVs6zOSQy',
#  'Bitcoin Set to Retain Its Five-Figure Valuation: DeVere CEO ➡️https://t.co/44zTNHmyLs 🗺️ ▶️https://t.co/vdnO18c8ZC #last7daysnews #Bitcoin #blockchain #crypto https://t.co/rN5ZgOeWd4',
#  'Did conflicting reports about Evergrande defaulting cause Bitcoin to tank? https://t.co/s7zU4nd1Mo',
#  'In the last hour, 7 people won 0.42 BTC playing Bitcoin lottery at http://10xbtc.com\xa0, the easiest BTC lottery, 160BTC Jackpot',
#  'Some gold investors are looking at the digital gold #Bitcoin $BTC while its price is expected to hit $USD 100,000 by the end of 2021, according to an anonymous investor @100trillionUSD, known for his insights into the stock-to-flow ratio.   https://t.co/mQK2IJSX2W',
#  '#Putin Tells Central Bank Not to Create Barriers to #Cryptocurrencies',
#  "https://t.co/zE0DCkP3az #xrp #ripple #trx #btc #Hrithik And Abhishek Agree With Deepika Padukone That '#AllSleepMatters' - #Cricket   #CricketWorldCup2019 - https://t.co/pEpcvupZw5 #Check out Deepika's post and Hrithik and Abhishek's comments below.",
#  '@alexhern thanks for your video on bitcoin and energy use. One thing to consider is that bitcoin mining can help marginal green energy projects become profitable. The money that can be made from bitcoin mining can enable more of these projects to go ahead.',
#  'Bitcoin Cash falls under 1.00BTC for the first time since 50 days ago during the https://goo.gl/fb/wo2yS9 # Bitcoin',
#  '2/3) Has it woken people up? No doubt. But one man is never going to bring down these assholes.  #Bitcoin financially incentivises people to opt into a system that will defund these people. It gets at the very lifeblood which sustains them - their ability to print money.',
#  "@PeterSchiff @PeterSchiff so much for ur bitcoin vs silver theory, as bitcoin climbs back up by $10,500 today. Your gold and silver will stay in the same basic range it's been in for the last 8 years, just wasting ppls time and $$",
#  '@100trillionUSD And you me friends too. All who cares.  That’s why l have this for you.   5000 Bitcoin airdrop has just begun!!!  Join me:',
#  '#Bitcoin #BTC  Fear Greed Index (FEARGREED) 📈 BULLISH indication  Stock to Flow (S2F) 📈 BULLISH indication  Relative Strength Index (RSI) 📈 BULLISH indication',
#  '#Bitcoin #BitcoinCrash  it’s healthy for market to pullback, actually that’s when you should apply technical analysis so that you know which levels to buy the dip!!! I like it when coins dips👌. Blessings in disguise 💰💰💰. https://t.co/qFecXq0RJG',
#  'Ready to begin trading cryptocurrency? Then you should definitely check out Coinigy... Get a 30 day free trial when you sign up here - http:',
#  '@sapatoken great and strong project  @arunanand147  @Kiran56048844  @jingga2620   #Airdrops #Sapa #SapaArmy #Bitcoin\xa0 #BSC\xa0 #BSCgem #BNB',
#  '@johnnylapdance Whatsapp+17346660935Are you interested in Forex trade and bitcoin? Invest with us and get a better return in 3 hours(GENUINE AND LICENSED COMPANY) I can help you manage your account with the minimum of $500 assure you to get $5000.  Invest $600 and earn $6000 weekly.',
#  '@ScalperSilly @APompliano Then you are 100% welcome for my part in the ecosystem...it’s holders like me who guarantee that bitcoin will never go below 3,000 USD again',
#  'http://bit.ly/helpscoin # blockchain # bitcoin # fintech - Photo: FM The Waves blockchain platform is launching i https://twitter.com/i/web/',
#  "@APompliano The US Dollar is WORLD's RESERVE CURRENCY as it is extremely stable and accepted around the world, in digital or cash transactions, &amp; deposits are protected against loss in US Banks Bitcoin is a (digital) asset, highly volatile &amp; subject to fraud ideal for Cartels and the darkweb",
#  '@elonmusk BITCOIN FREESTYLE  (ALONE DESERT TIME by Twenty2Eli on #SoundCloud https://t.co/tgVi3WmQx3',
#  'Please join the BTC Supporter Group! https://t.co/txvILWQuKY 2019-08-04T12:25:01Z https://t.co/nujyw8oPfQ https://t.co/idu2sIlUMU https://t.co/LoE8ZzDGqV',
#  'Russian ZP Legal Claims They Can Recover Mt. Gox’s $2 Billion Lost in Bitcoin Hack https://t.co/2AqrRV2MWy',
#  'Rally caps baby. #Bitcoin bout to move',
#  'Crypto Prices (USD/₿)  Bitcoin ➽ $61321.0337➶ BitcoinCash ➽ $596.0828➷ Polygon ➽ $1.9176➷ Filecoin ➽ $62.4918➶ Stellar ➽ $0.3689➷ Cosmos ➽ $37.3718➷ TRON ➽ $0.1032➷  #Crypto #Bitcoin #BitcoinCash #Polygon #Filecoin #Stellar #Cosmos #TRON',
#  'Nobel Prize Winning Economist Paul Krugman Expresses Skepticism About Crypto, Predicts Collapse http://j.mp/2NWOmTW\xa0 #Bitcoin #Cryptocurrenciespic.twitter.com/tRffGoVwJz',
#  'Girlfriend will buy your groceries but wont buy bitcoin',
#  '@crypto_thug #securypto locked for a while only.. Actually germany always built their country and never ending.. #cryptocurrency #bitcoin #altcoin',
#  'Earn #btc with Bitkong and get 8% interest on all #Winnings. Highly addictive! fast payouts! https://t.co/xTd9NoEfjy #bitcoin via bitkongme',
#  "JasL15 found #bitcoin in a User vault in #Toronto #coinhuntroadtrip Join me playing #coinhuntworld, It's awesome! https://t.co/BTYuD0bCsR #cryptocurrency #32432 https://t.co/HCctRlWFMn",
#  '⏰ LIQUIDATION on BTC-28JUN19 ☠️️   Bought $4,000 of #BTC @ $13152.50  27 Jun 2019 00:10:43 UTC Trade ID: 26848717',
#  'Everything is down ~30%. I guess its time to buy more # coins # CryptoCurrency # bitcoin # litecoin # ripple',
#  'Bitcoin And FinTech Technology Trends For 2016 # crypto # currency # fintech # bitcoin # mining http://makebitcoins.de/bitcoin-and-fintech-t',
#  'I hate that when a #bitcoin bull market starts taking off that actual #bitcoin websites that upload news articles start uploading stuff that damages sentiment. Like banks having new regulations for #crypto etc.  They support Bitcoin but love reporting bad news.  Makes no sense',
#  '# TheMerkle History of # Bitcoin in 500 words on @ Steemit by @ themerklenews http://buff.ly/2leeeiPpic.twitter.com/aqd2fYx1qM',
#  ...]

# %%
df["text"] = df["text"].progress_apply(normalizeTweet)
# Out:
# 100%|██████████| 129991/129991 [00:29<00:00, 4450.16it/s]

# %%
df["text"].to_list()
# Out:
# [':bar_chart: Interesting chart : we can clearly see how long-term holders been accumulating Bitcoins during the Summer-Autumn dump . At the moment total supply held by holders is at almost All Time High . #Btc #100xgem #cryptocurrencies #HODL #ToTheMoon HTTPURL',
#  "Bitcoin 's ' Elon Musk pump ' rally to $ 48K was exclusively driven by whales HTTPURL Laranjal do Elon",
#  "#Bitcoin over $ 50K this morning ... is this the #DeadCatBounce that will go parabolic ? Yesterday , $ SQ announced they purchased Bitcoin ... did #TSLA buy more in the 40s too ? I continue to be bullish on Bitcoin which is why I 'm bullish on $ MARA , $ RIOT , $ MSTR , and $ TSLA .",
#  "Who cares about China 's ban on #Bitcoin . Ca n't ban crypto - moving on ...",
#  'bitcoin tries to take direction again . :up_arrow: :down_arrow: I think after some correction it will be up again . $ btc #btc :speech_balloon:',
#  'The # Skyllz crew is creating the blockchain based and distributed skill validation platform to showcase track and boost human talents acro',
#  "Saying #Bitcoin is n't real because it 's not tangible is like saying the internet is n't real because you can't hold it .. $ btc",
#  '@USER $ shib the money making machineMoney - Also a doge killer #shibarmy #doge #uniswap #cryptocurrencies #ethereum #bitcoin #DeFi #ID #shibaswap',
#  'This is a great project and good team @USER @USER @USER @USER @USER',
#  '@USER #Bitcoin getting really loud * * 5 * 87 * million transactions ( size-able [ 41k -47.9 k + up ] ) in the last 4 days . #USA news .',
#  '# Xapo refused to consider original # BTC as real # bitcoin HTTPURL',
#  '#blockchain #btc #crypto #cryptocurrency #bitcoin #Ethereum #ETH 11 The first blockchain platform to power sports bets via Ethereum smart contracts . No book , no accounts , no odds . Just P2P bets between fans of sports and crypto.https :/ / cryptosportz.com/',
#  "RT @USER : :collision: USA needs to catch up to world on #Bitcoin and crypto regulation - Shark Tank 's Kevin O'Leary",
#  '#fomo is going to eat ppl alive . #doge #dogecoin #btc #Bitcoin HTTPURL',
#  'In my opinion it is the best project 2018 , very strong team , big prospects , good luck to team . #VITA #VITATOKEN #ICO #bitcoin #btc and #cryptocurrency .',
#  'Every day I become more and more a #bitcoin maxi .',
#  "It is extremely hard to see the truth when you rule the World . You 're just too busy .",
#  '- BTC price : $ 34,694 / £ 25,592 28.82 Naks per USD 39.07 Naks per GBP < going UP ! > One #Bitcoin = one million #Naks . Simple as that ! #Bitcoinprice #SatoshiNakamoto 22/01 / 2022 18:25 : 00 GMT HTTPURL',
#  'on the 08/04 / 2021 at 04:02 1BTC was worth $ 37936.00 #Bitcoin #Crypto #BotcoinUSD #Bitfinex',
#  'Saquon Barkley , Star of New York Giants Switched Endorsement Payment to Bitcoin HTTPURL HTTPURL',
#  'current #bitcoin price ( bitstamp ) is $ 222.00 , last changed Sat , 18 Apr 2015 10:22 : 33 GMT . queried at : 10:22 : 40',
#  'Top 1 #Signals $ SNT - Possible Decrease VC : 122.04 % P: 0.0000030300 To see more visit HTTPURL #altcoins #trading #TradingView #crypto #pump #signal $ BTC $ ETH $ XRP $ TRX $ EOS HTTPURL',
#  'BSV better hold $ 140 - $ 145 this week #BSV #BitcoinSV #Bitcoin #BTC HTTPURL',
#  'RT @USER : :magnifying_glass_tilted_left: New #Airdrop : Swords of Blood :heavy_dollar_sign: Reward : Up to 222 SWDTKN ( ~ $ 10 ) + 111K SWDTKN ( ~ $ 5K ) referral pool :red_circle: Start the airdrop ...',
#  "@USER @USER He 's right about the valuation model though :face_with_monocle: those applying old-world financial models to bitcoin will crash and burn .",
#  '@USER Because we believe in #btc',
#  "New DCG Report highlights confidence in asset #Tokenization and #Bitcoin as ‘ store of value ' reported by HTTPURL - - - #Blockchain #BTC #Companies #Digital_Currency_Group #Payments",
#  'Another China FUD ? :dog: The State Council of China : Crack down on Bitcoin mining and trading , and prevent individual risks transmitted to the social field . HTTPURL',
#  '@USER @USER @USER You can not stop phenomena like #bluesparrow #bluesparrow will take over the world The world and governments must adapt themselves with #bluesparrow #bluesparrow :fire: :rocket: #Charity #bitcoin #KYC #Renounce @USER :hundred_points: HTTPURL',
#  '@USER Apollo Coin APX . Listen to the CEO explain why Apollo Coin is going to exceed all expectations in the coming months ! !',
#  "Hellosaurus engineering extraordinaire @USER wrote a fantastic article about monkeys , bitcoin millionaires , workplace motivation , and more . It 's a must-read :down_arrow: :down_arrow: :down_arrow: HTTPURL",
#  "@USER @USER It 's an amazing feeling to have lightning transactions from my phone controlling my own lightning node . Add to that cold storage and .. sorry what are banks for ? Cheap debt is about all I can think of",
#  'How to get paid in #Bitcoin HTTPURL via @USER .twitter.com/VaV47k2x1o',
#  'They have fear because #Bitcoin is already going to make them obsolete . HTTPURL HTTPURL',
#  '@USER I mentioned this earlier . If all you have access to is a disk drive containing the blockchain . How can you verify it is the valid one ? With Bitcoin , a fork would be noticed in a huge drop in Hash power . But an entirely fake blockchain would be noticed by a very low hash power',
#  'Blockchain Browsers — How DLT Could Affect Web Surfing HTTPURL #Blockchain , #Android , #IOS , #API , #wallet , #Internet , #Opera , #Ethereum , #cryptocurrencies , #bitcoin',
#  'Use my referral link HTTPURL to sign up for HTTPURL and we both get $ 25 USD :) #crypto #crypto . com #bitcoin',
#  "HTTPURL #xrp #ripple #trx #btc #We toured Disneyland 's new Star Wars park . Here 's what we learned . - #Cricket #CricketWorldCup2019 - HTTPURL #",
#  'Teenage homeschooler leverages # bitcoin millions to transform higher ed . # homeschooling # cryptocurrencyhttp :/ / bitcoinist.com/teenage-bitc',
#  "@USER : Trezor stopped working on CashAddr ... Because it 's done ! CashAddr code is ready for the next release ! HTTPURL",
#  'STOP THE WAITING NOW PEOPLE ARE GETTING PAID , DM US TODAY TO LEARN HOW TO INVEST IN BITCOUN AND BINARY OPTIONS TRADE :envelope_with_arrow: 24HOURS TRADING 99.9 % WINNING RATE . #bitcoin #investing #invest #binarytrading #optiontrading #love #instagood #me #dubai #hongkong #cute #pioneer #GoodEvening HTTPURL',
#  'TREZOR Silicone Protective cases in 5 colors . They have Free Worldwide Shipping HTTPURL # reddit # bitcoin',
#  '#xeraexchange verifies personal profiles and listings by blockchain technology , to put in the amount of the system is customers , Referrers and friends can be made as reliable #exchange #crypto #cryptocurrency #btc #eth #blockchain #altcoins #technologyli ]',
#  '@USER Everyone see that BTC is bullish again . I know private source with market analytics . And it is free for one week ! Look --> HTTPURL :heavy_large_circle: 2573552 35',
#  '# Bitcoin Current bitcoin price is 0.0004315 2 BTC for $ 1 USD # GoldCoinJar',
#  "Bullish news is that Bitcoin has reached Wall Street . #Bitcoin Futures exchange #Bakkt will launch $ BTC custody for institutional clients on Sept 6 & trading on Sept 23 . Bakkt is founded by Ice , parent company of New York Stock Exchange . Ca n't get bigger than that",
#  'Well done and thanks for this great opportunity . This is an amazing project with good community am looking forward to . @USER @USER @USER #Airdrops #Bitcoin #LOTTRADE #AirdropDet #crypto #Blockchain $ lott HTTPURL',
#  'The current price of Bitcoin is $ 59722.00 . The current price of BCash is $ 589.28 , or 0.0098670 5 BTC . The current price of BCashSV is $ 161.22 , or 0.2735881 1 BCash .',
#  "RT @USER : @USER Check us out ! @USER #TRUMP2024 Love him or Hate him .. these #NFTs will be PRICELESS Do n't Miss Out ! #TRUMPBACKONTWITT ...",
#  "15 / And for a broad , historical ranking in table format , for the entirety of Bitcoin 's history since 2009 , that information is here . HTTPURL",
#  '@USER @USER @USER @USER @USER @USER @USER I think it will definitely do 100X',
#  '@USER @USER And shake off your Peruvian hallucinogens . Crypto is bigger than Bitcoin .',
#  "@USER @USER @USER @USER @USER Lol , he can't do shit , all he can do is to sell his #Bitcoin but he does n't have the balls !",
#  "I 'm exasperated that my friends and family seem to have no better understanding of bitcoin than they did in 2017 . Honestly do n't know if this is bearish or bullish .",
#  ':alarm_clock: LIQUIDATION on BTC-PERPETUAL :skull_and_crossbones: ️️ Bought $ 20 of #BTC @USER $ 8737.00 2 Jun 2019 22:36 : 45 UTC Trade ID : 2296281 1',
#  'BIT FUN . Play games , have fun , earn bitcoin ! . HTTPURL ... #bitcoin #faucet via @USER',
#  '$ BTC retested the 38,600 support and quickly recovered :flexed_biceps: #Bitcoin $ BTC $ ETH #Crypto #Cryptocurrency #Altcoins #TechnicalAnalysis #DeFi #ビットコイン #биткойн #比特币 HTTPURL',
#  '@USER @USER @USER Bitcoin was created to revolutionize currency . You use it as a currency . Start accepting it at your business if you have one . I offer my customers and tenants to pay with Bitcoin usually at a discount relative to USD . HTTPURL',
#  "Tesla can be bought with #Bitcoin Hoping we 'd be able to buy this car with crypto too . Speaking of cryptocurrency , earn a free share of 4K $ TRB tokens on #LATOKEN HTTPURL",
#  "It is extremely hard to see the truth when you rule the World . You 're just too busy .",
#  '@USER @USER @USER HTTPURL is a great place to start ! ! Watch @USER YouTube videos . What questions do you have ?',
#  'Here go #bitcoin , another game changer HTTPURL',
#  'FINALLY OUR EBOOK IS ONLINE :face_screaming_in_fear: :party_popper: Download it now on HTTPURL and take your investments to the next level :clapping_hands: $ BTC #alts #bullrunpreparation HTTPURL',
#  '@USER When will we be able to buy and sell @USER and @USER on @USER ? #cz_binance #BNB #BTC #Ethereum #vitalik @USER #ElonMusk #mayemusk @USER @USER #MATIC #polygon @USER',
#  "It is extremely hard to see the truth when you rule the World . You 're just too busy .",
#  'I want a book to read . Help me ! What will it be ? The Big Reset or The Great Reset ? Willem vs Klaus @USER @USER @USER #thebigreset #TheGreatReset #Covid_19 #gold #bitcoin #books #quote HTTPURL',
#  '@USER @USER @USER Yep . Tell me the partnerships Bitcoin has with major players in the world of finance .',
#  'What percentage should you invest in each cryptocurrency to become a millionaire ? A winning index strategy HTTPURL #Bitcoin #Crypto #Ethereum #Litecoin #Ripple #EOS HTTPURL',
#  'DASH / USD and LTC / USD Technical Analysis May 30 2017 HTTPURL # bitcoin',
#  '@USER Learned myself today as well . Tried to get my feet wet in the market with $ 60 and failed . But I have never failed with bitcoin . #decrentralization for the win .',
#  'This zesty faucet from @USER is making me tweet this to claim my free Lightning sats . :high_voltage: @USER unlock me eb5fd996 - 376e - 42cc - b7fa - ac10a9758c67 #Bitcoin #BTC #LN #LightningNetwork #boltcoiner HTTPURL',
#  'Bitcoin ( btc ) and Ethereum ( eth ) morning price ! — — — :bar_chart: Top 17 Altcoin price ! :bar_chart: — — — - :bank: Market Cap . / Bitcoin dominance / 24 hours volume ! :bank: — — — - :classical_building: Top 6 ... HTTPURL',
#  '@USER @USER @USER @USER This is the best offer to make money on cryptocurrency @USER #Crypto #Bitcoin #USDT #Exchange HTTPURL',
#  'Bitcoin slides in worst weekly drop since March amid selloff HTTPURL',
#  'FBI Requests New Funding To Investigate Use Of Virtual Currencies HTTPURL # Bitcoin # currencies # fundingpic.twitter.com/SDtO',
#  '* LONG POSITION SUGGESTED FOR #BITCOIN * CURRENT PRICE : $ 4.608 ALGO NAME : $ 0.5 S TRACKER ALGO GROUP : HTTPURL ACCURACY : 80 % DATE : 2021-10- 14 09:43 : 13.077395 TRADE NOW : HTTPURL HTTPURL',
#  "But why on earth a country as this sheattle can go to the length of blocking its citizen way of hustling and meeting ends meet ... When they can't produce anything for its citizen ... Dem no want make we dey sucessfull in this part of the world ... ajeh #Bitcoin",
#  'My Crypto Strategy on ICONOMI just outperformed BTC . Check it out here : HTTPURL #trading #forextrader #bitcoin #cryptocurrencies HTTPURL',
#  '#Binance Buyer Volume Alert Stage 1/3 : Ignition :fire: Name : #Bitcoin Cash ABC Symbol : $ BCHABC Pair : $ BTC Price : ₿ 0.0529500 0 TradingView : HTTPURL Hodloo : HTTPURL HTTPURL',
#  '#NUSD #kucoin #Arbitrage Opportunity :rocket: ! 1 ) Sell $ USDT for $ DAI . 2 ) Convert $ DAI to $ NUSD @USER HTTPURL . 3 ) Sell $ NUSD for $ BTC . 4 ) Sell $ BTC for $ USDT . Potential 0.61 % profit ( #kucoin and @USER fees included ) ! 2019-06- 27 23:02 : 37 + 0000',
#  "I pay in bitcoin . DM ya wallet I 'll send ya $ 10 @USER",
#  "@USER Twisted scenario ? The original XRP will die and stay dead . They 'll release a new type of #XRP token tied to #BTC ENERGY & PRECIOUS METALS Buttt ... I do n't know if y'all are ready to hear that full story so I 'll keep it short & simple :rolling_on_the_floor_laughing: :rolling_on_the_floor_laughing: :rolling_on_the_floor_laughing:",
#  "@USER @USER @USER @USER #Bitcoin is still sitting at the $ 60k resistance building up for another push , bears can't seem to get hold to push it down . Now I think 70k is a more likely target Everyone should follow @USER tips and tweets I have been doing superb following her",
#  '@USER UNV is digital gold on the exchange . You can trade $ KBC - UNV , $ BTC-UNV , $ ETH-UNV , and USD-UNV pairs .',
#  "@USER @USER @USER @USER Dude the claim being made is that bitcoin fixes NK by magical trojan horse 12D chess . It does n't - it helps the current regime . What you said does n't strengthen a case that bitcoin fixes NK , you 're just agreeing that it does n't .",
#  '#Altcoin #Bitcoin #Crypto #News Over $ 30 Billion Worth of ADA Now Staked on Cardano HTTPURL',
#  'Invest in bitcoin and earn tremendous profits :money_bag: :credit_card: :money_with_wings: :money_with_wings: :money_with_wings: :hundred_points: HTTPURL',
#  '@USER Damn @USER knows how to buy the dip #bitcoin',
#  'Local ou virtuel largent change de visage HTTPURL',
#  'Bitcoin Mining Could Use More Energy Than All of Italy by 2024 - VICE HTTPURL',
#  "@USER @USER Just do n't buy bitcoin becouse I am sure that bitcoin is not going to hit 10x soon , buy $ KISHU this token have chance to hit 1000x or more :money_with_wings: :rocket: :rocket: :rocket: :chart_increasing: :chart_increasing: :chart_increasing:",
#  'BTC Price : 4551.03 $ , BTC Today High : 4559.39 $ , BTC All Time High : 4742.42 $ ETH Price : 312.52 $ #bitcoin #BTC $ BTC #ETH $ ETHpic.twitter.com/uxIPGIMMO8',
#  '@USER @USER Have you looked into getting bitcoin or litecoin',
#  'ALERT : Bitcoin ( BTC ) at Euro 9764.59 decrease by 4.88 % during the past hour . Price : Euro 9764.59 Timestamp : 18:42 : 03 27-06- 2019 ( Malta / Europe ) This is not financial advice . Do your own research .',
#  "From Parabolic Price to ‘ Ban Bitcoin ' Politicians : Past Week 's Top Stories :right_arrow: ️https :/ / t.co/HO3pXBOy5H :world_map: :play_button: ️https :/ / t.co/vdnO18c8ZC #newsoftheweek #Bitcoin #blockchain #crypto HTTPURL",
#  'Have gotten my girlfriend into this “ virtual money ” followed by her father and her 14yr old sister . My girlfriend and her father now 1 month later are now DCA with @USER . All started with sending $ 1 on lightning and watching it #Bitcoin',
#  'No wonder why it is hard to own a full #Bitcoin nowadays ... 1 $ BTC would be the average net worth of American millennials . HTTPURL',
#  '“ If Libra takes off we get a billion new crypto users that will eventually migrate somewhat into Bitcoin and grow the whole ecosystem . If Libra gets shut down ... boom ! Now we know why Bitcoin is so powerful as a global reserve currency . ” — Brad Stephens',
#  "3LwZf9osJSTTANrqDfkWxA6PjirkUnrbmgtp6eox3Fcg #EidMubarak2022 #Crypto #cryptocurrency #BTC #SOL #SolanaGiveaway #AirdropCrypto #Trending #BULLS I 'm a Christian and this is my roomie and my best buddy though ( I posted his Eid pictures instead ) . One love y'all :flexed_biceps: :hundred_points: :red_heart: HTTPURL HTTPURL",
#  'Bitcoin hits new high as Tesla reveals $ 1.5 bn investment HTTPURL HTTPURL',
#  '#linkedin #twitter #facebook #instagram #tiktok #giftshop #socialmedia #pinterest #dogecoin #deal #gift #gifts #giftideas #shop #shopping #affiliatemarketing #bitcoin Up to 15 % off New Products from #Amazon #Brands HTTPURL',
#  'Can someone make a list about Bollinger bands or some other technical analysis stuff that seems to never matter ? It humors me . #bitcoin',
#  'I know #BTC #Bitcoin is going Hyper Parabolic any time now to 20K + So every time I look at BTC this is what I see #DigitalGold #DigitalAssets #Crypto #Coinbase #Binance #Fidelity #China #XRPtheStandard #Bitstamp #Bitmex #XRP #Ripple #XRPcommunity HTTPURL',
#  'Get any of these for only 8,500 naira Size : 37-41 Kindly retweet To order send a DM / call / WhatsApp on 08082744728 #BBNajia2019 #nationalboyfriendsday #EuropaLeague #WorldAthleticsChamps #JokerMovie #bitcoin #BamLisaxAIS HTTPURL',
#  'RT @USER : :magnifying_glass_tilted_left: New #Airdrop : BrightyPad :trophy: Airdrop Pool : 4,5 Million BYP [ ~ $ 36,000 ] :red_circle: Start the airdrop bot HTTPURL :radio_button: ...',
#  '#Bitcoin Market Alert ! :police_car_light: Order Balance : 32.59 % ( Buy ) Buy 66.30 % | Sell 33.70 % Bid : $ 55354.318 Ask : $ 55354.91 Spread : $ 0.592',
#  '@USER @USER @USER @USER @USER I actually earn my bitcoin at this point . I could hold oranges , cars , houses but instead I hold bitcoin . I do this because its inf easier to secure my coins than it is to protect my wealth by storing it in houses or anything else .',
#  'Are you a newbie on the Binary bitcoin mining network or you already have Bitcoin ? Do you know that you can mine Bitcoin with the Help of the BITMAIN MINING Hardware ? Yes your Bitcoin can mine Up to $ 2000 worth Bitcoin in a day for 2weeks of connection',
#  'Top 3 candidates for reversal for May 16 on @USER ( 1 ) BCHABC ( 2 ) NPXS ( 3 ) EOS #altcoins #bitcoin #BCHABC #NPXS #EOS',
#  "@USER They just do n't see it our way yet , they will , in due course , learn to love Waifu NFT 's . I mean Bitcoin , Bitcoin for sure .",
#  'I believe we are just in a re-accumulation phase and it could take some time to break to new yearly highs . More time and opportunities to #stacksats :beaming_face_with_smiling_eyes: :beaming_face_with_smiling_eyes: #bitcoin $ BTC HTTPURL',
#  'Dont let # FUD Make your investment decisions . Now is the time to # buythedip if youre investing for the long haul . Stick to your portfolio',
#  'Current price of $ BTC is $ 1251.59 via Chain # bitcoin # btc',
#  '#Bitcoin price tags $ 50K for the first time since May :chart_increasing: HTTPURL #BTC #crypto #cryptocurrency @USER HTTPURL',
#  '6Father raised his voice , You allowed your Greed and Sloth to waste the precious rewards , the devotion of others , wasted for many blocks ! Your unfairness is what causes those with Envy and Lust pursue you ! #mod88Block #Bitcoin Block : 578248',
#  "There 're number of ways to start a business For instance you can Buy & Sell #bitcoin using top payment methods including #PayPal in Ghana . Receive and Send physical or digital cash with over 7 million people just like you . Sign up here : HTTPURL & start trading HTTPURL",
#  "Buy Bitcoin ? Trump Says US ‘ Should Match ' China 's Money Printing Game HTTPURL HTTPURL",
#  'Duplicate successful traders automatically with Bitcoin ! I copy " wangzai 888 " . Do you ? HTTPURL Talk about a great & simple \' set-and-forget \' income ! $ IOST | $ TRX | $ WTC | $ ELF | $ OCN | $ GNT | $ STEEM | $ LTC | $ NXT | $ EOSpic.twitter.com/pxHoge30aZ',
#  'New post : " GOLDMAN SACHS : Bitcoin and other cryptocurrencies tend to be locked together — and that \'s a big problem " HTTPURL',
#  'Praise #Satoshi another 10 #Bitcoin blocks have been found ! Be thankful for EVERY Block ! Block # : 579230 Hash : 00000000000 00000002 3e27e0dfb88a883c7128ded02ddb897077b439ff391e5 HTTPURL',
#  "@USER @USER This was solid ... notes from the Vallis / Saylor podcast . “ GOLD is a corruptible monetary system because its centralized . Its corruptible because it 's an open system . It 's a counter party risk because it 's OPEN . ” - Saylor “ Bitcoin is a decentralized , closed system . ” - Saylor",
#  '@USER Why is Bitcoin in decline then ? ?',
#  'RT @USER : #Defipays Bug hunting is ongoing ! Sign up , help clear the bugs and also get rewarded . Sign up to check for bugs here : htt ...',
#  '@USER $ BORING of @USER This project could allow any blockchain with smart contracts like Ethereum to become a #Layer2 solution for Bitcoin and make $ BTC and other assets programmable . #BORING #BoringDAO @USER',
#  "worth adding , I 'm not an expert in trading , but I use mathematics and numerology , numbers are not charts , numbers are more accurate . #bitcoin",
#  '#Bitcoin in a local Head & Shoulders BTC has always corrected within 7 days of the technical setup created by the last pump ( by the 13th ) . But whatever happenes , we end Uptober way UP :up_arrow: HTTPURL',
#  "US Lawmaker Questions Facebook 's Real Intentions With Libra :right_arrow: ️https :/ / t.co/e6YIjWJzRx :world_map: :play_button: ️https :/ / t.co/vdnO18c8ZC #newsoftheweek #Bitcoin #blockchain #crypto HTTPURL",
#  "So-I now have bitcoin ! What a process but glad I have it ! The only thing is , there 's a waiting period or a limit on what you can spend . I 've learned quite a bit today ! I 'm a naughty student though ; I would love to show you my school girl naughtiness . HTTPURL HTTPURL",
#  'Call : 10/21 / 19 12:00 AM Type : CX-Day Pair : #BTC . X | $ BTC . X Broker : CoinBase Candle : 1H Expectation : Long / Buy HTTPURL Follow me for more free #MAXSignals and join us in the live room',
#  'BTC has no overseer . Bitcoin carries all the same advantages / disadvantages and dangers of cash + many other features outlined elsewhere.Treat it with the same care and caution . #PayItForward',
#  'Disaster Response Training Program - Students , New Graduates - [ :right_arrow: HTTPURL ] #Agile #Scrum #Agile #Kanban #ProjectMangement #jobs #Hiring #Careers #Cryptocurrency #Blockchain #BTC #BitCoin #ETH #crypto HTTPURL',
#  'Are you seriously not using the Fold Card / app yet ? Why the fuck are you turning down free Sats ! ? Get with the program . Sign up for the first Bitcoin rewards card and get 5,000 sats for using my referral link to sign up for Fold ! HTTPURL',
#  'Great Analysis crypto currency Channel ! join = > HTTPURL $ BTC $ XRP $ LTC $ ETH $ ADA $ XLM $ XVG $ TRX $ OCN $ IOST $ NCASH $ STORM $ EOS $ NEO $ IOTA $ CDT $ DASH $ XEM $ VEN $ ETC $ GVT $ LISK $ OMG $ APPC $ MOD $ NEBL $ ENJ 5',
#  '#Bitcoin Last Price $ 21512 #BTC :rocket: Daily Indicators : • Variation since 00h00 ( UTC ): +0.1 % • MACD : - MACD Line : - 2331 - Signal Line : - 2525 #Ethereum Last Price $ 1246 #ETH • Variation : +0.27 % • MACD : - MACD Line : - 178 - Signal Line : - 213 #Crypto #Web3 ( 2/3 ) 131878',
#  'Bitmain Antminer T15 23 TH / s Bitcoin Miner BTC BCH + PSU In Hand Ready ship HTTPURL #bitcoin #crypto #antminer #bitmain',
#  "@USER @USER @USER #bitcoin will always stand for the best in / of humanity . CBDC 's and shitcoins ( eth ) will always be known for scams and surveillance of of its users .",
#  'Out of trade long back . Will wait and watch the BTC move before re-entering .',
#  'HTTPURL be at the start to secure you future',
#  'Everything you need to know about #BITCOIN and #CRYPTOCURRENCY in Hong Kong is here in @USER HTTPURL',
#  'You can do Cloud Mining using this site HTTPURL #mining #dogemining #trxmining #btcmining #money #earnmoney #register #bitcoin #ethereum #btc #eth 8098',
#  'One click to start mining cryptocurrencies together with > 45K people . # bitcoin HTTPURL # IT',
#  'Time to sell XLM for : 0.0004174 9 BTC in HitBTC Date : 2019-11- 10 12:15 : 57',
#  '#Customer Service Positions - #Entry Level - #New Office Opening - [ :right_arrow: HTTPURL ] #Agile #Scrum #Agile #Kanban #ProjectMangement #jobs #Hiring #Careers #Cryptocurrency #Blockchain #BTC HTTPURL',
#  'Wel wel , i just saw Dr . L . Baird explaining the evolution on BTC to come . Also the opinion today where C . Lagarde ( ECB , former ITF ) states that bitcoin is not so out of the woods on regulations as a majority seems to assume . I have zero doubt on XRP , both prefer that technology .',
#  'I will get acquainted at this ICO-project and I will consider supporting them . I more than one hundred per cent sure that they will become successful ! #Shato',
#  'Is it safe to go straight from Bittrex to Bitpay when buying a game from Steam ? HTTPURL # reddit # bitcoin',
#  'Shoppers Can Now Use Bitcoin and Crypto to Purchase Personal Care Goods and Medicine at Pharmacy Chain in Venezuela HTTPURL',
#  'RT @USER : I shorted #BTC before going to sleep HTTPURL',
#  'Just watched the Khan Academy video on Proof of Work HTTPURL # reddit # bitcoin',
#  'Everyone knows the wife should get all the # Bitcoin too .',
#  "This team offers conditions at a first-class level . Best product I 've ever experienced ! #Shato",
#  'In terms of the NVT Signal , $ BTC has worked out its contradiction and reached the relative value of the network . Watching ! :eyes: $ BTCUSD $ XBT $ XBTUSD #btc #bitcoin #crypto #blockchain #onchain #barovirtual #baro_virtual HTTPURL',
#  "You should be taking this technology as seriously as you should have been taking the development of the Internet in the early 1990 ' s #crypto #btc #bitcoin #bnb #bsc #cryptocurrency #altcoins #eth",
#  'Check out #blockchain events all over the world and get tickets with #crypto on @USER ! HTTPURL #event #conference $ BTC $ ETH',
#  "The #MONEY in your #bank account does n't really belong to you ... #bitcoin #Crypto #decoupling #markets #Dollar HTTPURL",
#  "MAN I 'm so tired of #bitcoin just wiping out all growth regularly",
#  'New Crypto Coins and Tokens Released . July 2021 HTTPURL via @USER #bitcoin #cryptocurrency #blockchain Best Crypto Earning Sites : HTTPURL',
#  "Analyst Who Predicted Bitcoin Bottom Says It Wo n't Find New Lows HTTPURL #BTC , #Market , #Trading , #Business",
#  "HiveEx Cryptocurrency Landscape Report Declares Bitcoin 's Winter is Finally Over , Here 's Why HTTPURL via @USER",
#  'Yes ! God Plays Dice and thats the only thing he does HTTPURL | #chille #perth #crowdfunding #softbank #equity #neworleans #ITOs #stlouis #miami #Moscow #ardor #minneapolis #stlouis #london #melbourne #bitcoin #deals #preicosale #campaign #abraaj #ITOs #forthworth HTTPURL',
#  "Bitcoin [ BTC ] smashes $ 8000 on the back of Bakkt 's Bitcoin Futures contract launch in July - HTTPURL",
#  '@USER Wonderful project , this project is very good and this projector has a lot of attractions , so hopefully the project will be better in the future . @USER @USER @USER #Airdrops #BSC #Crypto #Bitcoin #VufiFonance',
#  'IMF Warns Against Adoption of Crypto as National Currency #crypto #bitcoin #cryptopostio HTTPURL',
#  'If only he had bought yahoo as early on as we are buying #Bitcoin HTTPURL',
#  '# bitcoin # miner New Bitmain Antminer T9 miner 11.5 Th in-hand - batch 1 $ 1650.00 HTTPURL',
#  '$ NEXCF Signs AR University Deal with Leading Brand " Mr . Steak ” HTTPURL #ad #wsj #nytimes #reuters #bloomberg #thestreet #forbes #nasdaq #IHub_StockPosts #newyork #business #bitcoin #cannabis #weed #marijuana #CBD #Colorado #latimes #Dispensary #robbreport #MAGA HTTPURL',
#  "@USER @USER @USER Is n't it price of Bitcoin times total supply , which is 18.8 M ? How could that supply get thinner ?",
#  ':warning: MICRO-BREAKOUT ! :warning: MICRO-PUMP ! ! BYBIT : BTCUSD Price : 35720.5 - - - • LIVE Streaming 24/7 :rocket: • ONLY Trade the Breakouts ! • Try it in Tradingview with a FREE Trial HTTPURL #Bitcoin #Ethereum $ BTC $ ETH #Crypto',
#  '@USER @USER @USER Oh look an antivax bitcoin boy , what a surprise',
#  "Bitcoin SV 's Community Experiences Sour Anniversary as Death Cross Forms on BSV / USD HTTPURL HTTPURL",
#  '# bitcoin : # bitcoin CASH Update -10-13 # cryptoCurrency Technical Analysis HTTPURL # cryptocurrency # breaking # news # discus',
#  "Some screenshots of today 's payouts sent directly to my investors bitcoin wallets . Dm for more information on bitcoin mining . #BitcoinCash HTTPURL",
#  "@USER Happy New year ! :party_popper: :party_popper: :party_popper: :rocket: Do n't miss this really cool project ! @USER #SyncArny #SYNC #BinanceSmartChain #btc #Crypto #DeFi #altcoin #HAPPYNEWYEAR2022",
#  'Imagine learning 12 words and taking your wealth away from the greedy claws of apparatchiks forever . Crazy ? Certainly . Possible ? Already for many years .',
#  '# Bitcoin Current bitcoin price is 0.0003982 2 BTC for $ 1 USD # GoldCoinJar # bitcoin # cryptocurrency # ethereum',
#  '$ BTC Latest Block Info : Block 673560 holds 2,125 transactions for a total of 3,551 . 81564 #Bitcoin including Block Reward . Block Size 1,419 , 892 Bytes',
#  '#platinumcryptoacademy #bitcoin #cryptocurrency #pancakeswap #defi GAIN PROTOCOL ANNOUNCES CHANGES IN RESPONSE TO BOT TRADING DURING PRE-SALE HTTPURL',
#  'Bitcoin Daily : Head Of Bitcoin Escrow Firm Charged With Stealing $ 7M HTTPURL HTTPURL',
#  'Simply , the only thing I bought or sold today was purchasing more bitcoin . $ BTC',
#  '#Bitcoin attacking the H1 EMA 30 again . It has been rejected from this EMA ever since we hit $ 52,000 . A close above could finally mean we look to break out of the HTF channel again You should Follow @USER he knows his stuff when it comes to #BTC & #cryptocurrency :thumbs_up:',
#  'Bitcoin Cash Acceptance and Community Growth Ramp Up HTTPURL',
#  "Some of my friends still have n't bought bitcoin 🤷🏼\u200d♂ HTTPURL",
#  'Join us and earn 4X your # Bitcoin with # bitcoinx 4 HTTPURL',
#  '# cryptocurrencies were supposed to replace the finance industry and instead they have replicated it . # bitcoin # tezos',
#  'The #Bitcoin inflation rate briefly fell to 0.71 % on 27 - June , the lowest level in history . Blocks will be mined slower when large volumes of hash-power come off the network , and prior to the difficulty adjusting down ( estimated to be -27.6 % on 3 - July ) . Live Chart',
#  'The cocksuckers @USER built a cocksucking quantm computer , @USER and the elite gimps want to use it to break ALL proof of work crypto . Bye bye #BTC :(',
#  "Bitcoin is beta version gold ; revolting against precious metals a bad idea , claims Crescat Capital 's Otavio Costa HTTPURL #Bitcoin #BTC #CryptoNews #Cryptocurrency #Gold",
#  '@USER Hahahaha sucked into the shitcoin vortex . See you in a few years when you realise Bitcoin is the only way .',
#  'Doxxed wrote a page about HTTPURL ! :star-struck: Did you already read jt ? If not , check it out here :backhand_index_pointing_right: HTTPURL :rocket: #SYA #BNB #Flooztrade #SYAHumanizeCrypto $ SYA #Bitcoin #Crypto',
#  '3761.60 #BTC has been transfered to an unknown address 𝗦𝗲𝗻𝗱𝗲𝗿 : 3EnqNQgygQ1BJfRQEJZLZMz13jWcFxpYTG Balance : 0.00 BTC 𝗥𝗲𝗰𝗶𝗲𝘃𝗲𝗿 : 3D8pWW4tFyhxsT3tLcKf5RU9rJFxgNT63k Balance : 3761.60 BTC',
#  '#bitcoin #forex #crypto #cryptocurrency #deals #affiliatemarketing #gift #shopping #gifts #onlineshopping #bitcoin free shipping on purchases over $ 25 at #Amazon HTTPURL',
#  '@USER This project looks very interesting . I am shohid 123 interested and I will support this project until it is successful according to the plan Good project @USER @USER @USER #Bitcoin #Airdrops #AirdropCrypto',
#  'ByBit $ BTC Whale : $ 400,000 worth of #BTCUSD bought at $ 10,515 . 0 15:39 : 07 2019/07 / 15 | :yen_banknote: :yen_banknote: :yen_banknote: Wait until Wall street gets in ! To the moon !',
#  "@USER @USER @USER @USER Your unregistered security master Calvin literally told people to mine bitcoin and buy his unregistered security token with the profit . Likely no miner took that advice because it 's incredibly retarded .",
#  "@USER @USER True but everyone thought bitcoin was a joke at $ 0.06 too ... someone used 10,000 bitcoins to buy a pizza 10 years ago . Poor soul .. I 'll gladly let a few thousand dollars sit in $ doge . The potential reward outweighs the risk imo . Crypto is the future .",
#  '#BTC :up_arrow: ️️ 0.58 % to AUD $ 41,458 RSI 3 : :worried_face: Overbought RSI 14 : :bear_face: Bearish Trajectory : $ 41,142 in 3 days $ 41,233 in 14 days $ 41,367 in 30 days HTTPURL',
#  '@USER Why not just buy bitcoin in large amounts then ? They can buy like the rest of the whales ... Pssht .',
#  "Despite Bitcoin Price Growth , Queen 's Bank Laughs Off Bitcoin HTTPURL",
#  '#Bitcoin is trading at a sweet price for those who want to long it . Earn free crypto on @USER $ ELCASH airdrop and later use it to trade tokens : HTTPURL #Ethereum #LATOKEN #LatokenApp',
#  "@USER @USER Playing Litecoin is stupid . Privacy is messed up , can't rise , fall faster than anyone else ? Fans of Litecoin also comforted themselves by saying that it was a dishwashing , Bitcoin Gold Wright Silver . What kind of cock stuff . Cultists",
#  'Most meaningful notes from all my scribbles today : “ ... to believe things not because she * should * but because she understands . ” Thank you for bridging #Bitcoin with the Western Canon @USER #Bitcoin2021',
#  'Canadas SecureKey to Build a Blockchain Digital Identity Network with US Grant HTTPURL HTTPURL # bit',
#  "@USER #Bitcoin bulls have had a good run so far during this uptober watching $ 60k - 62k as the new resistance support @USER is a super underrated bitcoiner I 've been taking her tweets and tips seriously & I 've been doing extremely great Follow her for more TA tips",
#  'Grab yourself a 25 % discount on all @USER cryptopay Bitcoin Debit cards . HTTPURL # Bitcoin # cryptocurrencies',
#  'RT bitcoinagile " Red Stag Casino $ 21 No Deposit Bonus Code - # bitcoin Casino No Deposit Bonus pic.twitter.com/c8h6l194V8 "',
#  'Block 596630 Hash : 0x ... 00cd21bbba5106bec963f06334bc6044aa5d1c6263b3f4 Size : 0.22 MB , 726761 WU , 18 % full Txs : 512 SegWit spends : 46 % 921 in → 1,627 out Out / In Ratio : 1.77 Out Value : $ 5,715 , 760 | 680 btc HTTPURL',
#  "Check out Defender Of The Blockchain 's video ! #TikTok HTTPURL #cryptoart #crypto #bitcoinnews #bitcoin #Cryptocurency",
#  'What a weak dump , you got any more ? $ btc $ ltc $ eth $ link HTTPURL',
#  "Full thanks to @USER as they have analysed this #Bitcoin crash so my funds does n't affected and I have not faced any type of losses They are absolutely amazing in tips , advices and everything :relieved_face: #BTC #Crypto #Metaverse #NFT p",
#  'Listen to this interesting interview with Ian Dawson CEO of @USER Exchange . The future is now with ZBX Exchange . #crypto #Bitcoin #exchange HTTPURL',
#  '$ NEO is now worth $ 13.36 ( -0.46 % ) and 0.0014106 2 BTC ( -1.06 % ) #NEO :right_arrow: HTTPURL',
#  '#bitcoin #iota #chartanalysis As #undervaluedIOTA still is a slave of the bitcoin Price here is a bitcoin analysis . Hopefully we see a stable bitcoin price going up to pull IOTA to break out of his neutral sideways trend . HTTPURL',
#  'HTTPURL give a free nft , so take it fast bro :fire: :fire: :fire: 0xf8f96CdfAF6BC8f00c24d091CfA0389f65130052',
#  'Sign up on the best crypto gambling website in the world ! You will get a daily , weekly and monthly bonus ! #casino #slots #crypto #betting #eth #btc #gambling #dice HTTPURL HTTPURL',
#  'Bear Signal $ ATVI ( $ 56.0 ) in market trading on HTTPURL RSI : 54.0 , ATR : 1.5 #trade #stocks #bitcoin',
#  'Buy Crypto With Your Credit Card / Fast Crypto Exchange HTTPURL #Bitcoin #BTC #ETH #XRP #Crypto 07:36 HTTPURL',
#  '# Bitcoin # News : Coinbase Deems European Market Insufficiently Healthy to Trade Bitcoin Cash HTTPURL',
#  "suddenly your views on BTC become an excellent predictor of your views on $ TLRY or $ TSLA or immigration . how this coalesces is so chaotic and random as to defy prediction , but it does and it 's all about in-group / outgroup and tight internal correlations . this way , madness lies",
#  '@USER Adds 14 New Tokens and Multiple New Trading Pairs to the Convert & OTC Portal #Crypto #cryptocurrency #cryptocurrencies #cryptotrading #Cryptocurency #cryptoworld #cryptotwitter #forex #Bitcoin #BTC #binance #invest #investing #BinanceSmartChain $ BTC $ BNB',
#  '@USER THE NEXT BIGGEST BSC PROJECT ! ! :baby: :rocket: @USER :baby: :rocket: is the # 1 baby themed hyper defiationary token based on the Binance smart chain . :white_heavy_check_mark: 3 rewards ETH-BNB-BUSD ( EVERY HOUR :face_with_open_mouth: ) :white_heavy_check_mark: Dev private Doxxed to marketing team :white_heavy_check_mark: Telegram HTTPURL #BTC #BNB #crypto',
#  'Nice to catch up with crypto OGs today over dinner . Watched the CPI data move $ eth and #Bitcoin prices',
#  'Goldman Sachs sees more price pain ahead for bitcoin HTTPURL ...',
#  '@USER And he got a bitcoin',
#  '@USER @USER @USER Nice project and congratulations to the team for their efforts and dedication and highly appreciated the visionary thought of the projector and it will create history #CROOTBALL will go to moon :smiling_face_with_3_hearts: @USER #CROOTBALL #toto #aksu #infinixNote12 #football #bet #btc',
#  "strategy : 5010HL1h atr 20d : 1927.33 26 May 2022 11:00 : 02 UTC :counterclockwise_arrows_button: ' None ' 20:00 : 02 JST - - - 30194.5 long_entry_trigger > 29097.0 last_price $ BTC / USD - - - 28605.5 short_entry_trigger #BTC / USD perpetual contract on #BitMEX",
#  'See @USER no doubt our boys will be part of the #btc #financialrevolution #crypto HTTPURL',
#  'In the last 10 mins , there were arb opps spanning 19 exchange pair ( s ) , yielding profits ranging between $ 0.00 and $ 345.71 #bitcoin #btc',
#  "We cheer @USER buying $ 1.5 B #Bitcoin . Less so for #Nexon 's ¥ 11B ( $ 100M ) . Fair enough . But consider the enormity of non-USD currencies sitting on balance sheets globally being replaced by $ BTC . Is it likely ? Most have high inflation & / or - ve rates . A wall of money awaits . :bank: :water_wave: :dollar_banknote: HTTPURL",
#  'DOGE / BTC Volume Advance - Dogecoin ( DOGE ) 24h volume advances above 30 day average - $ DOGE $ BTC #dogecoin #fintech #finance',
#  'I can add tennis scoring to that list , no idea how the how any of this works HTTPURL',
#  '#Bitcoin Longs VS shorts There we go again . HTTPURL',
#  '@USER Linking parallel worlds with :collision: #bluesparrow :globe_showing_Asia-Australia: :globe_showing_Americas: :ringed_planet: :fire: #bluesparrow :fire: for everyone #bluesparrow #bluesparrow TO THE MOON :crescent_moon: #bluesparrow #bluesparrow #bluesparrow @USER #bitcoin #crypto #Web3 :smiling_face_with_heart-eyes: :smiling_face_with_heart-eyes: :smiling_face_with_heart-eyes: :fire: :fire: 3',
#  ':ox: :chart_increasing: :police_car_light: Ark Invest CEO Says Impossible to Shut Down Bitcoin — Regulators Will Become More Friendly Over Time – Regulation Bitcoin News - Bitcoin News #BTC HTTPURL',
#  '#Bitcoin Enters “ Extreme Fear ” Territory Following Recent Crash The Bitcoin ( BTC ) Fear and Greed Index , a measure of the general outlook on BTC , had entered “ extreme fear ” conditions for the first time since late June .',
#  'Join All The Blockchains Together HTTPURL via @USER #blockchain #interoperable #decentralized #autonomous #Libonomy #bitcoin',
#  '#BTC roaring , crypto is poised to change the financial system',
#  "@USER @USER Okay . Sell me on bitcoin . How do I know that it 's value does n't stem purely from market speculation ? Specifically , given that there 's no end-point consumption use , as there is with commodities like gold or even fiat currency ( Use-case is taxes ) ?",
#  '@USER As you know , I am running for President . And to gain support , I have prepared an amazing promotion for you folks . The 500 Bitcoin and 5,000 Ethereum #McAfee crypto-extravaganza airdrop has just begun . Read more : HTTPURL',
#  'Remember $ 25 fees to send BTC near the end of 2017 .. Are we headed there again ? HTTPURL',
#  '@USER vice article from 3 years ago really puts things into perspective : HTTPURL # bitcoin # crypto # throwback # perspective',
#  "@USER Nope ... Nobody wants boomer rocks when they can have Bitcoin . It 's just superior in every way . Boomers are going to learn a hard lesson when they try to dump their gold and there are no buyers .",
#  "Full thanks toas they have analysed this #Bitcoin crash so my funds does n't affected and I have not faced any type of lossesThey are absolutely amazing in tips , advices and everything :relieved_face: #BTC #Crypto #Metaverse #NFT :smiling_face_with_heart-eyes: :smiling_face_with_heart-eyes:",
#  'If Bip 300 was integrated in 2014 . Vitalik Buterin , Gavin Wood would of continued making impactful contributions to BTC . Bitcoin block size wars created by immoral lunatics severely stunted Bitcoin Layer 2 , Layer 3 , and sidechains . Bitcoin needs to soft fork . For endgame . #Bitcoin',
#  'Daily Dot : How DDoS attacks knock your favorite websites offline HTTPURL #news #bitcoin #btc #bitcoin #crypto #news #finte ...',
#  '@USER Over 101 % + Profits within 2 hours from #BTC signal for free . telegram link : HTTPURL HTTPURL',
#  '@USER Setup your FREE account Now : HTTPURL Automatic Bitcome - Get Paid CASH Automatically From Businesses All Over The World Every 60 Minutes Even While You Sleep ! ! Get Your Free Account Now : HTTPURL #Crypto #Cryptocurrency #Bitcoin #BTC #btc',
#  'where am I & where are you #BITCOIN ? HTTPURL',
#  'Bitcoin : Is the bubble about to burst ? HTTPURL',
#  'Bitcoin touches over $ 16,000 but most institutional investors believe it is an unsustainable bubble HTTPURL ...',
#  'Currently on round #10697 with 84/100 participants ( 0.1006562 BTC each )',
#  '#Bitcoin binance cz chinese mind set never change for dumps',
#  "If you are not ready to suffer , then go away , do n't expect to be a victorious general , to be successful , you must be ruthless ! — — [ US ] Soros #cryptocurrency #bitcoin #Ethereum #investment #venture #shib #future #currency #metaverse #NFT #Polygon #PolygonNFT #doge HTTPURL",
#  'Bitcoin is trading sideways above the key level of $ 11,000 . The leading cryptocurrency is up 0.61 % at $ 11,730 according to the latest data from COIN 360 at ... Read more : HTTPURL',
#  '@USER @USER @USER Dogs cant fly but birds can :rocket: :rocket: #bluesparrow :collision: :fire: #crypto #bitcoin #ETH #BlueSparrow #BlueSparrowtoken #BlueSparrowCommunity :star-struck: #Draw #BestDrawToken @USER HTTPURL 1',
#  'Nice team good job',
#  'There is ! :trophy: I chose the lucky cell and won 0.0000121 55 ETH ! My Username : Otkooooo #betfurysuccess #bitcoin #staking',
#  '@USER Wow 16M $ Only a fraction of that on #BSC : HTTPURL #NFT #NFTs #CryptoArt #CryptoArtist #DigitalArt #DigitalArtist #Crypto #Art #Artist #ETH #GIVEAWAY #NFTCommunity #BSC #Binancesmartchain #BTC #Binance #doge #dogecoin #ethereum #BSCGems',
#  "Forex Invest futures Bitcoin 's Surge Means Smaller Rivals May Be Due for Rallies HTTPURL HTTPURL",
#  'My target :direct_hit: for #BTC is 30k now ! !',
#  'Bitcoin : A Peer-to-Peer Electronic Cash System HTTPURL June 28 , 2019 at 12:58 PM #CryptoCurrency',
#  '#bitcoin emergence as digital gold could lift price to $ 146,000 , says JPM HTTPURL HTTPURL',
#  '$ LTC performing as expected , In my opinion we are at wave C . Took profits at wave A , planning to short wave C . Chart keeps indicating bearish divergance . #LTC #BTC #BItMEX #XBT @USER HTTPURL',
#  'Currently on round #8348 with 79/100 participants ( 0.1035544 1 BTC each )',
#  "@USER @USER @USER @USER IOU implies that it 's like credit , but that 's not what L-BTC is . if you hold funds on Liquid , they are cryptographically backed 1:1 with funds on the bitcoin network , but are in a smart contract . users have a few ways to convert L-BTC to BTC , basic trade , atomic swap , or peg-out",
#  'There is Bitcoin and ... there is Blockchain BS ! HTTPURL # bitcoin # digitalnomadpic.twitter.com/cgyiAQ6Skj',
#  'Long / Short BTC changes with up to 100x Leverage at PrimeXBT ! :money_bag: :star-struck: Sign up immediately and trade your $ 50 into $ 5000 : :white_heavy_check_mark: HTTPURL :white_heavy_check_mark: Earn money even when BTC is falling ! :chart_decreasing: :chart_decreasing: $ BLOC - $ FAT - $ LOOM - $ EKT - $ MCO - $ KCS - $ RSR - $ INB - $ NET - $ BSV HTTPURL',
#  '@USER One can take #bitcoin to heaven but land is for generations to come . Private key is not operational in #Heaven',
#  "@USER One of the strongest community 's ! Pitmag announcement and pumping . We finish the zeros one by one . $ PIT BscPitbull Do n't mis it again :police_car_light: Last change Thanks to the spirit of the Pitbull community . :fire: Pitbull Token @USER $ PIT #Bitcoin #btc HTTPURL",
#  '" Invest in binary options trade today and gain financial #cryptonews #bitcoinsallday #btcc #bitcoin #dashcoin #blockchain #bitcoinasia #bitcoinprogress #bitcoincharts #ether #bitcoinwallet #btcpics #btc #ico #bitcoinbillionaire #cryptocurrencies #coinbase #profit #millions HTTPURL',
#  '# VLB.IO is the 1st global vehicle lifecycle # blockchain . Stay tuned # ICO starts on November 27 ! HTTPURL # ETH # BTC # ETHEREUM # b',
#  '@USER @USER Most people in the developed and even a very large percentage of the underdeveloped world have equality of opportunity to get involved with Bitcoin . It is more nuanced than that , yes , but the argument stands regardless .',
#  "@USER You got one thing right ! Hodlers do n't want to spend their Bitcoin . But that issue is solved with anyone having education on how to manage assets . Hold the asset and borrow . Robert kiyosaki . But the main solution is the actual Bitcoin will never be spent .",
#  'I feel like #HODL is being misappropriated by equity & meme coin groups . #Bitcoin',
#  "Going to buy a few more btc l just because it 'll be back at 10 + soon lol",
#  "@USER I 'm willing to trade all my #bitcoin for a little more .",
#  'Bitcoin devours more electricity than many countries HTTPURL',
#  'Pick a team : Team 🅰️ Team 🅱️ $ BTC $ ETH $ SOL $ ADA $ XRP $ AVAX',
#  'Video Shows $ 10M Chinese Bitcoin Mining Farm in Flames HTTPURL',
#  "June 10 $ zil news : if I put a stoploss on I 'll get stopped out tonight / If I hold over night $ btc will dump and drag zil down / If the news is not FB everyone will be disappointed and dump / If it is FB then everyone will dump because FB is dying / If I tether it will run hard .",
#  'Priced in #Bitcoin Mar . 30 , 2021 - Gold : 0.029 BTC per ounce - SP500 : 0.067 BTC - Crude Oil : 102k sats per barrel HTTPURL',
#  'current #bitcoin price ( bitstamp ) is $ 225.52 , last changed Thu , 30 Apr 2015 00:07 : 50 GMT . queried at : 00:08 : 04',
#  "Iran Bitcoin Miners Set Up Shop in Mosques Amid Gov't Crackdown - HTTPURL Bitcoin Miners Set Up Shop in Mosques Amid Gov't Crackdown",
#  ':money_bag: #BTCOW . trade FREE TOKENS :money_bag: :four_leaf_clover: Get free 500 #BCO tokens worth 100 $ early birds only : HTTPURL ℹ️ Follow HTTPURL on Telegram HTTPURL and Twitter HTTPURL #AIRDROP #CRYPTO #BTC #FREE #BOUNTY #ICO',
#  '#Bitcoin morning TA . Good morning everyone ! Please see the thread below for an overview of all timeframes of the #BTC charts this morning ! Follow for regular updates ! Please like and retweet . See thread below :backhand_index_pointing_down: :backhand_index_pointing_down: :backhand_index_pointing_down: 1 ) Weekly : Back under the April H & S breakdown and ... HTTPURL',
#  '@USER @USER To the moon ? Or to the hell ? #BTC',
#  "MLB Club the Oakland A 's Is Now Accepting Bitcoin for 2021 Season Passes HTTPURL",
#  'Not Accepting # bitcoin ? 3 Entrepreneurs Share Why Youre Definitely Leaving Money On The HTTPURL',
#  'Both nchain bitcoin and core bitcoin are severely handicapped . The future looks very different and you know it . The best way rn to prepare the new edge is via nchain bitcoin , the best way to prepare the center is core bitcoin . HTTPURL',
#  '@USER Have u been to the Land Down under ? Where #bitcoin rules & bears wonder Do they hear , do they hear the thunder ? They better run :person_running: They better buy cover :chart_increasing: 🇦🇺 HTTPURL',
#  '#Bitcoin continues to recover from the fiasco in China mining , but price movement on the small volume market remains delicate . #CryptoNews HTTPURL',
#  "Willdigga found #bitcoin in a Blue vault at this location ! Join me playing #coinhuntworld , It 's awesome ! HTTPURL #cryptocurrency #3100451 HTTPURL",
# ...
#  '@USER Cause you say shit like crypto :rolling_on_the_floor_laughing: :rolling_on_the_floor_laughing: :rolling_on_the_floor_laughing: #bitcoin only',
#  "@USER @USER @USER NFT 's are making 100x gains while the market dips . Just food for thought :thinking_face:",
#  '@USER Not even 1 % , is your mind blown yet ? I will be ! #bitcoin #GoWithTheFlo $ Flo',
#  '@USER Redman is reppin @USER . Share this video ! Weed giveaways ! Our burn is insane ! We will burn it all until we all make 420 gains ! Launching on PCS this weekend ! #BluntDOGE #BSC #BNB #BTC #MiniDOGE #BabyDOGE #DOGE #DOGEFAMILY @USER @USER @USER @USER',
#  '@USER yes , but how do you feel Bitcoin helps DNS ?',
#  "@USER Cardano continuing growth today . Get in now , do n't be left behind if we 're left behind for Bitcoin . Shown % 150 growth this week already . I believe this is Crossing $ 2 soon",
#  'How to buy bitcoin for $ 50 HTTPURL via @USER',
#  'Btc price is on the floor now !',
#  'GET 0,7 % daily of ur invest though a AI bot of TELEGRAM = > Bitcoin Arbitrage . From 5 € / $ ONLY IN BTC Sing-up : HTTPURL TaekookersGoingToJilParty TaekookersGoingToJalParty',
#  '@USER @USER I would join your battles if i had etherium or bitcoin',
#  '@USER Prob going to peg it to Bitcoin',
#  ':megaphone: :megaphone: :megaphone: 1 BTC = 452,821 , 350 LBP Be Your Own Bank #Bitcoin',
#  "Digital cash is the ‘ killer feature ' in Satoshi white paper , says Bitcoin ABC 's Amaury Sechet ( via @USER ) #BCH #BitcoinCash HTTPURL pic.twitter.com/KoxCm9xoHW",
#  'New post in TA by Joy Bangla : The Bitcoin Buy / Sell Indicator V5 . 1.2 says to cover all SHORT position and open LONG position . It is receiving TD9 oversold on 1 hour timeframe for #bitcoin #XBTUSD $ BTCUSD $ BTC . Disclaimer : Please read the disclaimer at th ... HTTPURL',
#  '#bitcoin could get a higher B , but ideally we see $ 9235 before a larger bounce . HTTPURL',
#  '@USER @USER #Bitcoin #Ethereum I am your active retweeter and liker to your tweets . I am hoping to be the winer . And I will claim it . Thank you for Continue to help others . Godbless you and more power . HTTPURL',
#  '@USER @USER You compared bitcoin to democracy but I disagree , a crypto currency would be for the people and by the people if everyone had an equal say or control over it , but the rich and powerful would have even more power over the financial system',
#  "This is what a leverage flush out looks like . Do n't be so greedy ! ! ! Just hodl ! ! ! #BTCUSDT $ BTC #Ethereum #Chainlink $ ETH #cryptocurrency #ETH #BTC #Avalanche #AVAX #ETH #etherium #Cardano #Binance #Holo #holochai̇n #VeChain #Bitcoin #SHIB #Solana #USDT #Crypto #sandbox HTTPURL",
#  "@USER BITCOIN : The Future of Finance or Fool 's Gold ? HTTPURL via @USER",
#  "@USER Aim for . 00021 . 0021 . 021 . 21 2.1 21 This does n't happen overnight Time is your friend #Bitcoin",
#  ':money_bag: Join now for the latest stock market news and real time alerts . Link in bio :money_bag: #stocks #stockmarket #pennystocks #investing #stockstowatch #AMC #wallstreet #Investing #cryptocurrency #bitcoin $ KXIN $ BIOC $ NCTY $ SGOC $ AMC HTTPURL',
#  '#bitcoin Innovation For Traveling On Blockchain HTTPURL HTTPURL #bitcoin',
#  "How does Bitcoin stack up against the world 's three largest GDPs ? The market value of goods produced in China , the EU and the United States , respectively , are 75 , 104 and 113 times Bitcoin 's market cap . HTTPURL",
#  'Misconception : Full blocks mean bitcoin is failing #bitcoin today ! HTTPURL',
#  'Crypto is my job and I take lots of time to investigate various projects . This project is the most top-drawer in my rating . #Shato',
#  '#Altcoins Top Gainers [ Last 24 hrs ] 1 . $ HOT #Holo 34.4 % :rocket: :fire: 2 . $ GRT #TheGraph 10.83 % 3 . $ ZEC #Zcash 10.73 % Biggest losers [ BTD ] 1 . $ MANA #Decentraland -16.81 % 2 . $ CHZ #Chiliz -14.78 % 3 . $ ENJ #Enjin -13.53 % The market is Ranging #CRYPTO #ALTS #Bitcoin',
#  '$ HIVE is the Social #Bitcoin Few understand this .',
#  'Bitcoin Vaults to 18 - Month Highs on Growing Popularity HTTPURL',
#  "@USER @USER Bro the S & P 500 is only down like 18 % from ATH The S & P 500 could retrace 60 % worst case scenario IMO which would bring #BTC down to like 3k . Highly unlikely but possible . I 'm personally expecting a bounce from 10-14 k #BTC",
#  'i remember when twilight had us all fooled and had us thinking bella was dead then this btc opened her eyes and the damn movie ended .',
#  'BitBlockBarbeque #Bitcoin Meet up in #Dallas , #Texas . HTTPURL Scheduled for July 29th , see you there . HTTPURL',
#  '@USER This is typical garbage that leads to trash leaving FOX to go to OAN or Newsmax lol . Hydroxychloroquine is still not verified to help normal symptoms of Covid or even passed basic scientific studies outside small control groups . Bitcoin story is sad tho . Griftors going to grift .',
#  "@USER #SeasonalTokens #CryptoMining #CyclicalInvesting #BTC Thanks to the well-coordinated and constructive work of the team of professionals.This is most valuable project and clear roadmap project . It 's very legit team work project .",
#  "Holding BTC has been terrifying for the longest time . I can't imagine holding it right now . Wow ... Luckily , I have ZERO .",
#  '#Volume Bot : $ XMR 0.0084020 0 8.81 BTC at Minute 26 1.7 % of Daily Volume UTC Time : 11:26 : 15 Join us on Discord : HTTPURL HTTPURL',
#  'To buy pipemoon , download a trust wallet , HTTPURL ... ... get smart BNB #eth #btc #blockchain #bitcoin #crypto #ethereum #cryptocurrency #cripto #trading #criptomonedas #ico #ripple #cryptocurrencies #forex #emprendedores #dinero #litecoin #criptodivisas #bitcoincash HTTPURL',
#  'On Aquila we are seeing several # SMB small business # merchants liquidating their @USER coinbase # bitcoin holdings past 3 days . More # blood ?',
#  'MikEliseev ... can u do the #YFD #YFDFI community a solid and check out this gem ... #Bitcoin',
#  'Nothing to add but what Jack said ! $ BTCx @USER @USER @USER @USER @USER #BitcoinX #BTCx #XDCNetwork $ XDC #XDC #Bitcoin #BTC #Crypto #Cryptocurrency #Web3 #NFTCommunity #StakingRewards HTTPURL',
#  "John Paulson : â \x80 \x9c Donâ \x80 \x99 t invest in Bitcoinâ \x80 \x9d | CRYPTO The post John Paulson : “ Do n't invest in Bitcoin ” appeared on HTTPURL . #crypto HTTPURL #cryptocurrency #crypto #altseason #defi #enrichedfeed #smartcontracts #furucombo #dex #cex",
#  'I like this nice project . He has good ideas , and people who are actively working together to achieve common goals . #TeleFy #DeFi #DEX #cryptocurrency #ETH #BSC #BTC #Airdrop #polkadot #MATIC $ TELE #Cardano HTTPURL',
#  'IT Giant Fujitsu Is Planning to Deploy Multiple Blockchain Business Models - CoinDesk HTTPURL # blockchain # bitcoin',
#  'BUY THE DIP Retweet and viral this post to pump it #dogecoin #moon #BTC #BitMart #BUY #buythedips #ADAcardano #Wink #ElonMusk #czbinance #JustinSun #TRX #cryptocurrency #Crypto #cryptocrash #EthereumClassic #ethereum #shiba #SAFEMOON #SAFESPACE #crash #Bitcoin #dogearmy #khansir HTTPURL',
#  'Get FREE btc every day ! ! PTC + PTP + Bitcoin Cloud Mining + BTC Games # btc # bitcoin HTTPURL 65pic.twitter.com/OEM2HTOPgG',
#  '#My partner has been physically and verbally abusive ever since he moved in HTTPURL | SPONSORED BY : Browsermine . us - #New #Smart #Way #Get #Bitcoin #Free !',
#  'Daily #Bitcoin Thermometer : MVRV-Z : Market Value to Real . Value Z-Score SOPR : Spent Output Profit Ratio MC / TC : Market Cap / Thermoc . Ratio RHODL : Realized HODL Ratio Adj S2F : Adj Stock-to-Flow Follow to be informed about the upcoming tops . #BTC #LTC #ETH HTTPURL',
#  "@USER It would be so expensive I could n't even dream about affording a whole #Bitcoin . We 'd be talking about sats",
#  'Is Bitcoin Poised For Further Losses After Its Recent Drop ? - Forbes HTTPURL',
#  'The Hardware Bitcoin Wallet . Get Trezor now for only $ 99 HTTPURL # btc # bitcoin 07 pic.twitte',
#  'Hope there will be a support about here #bitcoin HTTPURL',
#  'Sword women series coming out in opensea ! 1/7 #women #sword #warrior #procreate #fantasy #swordwoman #digitalpainting #oilpainting #illustration #nft #eth #btc #nftcollector #NFTcommuity #opensea #cryptoartist #nftcollector #cryptoart #NFTartists HTTPURL',
#  'One Bitcoin now worth $ 10297.35 @USER . High $ 10383.200 . Low $ 10258.490 . Market Cap $ 184.696 Billion #bitcoin HTTPURL',
#  '#Bitcoin mining revenue jumps to its second-highest level ever , topping $ 1.72 billion in October #Bitcoin $ BTC $ ETH #altcoin #NFTNYC #NFTCommunity #NFTGiveaway #HODL #CryptoNews #cryptocurrency #Bitcoin #Polkastarter #Polkadot #Polkadex #nftcollector #NFTcollectibles #nftart HTTPURL',
#  'ALL IN ONE for BITSTAMP : BTCUSD by LegendaryTrader 1980 #BITCOIN HTTPURL HTTPURL',
#  "@USER @USER But one thing I do wonder , why is LN good for Bitcoin , can't better digital cash systems , you know one 's that are actually censorship resistant , like Monero , just use it and do away with the need for BTC at all ?",
#  'Current Bitcoin $ BTC price is ~ $ 10,305 . In the last 24 hours , the price has changed by -2.461 % . For more information please visit our website HTTPURL | #CCInet',
#  'Singapore suspends crypto exchange over spat with K-pop group BTS HTTPURL #cryptocurrency #cryptonews #cryptocurrencynews #bitcoin',
#  '@USER new picture is a #silver fork Also means " A Fork in the road " . By extension , the point at which one must make a decision between two or more drastically different choices or opportunities . ( #bitcoin vs #Doge ) ? HTTPURL',
#  'When will # bitcoins bloodletting cease ? Fundstrats Lee turns to the Bitcoin Misery Index for answers HTTPURL',
#  '@USER @USER @USER @USER A little Doge + A little Bitcoin = 1 AWESOME #cryptopill #Cryptopills by @USER',
#  '#XRP #XRPUSDT #XRPCommunity #XRPHolders #BTC Do not trade based on these charts . These are study illustrations . My expectation continues . HTTPURL HTTPURL',
#  'RT @USER : RT @USER : RT @USER : RT @USER : Ripple Price Analysis : XRP Price is Set to Shoot Up #XRPthestandard #XRP #XRPCommunity #eth #btc #bitcoin #Blockchain #eos #ltc #trx #xlm #neo #binance #BNB #ADA HTTPURL',
#  'Thanks for continuing to talk about and educate others on # bitcoin pic.twitter.com/nMVs6zOSQy',
#  'Bitcoin Set to Retain Its Five-Figure Valuation : DeVere CEO :right_arrow: ️https :/ / t.co/44zTNHmyLs :world_map: :play_button: ️https :/ / t.co/vdnO18c8ZC #last7daysnews #Bitcoin #blockchain #crypto HTTPURL',
#  'Did conflicting reports about Evergrande defaulting cause Bitcoin to tank ? HTTPURL',
#  'In the last hour , 7 people won 0.42 BTC playing Bitcoin lottery at HTTPURL , the easiest BTC lottery , 160BTC Jackpot',
#  'Some gold investors are looking at the digital gold #Bitcoin $ BTC while its price is expected to hit $ USD 100,000 by the end of 2021 , according to an anonymous investor @USER , known for his insights into the stock-to-flow ratio . HTTPURL',
#  '#Putin Tells Central Bank Not to Create Barriers to #Cryptocurrencies',
#  "HTTPURL #xrp #ripple #trx #btc #Hrithik And Abhishek Agree With Deepika Padukone That ' #AllSleepMatters ' - #Cricket #CricketWorldCup2019 - HTTPURL #Check out Deepika 's post and Hrithik and Abhishek 's comments below .",
#  '@USER thanks for your video on bitcoin and energy use . One thing to consider is that bitcoin mining can help marginal green energy projects become profitable . The money that can be made from bitcoin mining can enable more of these projects to go ahead .',
#  'Bitcoin Cash falls under 1.00 BTC for the first time since 50 days ago during the HTTPURL # Bitcoin',
#  '2/3 ) Has it woken people up ? No doubt . But one man is never going to bring down these assholes . #Bitcoin financially incentivises people to opt into a system that will defund these people . It gets at the very lifeblood which sustains them - their ability to print money .',
#  "@USER @USER so much for ur bitcoin vs silver theory , as bitcoin climbs back up by $ 10,500 today . Your gold and silver will stay in the same basic range it 's been in for the last 8 years , just wasting ppls time and $ $",
#  "@USER And you me friends too . All who cares . That 's why l have this for you . 5000 Bitcoin airdrop has just begun ! ! ! Join me :",
#  '#Bitcoin #BTC Fear Greed Index ( FEARGREED ) :chart_increasing: BULLISH indication Stock to Flow ( S2F ) :chart_increasing: BULLISH indication Relative Strength Index ( RSI ) :chart_increasing: BULLISH indication',
#  "#Bitcoin #BitcoinCrash it 's healthy for market to pullback , actually that 's when you should apply technical analysis so that you know which levels to buy the dip ! ! ! I like it when coins dips :OK_hand: . Blessings in disguise :money_bag: :money_bag: :money_bag: . HTTPURL",
#  'Ready to begin trading cryptocurrency ? Then you should definitely check out Coinigy ... Get a 30 day free trial when you sign up here - HTTPURL :',
#  '@USER great and strong project @USER @USER @USER #Airdrops #Sapa #SapaArmy #Bitcoin #BSC #BSCgem #BNB',
#  '@USER Whatsapp +17346660935 Are you interested in Forex trade and bitcoin ? Invest with us and get a better return in 3 hours ( GENUINE AND LICENSED COMPANY ) I can help you manage your account with the minimum of $ 500 assure you to get $ 5000 . Invest $ 600 and earn $ 6000 weekly .',
#  "@USER @USER Then you are 100 % welcome for my part in the ecosystem ... it 's holders like me who guarantee that bitcoin will never go below 3,000 USD again",
#  'HTTPURL # blockchain # bitcoin # fintech - Photo : FM The Waves blockchain platform is launching i HTTPURL',
#  "@USER The US Dollar is WORLD 's RESERVE CURRENCY as it is extremely stable and accepted around the world , in digital or cash transactions , & deposits are protected against loss in US Banks Bitcoin is a ( digital ) asset , highly volatile & subject to fraud ideal for Cartels and the darkweb",
#  '@USER BITCOIN FREESTYLE ( ALONE DESERT TIME by Twenty 2Eli on #SoundCloud HTTPURL',
#  'Please join the BTC Supporter Group ! HTTPURL 2019-08- 04T12 : 25:01 Z HTTPURL HTTPURL HTTPURL',
#  "Russian ZP Legal Claims They Can Recover Mt . Gox 's $ 2 Billion Lost in Bitcoin Hack HTTPURL",
#  'Rally caps baby . #Bitcoin bout to move',
#  'Crypto Prices ( USD / ₿ ) Bitcoin ➽ $ 61321.0337 ➶ BitcoinCash ➽ $ 596.0828 ➷ Polygon ➽ $ 1.9176 ➷ Filecoin ➽ $ 62.4918 ➶ Stellar ➽ $ 0.3689 ➷ Cosmos ➽ $ 37.3718 ➷ TRON ➽ $ 0.1032 ➷ #Crypto #Bitcoin #BitcoinCash #Polygon #Filecoin #Stellar #Cosmos #TRON',
#  'Nobel Prize Winning Economist Paul Krugman Expresses Skepticism About Crypto , Predicts Collapse HTTPURL #Bitcoin #Cryptocurrenciespic .twitter.com/tRffGoVwJz',
#  'Girlfriend will buy your groceries but wont buy bitcoin',
#  '@USER #securypto locked for a while only .. Actually germany always built their country and never ending .. #cryptocurrency #bitcoin #altcoin',
#  'Earn #btc with Bitkong and get 8 % interest on all #Winnings . Highly addictive ! fast payouts ! HTTPURL #bitcoin via bitkongme',
#  "JasL 15 found #bitcoin in a User vault in #Toronto #coinhuntroadtrip Join me playing #coinhuntworld , It 's awesome ! HTTPURL #cryptocurrency #32432 HTTPURL",
#  ':alarm_clock: LIQUIDATION on BTC - 28JUN19 :skull_and_crossbones: ️️ Bought $ 4,000 of #BTC @USER $ 13152.50 27 Jun 2019 00:10 : 43 UTC Trade ID : 2684871 7',
#  'Everything is down ~ 30 % . I guess its time to buy more # coins # CryptoCurrency # bitcoin # litecoin # ripple',
#  'Bitcoin And FinTech Technology Trends For 2016 # crypto # currency # fintech # bitcoin # mining HTTPURL',
#  'I hate that when a #bitcoin bull market starts taking off that actual #bitcoin websites that upload news articles start uploading stuff that damages sentiment . Like banks having new regulations for #crypto etc . They support Bitcoin but love reporting bad news . Makes no sense',
#  '# TheMerkle History of # Bitcoin in 500 words on @USER Steemit by @USER themerklenews HTTPURL',
#  ...]

# %%
def preprocess(text):
    text = text.translate(str.maketrans('', '', string.punctuation))  # Remove punctuation
    return text.lower()  # Convert text to lowercase

# %%
df['text'] = df['text'].apply(preprocess)  # Preprocess all texts

# %%
df["text"].to_list()
# Out:
# ['barchart interesting chart  we can clearly see how longterm holders been accumulating bitcoins during the summerautumn dump  at the moment total supply held by holders is at almost all time high  btc 100xgem cryptocurrencies hodl tothemoon httpurl',
#  'bitcoin s  elon musk pump  rally to  48k was exclusively driven by whales httpurl laranjal do elon',
#  'bitcoin over  50k this morning  is this the deadcatbounce that will go parabolic  yesterday   sq announced they purchased bitcoin  did tsla buy more in the 40s too  i continue to be bullish on bitcoin which is why i m bullish on  mara   riot   mstr  and  tsla ',
#  'who cares about china s ban on bitcoin  ca nt ban crypto  moving on ',
#  'bitcoin tries to take direction again  uparrow downarrow i think after some correction it will be up again   btc btc speechballoon',
#  'the  skyllz crew is creating the blockchain based and distributed skill validation platform to showcase track and boost human talents acro',
#  'saying bitcoin is nt real because it s not tangible is like saying the internet is nt real because you cant hold it   btc',
#  'user  shib the money making machinemoney  also a doge killer shibarmy doge uniswap cryptocurrencies ethereum bitcoin defi id shibaswap',
#  'this is a great project and good team user user user user user',
#  'user bitcoin getting really loud   5  87  million transactions  sizeable  41k 479 k  up   in the last 4 days  usa news ',
#  ' xapo refused to consider original  btc as real  bitcoin httpurl',
#  'blockchain btc crypto cryptocurrency bitcoin ethereum eth 11 the first blockchain platform to power sports bets via ethereum smart contracts  no book  no accounts  no odds  just p2p bets between fans of sports and cryptohttps   cryptosportzcom',
#  'rt user  collision usa needs to catch up to world on bitcoin and crypto regulation  shark tank s kevin oleary',
#  'fomo is going to eat ppl alive  doge dogecoin btc bitcoin httpurl',
#  'in my opinion it is the best project 2018  very strong team  big prospects  good luck to team  vita vitatoken ico bitcoin btc and cryptocurrency ',
#  'every day i become more and more a bitcoin maxi ',
#  'it is extremely hard to see the truth when you rule the world  you re just too busy ',
#  ' btc price   34694  £ 25592 2882 naks per usd 3907 naks per gbp  going up   one bitcoin  one million naks  simple as that  bitcoinprice satoshinakamoto 2201  2022 1825  00 gmt httpurl',
#  'on the 0804  2021 at 0402 1btc was worth  3793600 bitcoin crypto botcoinusd bitfinex',
#  'saquon barkley  star of new york giants switched endorsement payment to bitcoin httpurl httpurl',
#  'current bitcoin price  bitstamp  is  22200  last changed sat  18 apr 2015 1022  33 gmt  queried at  1022  40',
#  'top 1 signals  snt  possible decrease vc  12204  p 00000030300 to see more visit httpurl altcoins trading tradingview crypto pump signal  btc  eth  xrp  trx  eos httpurl',
#  'bsv better hold  140   145 this week bsv bitcoinsv bitcoin btc httpurl',
#  'rt user  magnifyingglasstiltedleft new airdrop  swords of blood heavydollarsign reward  up to 222 swdtkn    10   111k swdtkn    5k  referral pool redcircle start the airdrop ',
#  'user user he s right about the valuation model though facewithmonocle those applying oldworld financial models to bitcoin will crash and burn ',
#  'user because we believe in btc',
#  'new dcg report highlights confidence in asset tokenization and bitcoin as ‘ store of value  reported by httpurl    blockchain btc companies digitalcurrencygroup payments',
#  'another china fud  dog the state council of china  crack down on bitcoin mining and trading  and prevent individual risks transmitted to the social field  httpurl',
#  'user user user you can not stop phenomena like bluesparrow bluesparrow will take over the world the world and governments must adapt themselves with bluesparrow bluesparrow fire rocket charity bitcoin kyc renounce user hundredpoints httpurl',
#  'user apollo coin apx  listen to the ceo explain why apollo coin is going to exceed all expectations in the coming months  ',
#  'hellosaurus engineering extraordinaire user wrote a fantastic article about monkeys  bitcoin millionaires  workplace motivation  and more  it s a mustread downarrow downarrow downarrow httpurl',
#  'user user it s an amazing feeling to have lightning transactions from my phone controlling my own lightning node  add to that cold storage and  sorry what are banks for  cheap debt is about all i can think of',
#  'how to get paid in bitcoin httpurl via user twittercomvav47k2x1o',
#  'they have fear because bitcoin is already going to make them obsolete  httpurl httpurl',
#  'user i mentioned this earlier  if all you have access to is a disk drive containing the blockchain  how can you verify it is the valid one  with bitcoin  a fork would be noticed in a huge drop in hash power  but an entirely fake blockchain would be noticed by a very low hash power',
#  'blockchain browsers — how dlt could affect web surfing httpurl blockchain  android  ios  api  wallet  internet  opera  ethereum  cryptocurrencies  bitcoin',
#  'use my referral link httpurl to sign up for httpurl and we both get  25 usd  crypto crypto  com bitcoin',
#  'httpurl xrp ripple trx btc we toured disneyland s new star wars park  here s what we learned   cricket cricketworldcup2019  httpurl ',
#  'teenage homeschooler leverages  bitcoin millions to transform higher ed   homeschooling  cryptocurrencyhttp   bitcoinistcomteenagebitc',
#  'user  trezor stopped working on cashaddr  because it s done  cashaddr code is ready for the next release  httpurl',
#  'stop the waiting now people are getting paid  dm us today to learn how to invest in bitcoun and binary options trade envelopewitharrow 24hours trading 999  winning rate  bitcoin investing invest binarytrading optiontrading love instagood me dubai hongkong cute pioneer goodevening httpurl',
#  'trezor silicone protective cases in 5 colors  they have free worldwide shipping httpurl  reddit  bitcoin',
#  'xeraexchange verifies personal profiles and listings by blockchain technology  to put in the amount of the system is customers  referrers and friends can be made as reliable exchange crypto cryptocurrency btc eth blockchain altcoins technologyli ',
#  'user everyone see that btc is bullish again  i know private source with market analytics  and it is free for one week  look  httpurl heavylargecircle 2573552 35',
#  ' bitcoin current bitcoin price is 00004315 2 btc for  1 usd  goldcoinjar',
#  'bullish news is that bitcoin has reached wall street  bitcoin futures exchange bakkt will launch  btc custody for institutional clients on sept 6  trading on sept 23  bakkt is founded by ice  parent company of new york stock exchange  ca nt get bigger than that',
#  'well done and thanks for this great opportunity  this is an amazing project with good community am looking forward to  user user user airdrops bitcoin lottrade airdropdet crypto blockchain  lott httpurl',
#  'the current price of bitcoin is  5972200  the current price of bcash is  58928  or 00098670 5 btc  the current price of bcashsv is  16122  or 02735881 1 bcash ',
#  'rt user  user check us out  user trump2024 love him or hate him  these nfts will be priceless do nt miss out  trumpbackontwitt ',
#  '15  and for a broad  historical ranking in table format  for the entirety of bitcoin s history since 2009  that information is here  httpurl',
#  'user user user user user user user i think it will definitely do 100x',
#  'user user and shake off your peruvian hallucinogens  crypto is bigger than bitcoin ',
#  'user user user user user lol  he cant do shit  all he can do is to sell his bitcoin but he does nt have the balls ',
#  'i m exasperated that my friends and family seem to have no better understanding of bitcoin than they did in 2017  honestly do nt know if this is bearish or bullish ',
#  'alarmclock liquidation on btcperpetual skullandcrossbones ️️ bought  20 of btc user  873700 2 jun 2019 2236  45 utc trade id  2296281 1',
#  'bit fun  play games  have fun  earn bitcoin   httpurl  bitcoin faucet via user',
#  ' btc retested the 38600 support and quickly recovered flexedbiceps bitcoin  btc  eth crypto cryptocurrency altcoins technicalanalysis defi ビットコイン биткойн 比特币 httpurl',
#  'user user user bitcoin was created to revolutionize currency  you use it as a currency  start accepting it at your business if you have one  i offer my customers and tenants to pay with bitcoin usually at a discount relative to usd  httpurl',
#  'tesla can be bought with bitcoin hoping we d be able to buy this car with crypto too  speaking of cryptocurrency  earn a free share of 4k  trb tokens on latoken httpurl',
#  'it is extremely hard to see the truth when you rule the world  you re just too busy ',
#  'user user user httpurl is a great place to start   watch user youtube videos  what questions do you have ',
#  'here go bitcoin  another game changer httpurl',
#  'finally our ebook is online facescreaminginfear partypopper download it now on httpurl and take your investments to the next level clappinghands  btc alts bullrunpreparation httpurl',
#  'user when will we be able to buy and sell user and user on user  czbinance bnb btc ethereum vitalik user elonmusk mayemusk user user matic polygon user',
#  'it is extremely hard to see the truth when you rule the world  you re just too busy ',
#  'i want a book to read  help me  what will it be  the big reset or the great reset  willem vs klaus user user user thebigreset thegreatreset covid19 gold bitcoin books quote httpurl',
#  'user user user yep  tell me the partnerships bitcoin has with major players in the world of finance ',
#  'what percentage should you invest in each cryptocurrency to become a millionaire  a winning index strategy httpurl bitcoin crypto ethereum litecoin ripple eos httpurl',
#  'dash  usd and ltc  usd technical analysis may 30 2017 httpurl  bitcoin',
#  'user learned myself today as well  tried to get my feet wet in the market with  60 and failed  but i have never failed with bitcoin  decrentralization for the win ',
#  'this zesty faucet from user is making me tweet this to claim my free lightning sats  highvoltage user unlock me eb5fd996  376e  42cc  b7fa  ac10a9758c67 bitcoin btc ln lightningnetwork boltcoiner httpurl',
#  'bitcoin  btc  and ethereum  eth  morning price  — — — barchart top 17 altcoin price  barchart — — —  bank market cap   bitcoin dominance  24 hours volume  bank — — —  classicalbuilding top 6  httpurl',
#  'user user user user this is the best offer to make money on cryptocurrency user crypto bitcoin usdt exchange httpurl',
#  'bitcoin slides in worst weekly drop since march amid selloff httpurl',
#  'fbi requests new funding to investigate use of virtual currencies httpurl  bitcoin  currencies  fundingpictwittercomsdto',
#  ' long position suggested for bitcoin  current price   4608 algo name   05 s tracker algo group  httpurl accuracy  80  date  202110 14 0943  13077395 trade now  httpurl httpurl',
#  'but why on earth a country as this sheattle can go to the length of blocking its citizen way of hustling and meeting ends meet  when they cant produce anything for its citizen  dem no want make we dey sucessfull in this part of the world  ajeh bitcoin',
#  'my crypto strategy on iconomi just outperformed btc  check it out here  httpurl trading forextrader bitcoin cryptocurrencies httpurl',
#  'binance buyer volume alert stage 13  ignition fire name  bitcoin cash abc symbol   bchabc pair   btc price  ₿ 00529500 0 tradingview  httpurl hodloo  httpurl httpurl',
#  'nusd kucoin arbitrage opportunity rocket  1  sell  usdt for  dai  2  convert  dai to  nusd user httpurl  3  sell  nusd for  btc  4  sell  btc for  usdt  potential 061  profit  kucoin and user fees included   201906 27 2302  37  0000',
#  'i pay in bitcoin  dm ya wallet i ll send ya  10 user',
#  'user twisted scenario  the original xrp will die and stay dead  they ll release a new type of xrp token tied to btc energy  precious metals buttt  i do nt know if yall are ready to hear that full story so i ll keep it short  simple rollingonthefloorlaughing rollingonthefloorlaughing rollingonthefloorlaughing',
#  'user user user user bitcoin is still sitting at the  60k resistance building up for another push  bears cant seem to get hold to push it down  now i think 70k is a more likely target everyone should follow user tips and tweets i have been doing superb following her',
#  'user unv is digital gold on the exchange  you can trade  kbc  unv   btcunv   ethunv  and usdunv pairs ',
#  'user user user user dude the claim being made is that bitcoin fixes nk by magical trojan horse 12d chess  it does nt  it helps the current regime  what you said does nt strengthen a case that bitcoin fixes nk  you re just agreeing that it does nt ',
#  'altcoin bitcoin crypto news over  30 billion worth of ada now staked on cardano httpurl',
#  'invest in bitcoin and earn tremendous profits moneybag creditcard moneywithwings moneywithwings moneywithwings hundredpoints httpurl',
#  'user damn user knows how to buy the dip bitcoin',
#  'local ou virtuel largent change de visage httpurl',
#  'bitcoin mining could use more energy than all of italy by 2024  vice httpurl',
#  'user user just do nt buy bitcoin becouse i am sure that bitcoin is not going to hit 10x soon  buy  kishu this token have chance to hit 1000x or more moneywithwings rocket rocket rocket chartincreasing chartincreasing chartincreasing',
#  'btc price  455103   btc today high  455939   btc all time high  474242  eth price  31252  bitcoin btc  btc eth  ethpictwittercomuxipgimmo8',
#  'user user have you looked into getting bitcoin or litecoin',
#  'alert  bitcoin  btc  at euro 976459 decrease by 488  during the past hour  price  euro 976459 timestamp  1842  03 2706 2019  malta  europe  this is not financial advice  do your own research ',
#  'from parabolic price to ‘ ban bitcoin  politicians  past week s top stories rightarrow ️https   tcoho3pxboy5h worldmap playbutton ️https   tcovdno18c8zc newsoftheweek bitcoin blockchain crypto httpurl',
#  'have gotten my girlfriend into this “ virtual money ” followed by her father and her 14yr old sister  my girlfriend and her father now 1 month later are now dca with user  all started with sending  1 on lightning and watching it bitcoin',
#  'no wonder why it is hard to own a full bitcoin nowadays  1  btc would be the average net worth of american millennials  httpurl',
#  '“ if libra takes off we get a billion new crypto users that will eventually migrate somewhat into bitcoin and grow the whole ecosystem  if libra gets shut down  boom  now we know why bitcoin is so powerful as a global reserve currency  ” — brad stephens',
#  '3lwzf9osjsttanrqdfkwxa6pjirkunrbmgtp6eox3fcg eidmubarak2022 crypto cryptocurrency btc sol solanagiveaway airdropcrypto trending bulls i m a christian and this is my roomie and my best buddy though  i posted his eid pictures instead   one love yall flexedbiceps hundredpoints redheart httpurl httpurl',
#  'bitcoin hits new high as tesla reveals  15 bn investment httpurl httpurl',
#  'linkedin twitter facebook instagram tiktok giftshop socialmedia pinterest dogecoin deal gift gifts giftideas shop shopping affiliatemarketing bitcoin up to 15  off new products from amazon brands httpurl',
#  'can someone make a list about bollinger bands or some other technical analysis stuff that seems to never matter  it humors me  bitcoin',
#  'i know btc bitcoin is going hyper parabolic any time now to 20k  so every time i look at btc this is what i see digitalgold digitalassets crypto coinbase binance fidelity china xrpthestandard bitstamp bitmex xrp ripple xrpcommunity httpurl',
#  'get any of these for only 8500 naira size  3741 kindly retweet to order send a dm  call  whatsapp on 08082744728 bbnajia2019 nationalboyfriendsday europaleague worldathleticschamps jokermovie bitcoin bamlisaxais httpurl',
#  'rt user  magnifyingglasstiltedleft new airdrop  brightypad trophy airdrop pool  45 million byp    36000  redcircle start the airdrop bot httpurl radiobutton ',
#  'bitcoin market alert  policecarlight order balance  3259   buy  buy 6630   sell 3370  bid   55354318 ask   5535491 spread   0592',
#  'user user user user user i actually earn my bitcoin at this point  i could hold oranges  cars  houses but instead i hold bitcoin  i do this because its inf easier to secure my coins than it is to protect my wealth by storing it in houses or anything else ',
#  'are you a newbie on the binary bitcoin mining network or you already have bitcoin  do you know that you can mine bitcoin with the help of the bitmain mining hardware  yes your bitcoin can mine up to  2000 worth bitcoin in a day for 2weeks of connection',
#  'top 3 candidates for reversal for may 16 on user  1  bchabc  2  npxs  3  eos altcoins bitcoin bchabc npxs eos',
#  'user they just do nt see it our way yet  they will  in due course  learn to love waifu nft s  i mean bitcoin  bitcoin for sure ',
#  'i believe we are just in a reaccumulation phase and it could take some time to break to new yearly highs  more time and opportunities to stacksats beamingfacewithsmilingeyes beamingfacewithsmilingeyes bitcoin  btc httpurl',
#  'dont let  fud make your investment decisions  now is the time to  buythedip if youre investing for the long haul  stick to your portfolio',
#  'current price of  btc is  125159 via chain  bitcoin  btc',
#  'bitcoin price tags  50k for the first time since may chartincreasing httpurl btc crypto cryptocurrency user httpurl',
#  '6father raised his voice  you allowed your greed and sloth to waste the precious rewards  the devotion of others  wasted for many blocks  your unfairness is what causes those with envy and lust pursue you  mod88block bitcoin block  578248',
#  'there re number of ways to start a business for instance you can buy  sell bitcoin using top payment methods including paypal in ghana  receive and send physical or digital cash with over 7 million people just like you  sign up here  httpurl  start trading httpurl',
#  'buy bitcoin  trump says us ‘ should match  china s money printing game httpurl httpurl',
#  'duplicate successful traders automatically with bitcoin  i copy  wangzai 888   do you  httpurl talk about a great  simple  setandforget  income   iost   trx   wtc   elf   ocn   gnt   steem   ltc   nxt   eospictwittercompxhoge30az',
#  'new post   goldman sachs  bitcoin and other cryptocurrencies tend to be locked together — and that s a big problem  httpurl',
#  'praise satoshi another 10 bitcoin blocks have been found  be thankful for every block  block   579230 hash  00000000000 00000002 3e27e0dfb88a883c7128ded02ddb897077b439ff391e5 httpurl',
#  'user user this was solid  notes from the vallis  saylor podcast  “ gold is a corruptible monetary system because its centralized  its corruptible because it s an open system  it s a counter party risk because it s open  ”  saylor “ bitcoin is a decentralized  closed system  ”  saylor',
#  'user why is bitcoin in decline then  ',
#  'rt user  defipays bug hunting is ongoing  sign up  help clear the bugs and also get rewarded  sign up to check for bugs here  htt ',
#  'user  boring of user this project could allow any blockchain with smart contracts like ethereum to become a layer2 solution for bitcoin and make  btc and other assets programmable  boring boringdao user',
#  'worth adding  i m not an expert in trading  but i use mathematics and numerology  numbers are not charts  numbers are more accurate  bitcoin',
#  'bitcoin in a local head  shoulders btc has always corrected within 7 days of the technical setup created by the last pump  by the 13th   but whatever happenes  we end uptober way up uparrow httpurl',
#  'us lawmaker questions facebook s real intentions with libra rightarrow ️https   tcoe6yijwjzrx worldmap playbutton ️https   tcovdno18c8zc newsoftheweek bitcoin blockchain crypto httpurl',
#  'soi now have bitcoin  what a process but glad i have it  the only thing is  there s a waiting period or a limit on what you can spend  i ve learned quite a bit today  i m a naughty student though  i would love to show you my school girl naughtiness  httpurl httpurl',
#  'call  1021  19 1200 am type  cxday pair  btc  x   btc  x broker  coinbase candle  1h expectation  long  buy httpurl follow me for more free maxsignals and join us in the live room',
#  'btc has no overseer  bitcoin carries all the same advantages  disadvantages and dangers of cash  many other features outlined elsewheretreat it with the same care and caution  payitforward',
#  'disaster response training program  students  new graduates   rightarrow httpurl  agile scrum agile kanban projectmangement jobs hiring careers cryptocurrency blockchain btc bitcoin eth crypto httpurl',
#  'are you seriously not using the fold card  app yet  why the fuck are you turning down free sats   get with the program  sign up for the first bitcoin rewards card and get 5000 sats for using my referral link to sign up for fold  httpurl',
#  'great analysis crypto currency channel  join   httpurl  btc  xrp  ltc  eth  ada  xlm  xvg  trx  ocn  iost  ncash  storm  eos  neo  iota  cdt  dash  xem  ven  etc  gvt  lisk  omg  appc  mod  nebl  enj 5',
#  'bitcoin last price  21512 btc rocket daily indicators  • variation since 00h00  utc  01  • macd   macd line   2331  signal line   2525 ethereum last price  1246 eth • variation  027  • macd   macd line   178  signal line   213 crypto web3  23  131878',
#  'bitmain antminer t15 23 th  s bitcoin miner btc bch  psu in hand ready ship httpurl bitcoin crypto antminer bitmain',
#  'user user user bitcoin will always stand for the best in  of humanity  cbdc s and shitcoins  eth  will always be known for scams and surveillance of of its users ',
#  'out of trade long back  will wait and watch the btc move before reentering ',
#  'httpurl be at the start to secure you future',
#  'everything you need to know about bitcoin and cryptocurrency in hong kong is here in user httpurl',
#  'you can do cloud mining using this site httpurl mining dogemining trxmining btcmining money earnmoney register bitcoin ethereum btc eth 8098',
#  'one click to start mining cryptocurrencies together with  45k people   bitcoin httpurl  it',
#  'time to sell xlm for  00004174 9 btc in hitbtc date  201911 10 1215  57',
#  'customer service positions  entry level  new office opening   rightarrow httpurl  agile scrum agile kanban projectmangement jobs hiring careers cryptocurrency blockchain btc httpurl',
#  'wel wel  i just saw dr  l  baird explaining the evolution on btc to come  also the opinion today where c  lagarde  ecb  former itf  states that bitcoin is not so out of the woods on regulations as a majority seems to assume  i have zero doubt on xrp  both prefer that technology ',
#  'i will get acquainted at this icoproject and i will consider supporting them  i more than one hundred per cent sure that they will become successful  shato',
#  'is it safe to go straight from bittrex to bitpay when buying a game from steam  httpurl  reddit  bitcoin',
#  'shoppers can now use bitcoin and crypto to purchase personal care goods and medicine at pharmacy chain in venezuela httpurl',
#  'rt user  i shorted btc before going to sleep httpurl',
#  'just watched the khan academy video on proof of work httpurl  reddit  bitcoin',
#  'everyone knows the wife should get all the  bitcoin too ',
#  'this team offers conditions at a firstclass level  best product i ve ever experienced  shato',
#  'in terms of the nvt signal   btc has worked out its contradiction and reached the relative value of the network  watching  eyes  btcusd  xbt  xbtusd btc bitcoin crypto blockchain onchain barovirtual barovirtual httpurl',
#  'you should be taking this technology as seriously as you should have been taking the development of the internet in the early 1990  s crypto btc bitcoin bnb bsc cryptocurrency altcoins eth',
#  'check out blockchain events all over the world and get tickets with crypto on user  httpurl event conference  btc  eth',
#  'the money in your bank account does nt really belong to you  bitcoin crypto decoupling markets dollar httpurl',
#  'man i m so tired of bitcoin just wiping out all growth regularly',
#  'new crypto coins and tokens released  july 2021 httpurl via user bitcoin cryptocurrency blockchain best crypto earning sites  httpurl',
#  'analyst who predicted bitcoin bottom says it wo nt find new lows httpurl btc  market  trading  business',
#  'hiveex cryptocurrency landscape report declares bitcoin s winter is finally over  here s why httpurl via user',
#  'yes  god plays dice and thats the only thing he does httpurl  chille perth crowdfunding softbank equity neworleans itos stlouis miami moscow ardor minneapolis stlouis london melbourne bitcoin deals preicosale campaign abraaj itos forthworth httpurl',
#  'bitcoin  btc  smashes  8000 on the back of bakkt s bitcoin futures contract launch in july  httpurl',
#  'user wonderful project  this project is very good and this projector has a lot of attractions  so hopefully the project will be better in the future  user user user airdrops bsc crypto bitcoin vufifonance',
#  'imf warns against adoption of crypto as national currency crypto bitcoin cryptopostio httpurl',
#  'if only he had bought yahoo as early on as we are buying bitcoin httpurl',
#  ' bitcoin  miner new bitmain antminer t9 miner 115 th inhand  batch 1  165000 httpurl',
#  ' nexcf signs ar university deal with leading brand  mr  steak ” httpurl ad wsj nytimes reuters bloomberg thestreet forbes nasdaq ihubstockposts newyork business bitcoin cannabis weed marijuana cbd colorado latimes dispensary robbreport maga httpurl',
#  'user user user is nt it price of bitcoin times total supply  which is 188 m  how could that supply get thinner ',
#  'warning microbreakout  warning micropump   bybit  btcusd price  357205    • live streaming 247 rocket • only trade the breakouts  • try it in tradingview with a free trial httpurl bitcoin ethereum  btc  eth crypto',
#  'user user user oh look an antivax bitcoin boy  what a surprise',
#  'bitcoin sv s community experiences sour anniversary as death cross forms on bsv  usd httpurl httpurl',
#  ' bitcoin   bitcoin cash update 1013  cryptocurrency technical analysis httpurl  cryptocurrency  breaking  news  discus',
#  'some screenshots of today s payouts sent directly to my investors bitcoin wallets  dm for more information on bitcoin mining  bitcoincash httpurl',
#  'user happy new year  partypopper partypopper partypopper rocket do nt miss this really cool project  user syncarny sync binancesmartchain btc crypto defi altcoin happynewyear2022',
#  'imagine learning 12 words and taking your wealth away from the greedy claws of apparatchiks forever  crazy  certainly  possible  already for many years ',
#  ' bitcoin current bitcoin price is 00003982 2 btc for  1 usd  goldcoinjar  bitcoin  cryptocurrency  ethereum',
#  ' btc latest block info  block 673560 holds 2125 transactions for a total of 3551  81564 bitcoin including block reward  block size 1419  892 bytes',
#  'platinumcryptoacademy bitcoin cryptocurrency pancakeswap defi gain protocol announces changes in response to bot trading during presale httpurl',
#  'bitcoin daily  head of bitcoin escrow firm charged with stealing  7m httpurl httpurl',
#  'simply  the only thing i bought or sold today was purchasing more bitcoin   btc',
#  'bitcoin attacking the h1 ema 30 again  it has been rejected from this ema ever since we hit  52000  a close above could finally mean we look to break out of the htf channel again you should follow user he knows his stuff when it comes to btc  cryptocurrency thumbsup',
#  'bitcoin cash acceptance and community growth ramp up httpurl',
#  'some of my friends still have nt bought bitcoin 🤷🏼\u200d♂ httpurl',
#  'join us and earn 4x your  bitcoin with  bitcoinx 4 httpurl',
#  ' cryptocurrencies were supposed to replace the finance industry and instead they have replicated it   bitcoin  tezos',
#  'the bitcoin inflation rate briefly fell to 071  on 27  june  the lowest level in history  blocks will be mined slower when large volumes of hashpower come off the network  and prior to the difficulty adjusting down  estimated to be 276  on 3  july   live chart',
#  'the cocksuckers user built a cocksucking quantm computer  user and the elite gimps want to use it to break all proof of work crypto  bye bye btc ',
#  'bitcoin is beta version gold  revolting against precious metals a bad idea  claims crescat capital s otavio costa httpurl bitcoin btc cryptonews cryptocurrency gold',
#  'user hahahaha sucked into the shitcoin vortex  see you in a few years when you realise bitcoin is the only way ',
#  'doxxed wrote a page about httpurl  starstruck did you already read jt  if not  check it out here backhandindexpointingright httpurl rocket sya bnb flooztrade syahumanizecrypto  sya bitcoin crypto',
#  '376160 btc has been transfered to an unknown address 𝗦𝗲𝗻𝗱𝗲𝗿  3enqnqgygq1bjfrqejzlzmz13jwcfxpytg balance  000 btc 𝗥𝗲𝗰𝗶𝗲𝘃𝗲𝗿  3d8pww4tfyhxst3tlckf5ru9rjfxgnt63k balance  376160 btc',
#  'bitcoin forex crypto cryptocurrency deals affiliatemarketing gift shopping gifts onlineshopping bitcoin free shipping on purchases over  25 at amazon httpurl',
#  'user this project looks very interesting  i am shohid 123 interested and i will support this project until it is successful according to the plan good project user user user bitcoin airdrops airdropcrypto',
#  'bybit  btc whale   400000 worth of btcusd bought at  10515  0 1539  07 201907  15  yenbanknote yenbanknote yenbanknote wait until wall street gets in  to the moon ',
#  'user user user user your unregistered security master calvin literally told people to mine bitcoin and buy his unregistered security token with the profit  likely no miner took that advice because it s incredibly retarded ',
#  'user user true but everyone thought bitcoin was a joke at  006 too  someone used 10000 bitcoins to buy a pizza 10 years ago  poor soul  i ll gladly let a few thousand dollars sit in  doge  the potential reward outweighs the risk imo  crypto is the future ',
#  'btc uparrow ️️ 058  to aud  41458 rsi 3  worriedface overbought rsi 14  bearface bearish trajectory   41142 in 3 days  41233 in 14 days  41367 in 30 days httpurl',
#  'user why not just buy bitcoin in large amounts then  they can buy like the rest of the whales  pssht ',
#  'despite bitcoin price growth  queen s bank laughs off bitcoin httpurl',
#  'bitcoin is trading at a sweet price for those who want to long it  earn free crypto on user  elcash airdrop and later use it to trade tokens  httpurl ethereum latoken latokenapp',
#  'user user playing litecoin is stupid  privacy is messed up  cant rise  fall faster than anyone else  fans of litecoin also comforted themselves by saying that it was a dishwashing  bitcoin gold wright silver  what kind of cock stuff  cultists',
#  'most meaningful notes from all my scribbles today  “  to believe things not because she  should  but because she understands  ” thank you for bridging bitcoin with the western canon user bitcoin2021',
#  'canadas securekey to build a blockchain digital identity network with us grant httpurl httpurl  bit',
#  'user bitcoin bulls have had a good run so far during this uptober watching  60k  62k as the new resistance support user is a super underrated bitcoiner i ve been taking her tweets and tips seriously  i ve been doing extremely great follow her for more ta tips',
#  'grab yourself a 25  discount on all user cryptopay bitcoin debit cards  httpurl  bitcoin  cryptocurrencies',
#  'rt bitcoinagile  red stag casino  21 no deposit bonus code   bitcoin casino no deposit bonus pictwittercomc8h6l194v8 ',
#  'block 596630 hash  0x  00cd21bbba5106bec963f06334bc6044aa5d1c6263b3f4 size  022 mb  726761 wu  18  full txs  512 segwit spends  46  921 in → 1627 out out  in ratio  177 out value   5715  760  680 btc httpurl',
#  'check out defender of the blockchain s video  tiktok httpurl cryptoart crypto bitcoinnews bitcoin cryptocurency',
#  'what a weak dump  you got any more   btc  ltc  eth  link httpurl',
#  'full thanks to user as they have analysed this bitcoin crash so my funds does nt affected and i have not faced any type of losses they are absolutely amazing in tips  advices and everything relievedface btc crypto metaverse nft p',
#  'listen to this interesting interview with ian dawson ceo of user exchange  the future is now with zbx exchange  crypto bitcoin exchange httpurl',
#  ' neo is now worth  1336  046   and 00014106 2 btc  106   neo rightarrow httpurl',
#  'bitcoin iota chartanalysis as undervaluediota still is a slave of the bitcoin price here is a bitcoin analysis  hopefully we see a stable bitcoin price going up to pull iota to break out of his neutral sideways trend  httpurl',
#  'httpurl give a free nft  so take it fast bro fire fire fire 0xf8f96cdfaf6bc8f00c24d091cfa0389f65130052',
#  'sign up on the best crypto gambling website in the world  you will get a daily  weekly and monthly bonus  casino slots crypto betting eth btc gambling dice httpurl httpurl',
#  'bear signal  atvi   560  in market trading on httpurl rsi  540  atr  15 trade stocks bitcoin',
#  'buy crypto with your credit card  fast crypto exchange httpurl bitcoin btc eth xrp crypto 0736 httpurl',
#  ' bitcoin  news  coinbase deems european market insufficiently healthy to trade bitcoin cash httpurl',
#  'suddenly your views on btc become an excellent predictor of your views on  tlry or  tsla or immigration  how this coalesces is so chaotic and random as to defy prediction  but it does and it s all about ingroup  outgroup and tight internal correlations  this way  madness lies',
#  'user adds 14 new tokens and multiple new trading pairs to the convert  otc portal crypto cryptocurrency cryptocurrencies cryptotrading cryptocurency cryptoworld cryptotwitter forex bitcoin btc binance invest investing binancesmartchain  btc  bnb',
#  'user the next biggest bsc project   baby rocket user baby rocket is the  1 baby themed hyper defiationary token based on the binance smart chain  whiteheavycheckmark 3 rewards ethbnbbusd  every hour facewithopenmouth  whiteheavycheckmark dev private doxxed to marketing team whiteheavycheckmark telegram httpurl btc bnb crypto',
#  'nice to catch up with crypto ogs today over dinner  watched the cpi data move  eth and bitcoin prices',
#  'goldman sachs sees more price pain ahead for bitcoin httpurl ',
#  'user and he got a bitcoin',
#  'user user user nice project and congratulations to the team for their efforts and dedication and highly appreciated the visionary thought of the projector and it will create history crootball will go to moon smilingfacewith3hearts user crootball toto aksu infinixnote12 football bet btc',
#  'strategy  5010hl1h atr 20d  192733 26 may 2022 1100  02 utc counterclockwisearrowsbutton  none  2000  02 jst    301945 longentrytrigger  290970 lastprice  btc  usd    286055 shortentrytrigger btc  usd perpetual contract on bitmex',
#  'see user no doubt our boys will be part of the btc financialrevolution crypto httpurl',
#  'in the last 10 mins  there were arb opps spanning 19 exchange pair  s   yielding profits ranging between  000 and  34571 bitcoin btc',
#  'we cheer user buying  15 b bitcoin  less so for nexon s ¥ 11b   100m   fair enough  but consider the enormity of nonusd currencies sitting on balance sheets globally being replaced by  btc  is it likely  most have high inflation   or  ve rates  a wall of money awaits  bank waterwave dollarbanknote httpurl',
#  'doge  btc volume advance  dogecoin  doge  24h volume advances above 30 day average   doge  btc dogecoin fintech finance',
#  'i can add tennis scoring to that list  no idea how the how any of this works httpurl',
#  'bitcoin longs vs shorts there we go again  httpurl',
#  'user linking parallel worlds with collision bluesparrow globeshowingasiaaustralia globeshowingamericas ringedplanet fire bluesparrow fire for everyone bluesparrow bluesparrow to the moon crescentmoon bluesparrow bluesparrow bluesparrow user bitcoin crypto web3 smilingfacewithhearteyes smilingfacewithhearteyes smilingfacewithhearteyes fire fire 3',
#  'ox chartincreasing policecarlight ark invest ceo says impossible to shut down bitcoin — regulators will become more friendly over time – regulation bitcoin news  bitcoin news btc httpurl',
#  'bitcoin enters “ extreme fear ” territory following recent crash the bitcoin  btc  fear and greed index  a measure of the general outlook on btc  had entered “ extreme fear ” conditions for the first time since late june ',
#  'join all the blockchains together httpurl via user blockchain interoperable decentralized autonomous libonomy bitcoin',
#  'btc roaring  crypto is poised to change the financial system',
#  'user user okay  sell me on bitcoin  how do i know that it s value does nt stem purely from market speculation  specifically  given that there s no endpoint consumption use  as there is with commodities like gold or even fiat currency  usecase is taxes  ',
#  'user as you know  i am running for president  and to gain support  i have prepared an amazing promotion for you folks  the 500 bitcoin and 5000 ethereum mcafee cryptoextravaganza airdrop has just begun  read more  httpurl',
#  'remember  25 fees to send btc near the end of 2017  are we headed there again  httpurl',
#  'user vice article from 3 years ago really puts things into perspective  httpurl  bitcoin  crypto  throwback  perspective',
#  'user nope  nobody wants boomer rocks when they can have bitcoin  it s just superior in every way  boomers are going to learn a hard lesson when they try to dump their gold and there are no buyers ',
#  'full thanks toas they have analysed this bitcoin crash so my funds does nt affected and i have not faced any type of lossesthey are absolutely amazing in tips  advices and everything relievedface btc crypto metaverse nft smilingfacewithhearteyes smilingfacewithhearteyes',
#  'if bip 300 was integrated in 2014  vitalik buterin  gavin wood would of continued making impactful contributions to btc  bitcoin block size wars created by immoral lunatics severely stunted bitcoin layer 2  layer 3  and sidechains  bitcoin needs to soft fork  for endgame  bitcoin',
#  'daily dot  how ddos attacks knock your favorite websites offline httpurl news bitcoin btc bitcoin crypto news finte ',
#  'user over 101   profits within 2 hours from btc signal for free  telegram link  httpurl httpurl',
#  'user setup your free account now  httpurl automatic bitcome  get paid cash automatically from businesses all over the world every 60 minutes even while you sleep   get your free account now  httpurl crypto cryptocurrency bitcoin btc btc',
#  'where am i  where are you bitcoin  httpurl',
#  'bitcoin  is the bubble about to burst  httpurl',
#  'bitcoin touches over  16000 but most institutional investors believe it is an unsustainable bubble httpurl ',
#  'currently on round 10697 with 84100 participants  01006562 btc each ',
#  'bitcoin binance cz chinese mind set never change for dumps',
#  'if you are not ready to suffer  then go away  do nt expect to be a victorious general  to be successful  you must be ruthless  — —  us  soros cryptocurrency bitcoin ethereum investment venture shib future currency metaverse nft polygon polygonnft doge httpurl',
#  'bitcoin is trading sideways above the key level of  11000  the leading cryptocurrency is up 061  at  11730 according to the latest data from coin 360 at  read more  httpurl',
#  'user user user dogs cant fly but birds can rocket rocket bluesparrow collision fire crypto bitcoin eth bluesparrow bluesparrowtoken bluesparrowcommunity starstruck draw bestdrawtoken user httpurl 1',
#  'nice team good job',
#  'there is  trophy i chose the lucky cell and won 00000121 55 eth  my username  otkooooo betfurysuccess bitcoin staking',
#  'user wow 16m  only a fraction of that on bsc  httpurl nft nfts cryptoart cryptoartist digitalart digitalartist crypto art artist eth giveaway nftcommunity bsc binancesmartchain btc binance doge dogecoin ethereum bscgems',
#  'forex invest futures bitcoin s surge means smaller rivals may be due for rallies httpurl httpurl',
#  'my target directhit for btc is 30k now  ',
#  'bitcoin  a peertopeer electronic cash system httpurl june 28  2019 at 1258 pm cryptocurrency',
#  'bitcoin emergence as digital gold could lift price to  146000  says jpm httpurl httpurl',
#  ' ltc performing as expected  in my opinion we are at wave c  took profits at wave a  planning to short wave c  chart keeps indicating bearish divergance  ltc btc bitmex xbt user httpurl',
#  'currently on round 8348 with 79100 participants  01035544 1 btc each ',
#  'user user user user iou implies that it s like credit  but that s not what lbtc is  if you hold funds on liquid  they are cryptographically backed 11 with funds on the bitcoin network  but are in a smart contract  users have a few ways to convert lbtc to btc  basic trade  atomic swap  or pegout',
#  'there is bitcoin and  there is blockchain bs  httpurl  bitcoin  digitalnomadpictwittercomcgyiaq6skj',
#  'long  short btc changes with up to 100x leverage at primexbt  moneybag starstruck sign up immediately and trade your  50 into  5000  whiteheavycheckmark httpurl whiteheavycheckmark earn money even when btc is falling  chartdecreasing chartdecreasing  bloc   fat   loom   ekt   mco   kcs   rsr   inb   net   bsv httpurl',
#  'user one can take bitcoin to heaven but land is for generations to come  private key is not operational in heaven',
#  'user one of the strongest community s  pitmag announcement and pumping  we finish the zeros one by one   pit bscpitbull do nt mis it again policecarlight last change thanks to the spirit of the pitbull community  fire pitbull token user  pit bitcoin btc httpurl',
#  ' invest in binary options trade today and gain financial cryptonews bitcoinsallday btcc bitcoin dashcoin blockchain bitcoinasia bitcoinprogress bitcoincharts ether bitcoinwallet btcpics btc ico bitcoinbillionaire cryptocurrencies coinbase profit millions httpurl',
#  ' vlbio is the 1st global vehicle lifecycle  blockchain  stay tuned  ico starts on november 27  httpurl  eth  btc  ethereum  b',
#  'user user most people in the developed and even a very large percentage of the underdeveloped world have equality of opportunity to get involved with bitcoin  it is more nuanced than that  yes  but the argument stands regardless ',
#  'user you got one thing right  hodlers do nt want to spend their bitcoin  but that issue is solved with anyone having education on how to manage assets  hold the asset and borrow  robert kiyosaki  but the main solution is the actual bitcoin will never be spent ',
#  'i feel like hodl is being misappropriated by equity  meme coin groups  bitcoin',
#  'going to buy a few more btc l just because it ll be back at 10  soon lol',
#  'user i m willing to trade all my bitcoin for a little more ',
#  'bitcoin devours more electricity than many countries httpurl',
#  'pick a team  team 🅰️ team 🅱️  btc  eth  sol  ada  xrp  avax',
#  'video shows  10m chinese bitcoin mining farm in flames httpurl',
#  'june 10  zil news  if i put a stoploss on i ll get stopped out tonight  if i hold over night  btc will dump and drag zil down  if the news is not fb everyone will be disappointed and dump  if it is fb then everyone will dump because fb is dying  if i tether it will run hard ',
#  'priced in bitcoin mar  30  2021  gold  0029 btc per ounce  sp500  0067 btc  crude oil  102k sats per barrel httpurl',
#  'current bitcoin price  bitstamp  is  22552  last changed thu  30 apr 2015 0007  50 gmt  queried at  0008  04',
#  'iran bitcoin miners set up shop in mosques amid govt crackdown  httpurl bitcoin miners set up shop in mosques amid govt crackdown',
#  'moneybag btcow  trade free tokens moneybag fourleafclover get free 500 bco tokens worth 100  early birds only  httpurl ℹ️ follow httpurl on telegram httpurl and twitter httpurl airdrop crypto btc free bounty ico',
#  'bitcoin morning ta  good morning everyone  please see the thread below for an overview of all timeframes of the btc charts this morning  follow for regular updates  please like and retweet  see thread below backhandindexpointingdown backhandindexpointingdown backhandindexpointingdown 1  weekly  back under the april h  s breakdown and  httpurl',
#  'user user to the moon  or to the hell  btc',
#  'mlb club the oakland a s is now accepting bitcoin for 2021 season passes httpurl',
#  'not accepting  bitcoin  3 entrepreneurs share why youre definitely leaving money on the httpurl',
#  'both nchain bitcoin and core bitcoin are severely handicapped  the future looks very different and you know it  the best way rn to prepare the new edge is via nchain bitcoin  the best way to prepare the center is core bitcoin  httpurl',
#  'user have u been to the land down under  where bitcoin rules  bears wonder do they hear  do they hear the thunder  they better run personrunning they better buy cover chartincreasing 🇦🇺 httpurl',
#  'bitcoin continues to recover from the fiasco in china mining  but price movement on the small volume market remains delicate  cryptonews httpurl',
#  'willdigga found bitcoin in a blue vault at this location  join me playing coinhuntworld  it s awesome  httpurl cryptocurrency 3100451 httpurl',
#  'user  10000 crypto giveaway i pray this time it s my turn to win foldedhands thanks for being a gem user  keep changing lives and god will reward you massively hundredpoints bsc bnb btc eth airdrop nft babydogecoin binance nftcommunity 1000xgem httpurl httpurl',
#  'user user the last time bitcoin marked a death cross in march 2020 proved no impediment to turned higher and formed a golden cross  so let s see',
#  'user the project is great and this projector has a strong team  so hopefully the project will be better in the future and the cryptocurrency will be the best  user user user airdrops vdf airdropdetective bsc bitcoin',
#  'user its because craig created bitcoin  satoshi is not a real person ',
#  'user user which means  provided there is no bear market  we will reach  1mm price per bitcoin by the end of summer  should we stockpile on bitcoin asap ',
#  'origami frog in magical book nfts nft nftart nftcommunity nftcollector nftartist cryptoart digitalart art crypto ethereum blockchain opensea nftcollectors bitcoin cryptocurrency nftdrop cryptoartist nftcollectibles openseanft nftartists eth artist nftcolle httpurl',
#  'greatness is is within user doubleexclamationmark ️transparent devs  bullish community unbelievable tokenomics doubleexclamationmark gemstone policecarlight join this gem gemstone globewithmeridians httpurl  cphx weburnwerise crypto cryptocurency bitcoin eth cryptocurrencies altcoins altcoin httpurl',
#  'user user i want my money back now  i do nt want to hold this turd for years just to be lucky to break even  bitcoin is soaring   how do you sleep at night  probably on a pillow stuffed with our   ',
#  'btc  bitcoin community  is it just me  or is the hardest part about being in the cryptoverse is just trying to get friends and family to see what you see and rethink their relationship with their finances  looking forward to a friendly discussion  be well  httpurl',
#  'bitcoin news   bitmain antminer d3 15 gh  s with apw 3   power supply ny bitcoin miner free ship  httpurl',
#  'said no to bitcoin and ethereum these two are great for money laundering and are currently used on black market  for nefarious reasons waste to much energy not transparent doesnt scale lacks liquidity prone to 51  attack 80   mined in china centrally controlled',
#  'user user bitcoin is on the rise chartincreasing barchart chartincreasing invest now and make massive profits visit  httpurl whiteheavycheckmark paying 100  whiteheavycheckmark automatic withdrawal whiteheavycheckmark 5  referral bonus whiteheavycheckmark 247 online customer support center register here freebutton backhandindexpointingdown backhandindexpointingdown backhandindexpointingdown httpurl httpurl',
#  'this is a wonderful projectstarstruck  i hope this project will be successful in future rocketrocket user user user crypto breezecoin bitcoin blockchain brze httpurl',
#  'there is a ton of volume coming into crypto and there is nt a thing you or your friends can do about it  httpurl',
# ...
#  ' playslots with  bitcoin  get 1  free  btc  t  cs apply at httpurl',
#  'wild crypto unveils new mascot monster httpurl  bitcoin uasociolog',
#  'con · vic · tion  kənˈviksh  ə  n   a firmly held belief or opinion  bitcoin btc crypto',
#  'major cryptocurrency latest prices  07  jun 1620   bitcoin  btc   7990  71 usd  ethereum  eth   24949 usd  xrp  xrp   042 usd  bitcoin cash  bch   40129 usd  litecoin  ltc   11664 usd learn more  httpurl cryptocurrency bitcoin',
#  'coinbase reportedly in advanced talks to acquire xapo s crypto custody business httpurl cryptocurrency bitcoin crypto blockchain ethereum btc money forex bitcoinmining trading cryptonews investing investment eth litecoin business investor bitco ',
#  'mark cuban talks about the future of tv httpurl   user user user tvrevolution crypto cryptocurrencies bitcoin ethereum blockchain fintech ico tvtwo  ttv  crypto',
#  'user what do you think guys  httpurl',
#  'let s check on dogearmy dogecoin hit alike if you think doge is going to hit  05 tonight and also get your customised wallet address for doge with vanitytoken vny shiba safemoonwallet babydoge binance bitcoin coinmarketcap eth',
#  'user cause you say shit like crypto rollingonthefloorlaughing rollingonthefloorlaughing rollingonthefloorlaughing bitcoin only',
#  'user user user nft s are making 100x gains while the market dips  just food for thought thinkingface',
#  'user not even 1   is your mind blown yet  i will be  bitcoin gowiththeflo  flo',
#  'user redman is reppin user  share this video  weed giveaways  our burn is insane  we will burn it all until we all make 420 gains  launching on pcs this weekend  bluntdoge bsc bnb btc minidoge babydoge doge dogefamily user user user user',
#  'user yes  but how do you feel bitcoin helps dns ',
#  'user cardano continuing growth today  get in now  do nt be left behind if we re left behind for bitcoin  shown  150 growth this week already  i believe this is crossing  2 soon',
#  'how to buy bitcoin for  50 httpurl via user',
#  'btc price is on the floor now ',
#  'get 07  daily of ur invest though a ai bot of telegram   bitcoin arbitrage  from 5 €   only in btc singup  httpurl taekookersgoingtojilparty taekookersgoingtojalparty',
#  'user user i would join your battles if i had etherium or bitcoin',
#  'user prob going to peg it to bitcoin',
#  'megaphone megaphone megaphone 1 btc  452821  350 lbp be your own bank bitcoin',
#  'digital cash is the ‘ killer feature  in satoshi white paper  says bitcoin abc s amaury sechet  via user  bch bitcoincash httpurl pictwittercomkoxcm9xohw',
#  'new post in ta by joy bangla  the bitcoin buy  sell indicator v5  12 says to cover all short position and open long position  it is receiving td9 oversold on 1 hour timeframe for bitcoin xbtusd  btcusd  btc  disclaimer  please read the disclaimer at th  httpurl',
#  'bitcoin could get a higher b  but ideally we see  9235 before a larger bounce  httpurl',
#  'user user bitcoin ethereum i am your active retweeter and liker to your tweets  i am hoping to be the winer  and i will claim it  thank you for continue to help others  godbless you and more power  httpurl',
#  'user user you compared bitcoin to democracy but i disagree  a crypto currency would be for the people and by the people if everyone had an equal say or control over it  but the rich and powerful would have even more power over the financial system',
#  'this is what a leverage flush out looks like  do nt be so greedy    just hodl    btcusdt  btc ethereum chainlink  eth cryptocurrency eth btc avalanche avax eth etherium cardano binance holo holochai̇n vechain bitcoin shib solana usdt crypto sandbox httpurl',
#  'user bitcoin  the future of finance or fool s gold  httpurl via user',
#  'user aim for  00021  0021  021  21 21 21 this does nt happen overnight time is your friend bitcoin',
#  'moneybag join now for the latest stock market news and real time alerts  link in bio moneybag stocks stockmarket pennystocks investing stockstowatch amc wallstreet investing cryptocurrency bitcoin  kxin  bioc  ncty  sgoc  amc httpurl',
#  'bitcoin innovation for traveling on blockchain httpurl httpurl bitcoin',
#  'how does bitcoin stack up against the world s three largest gdps  the market value of goods produced in china  the eu and the united states  respectively  are 75  104 and 113 times bitcoin s market cap  httpurl',
#  'misconception  full blocks mean bitcoin is failing bitcoin today  httpurl',
#  'crypto is my job and i take lots of time to investigate various projects  this project is the most topdrawer in my rating  shato',
#  'altcoins top gainers  last 24 hrs  1   hot holo 344  rocket fire 2   grt thegraph 1083  3   zec zcash 1073  biggest losers  btd  1   mana decentraland 1681  2   chz chiliz 1478  3   enj enjin 1353  the market is ranging crypto alts bitcoin',
#  ' hive is the social bitcoin few understand this ',
#  'bitcoin vaults to 18  month highs on growing popularity httpurl',
#  'user user bro the s  p 500 is only down like 18  from ath the s  p 500 could retrace 60  worst case scenario imo which would bring btc down to like 3k  highly unlikely but possible  i m personally expecting a bounce from 1014 k btc',
#  'i remember when twilight had us all fooled and had us thinking bella was dead then this btc opened her eyes and the damn movie ended ',
#  'bitblockbarbeque bitcoin meet up in dallas  texas  httpurl scheduled for july 29th  see you there  httpurl',
#  'user this is typical garbage that leads to trash leaving fox to go to oan or newsmax lol  hydroxychloroquine is still not verified to help normal symptoms of covid or even passed basic scientific studies outside small control groups  bitcoin story is sad tho  griftors going to grift ',
#  'user seasonaltokens cryptomining cyclicalinvesting btc thanks to the wellcoordinated and constructive work of the team of professionalsthis is most valuable project and clear roadmap project  it s very legit team work project ',
#  'holding btc has been terrifying for the longest time  i cant imagine holding it right now  wow  luckily  i have zero ',
#  'volume bot   xmr 00084020 0 881 btc at minute 26 17  of daily volume utc time  1126  15 join us on discord  httpurl httpurl',
#  'to buy pipemoon  download a trust wallet  httpurl   get smart bnb eth btc blockchain bitcoin crypto ethereum cryptocurrency cripto trading criptomonedas ico ripple cryptocurrencies forex emprendedores dinero litecoin criptodivisas bitcoincash httpurl',
#  'on aquila we are seeing several  smb small business  merchants liquidating their user coinbase  bitcoin holdings past 3 days  more  blood ',
#  'mikeliseev  can u do the yfd yfdfi community a solid and check out this gem  bitcoin',
#  'nothing to add but what jack said   btcx user user user user user bitcoinx btcx xdcnetwork  xdc xdc bitcoin btc crypto cryptocurrency web3 nftcommunity stakingrewards httpurl',
#  'john paulson  â \x80 \x9c donâ \x80 \x99 t invest in bitcoinâ \x80 \x9d  crypto the post john paulson  “ do nt invest in bitcoin ” appeared on httpurl  crypto httpurl cryptocurrency crypto altseason defi enrichedfeed smartcontracts furucombo dex cex',
#  'i like this nice project  he has good ideas  and people who are actively working together to achieve common goals  telefy defi dex cryptocurrency eth bsc btc airdrop polkadot matic  tele cardano httpurl',
#  'it giant fujitsu is planning to deploy multiple blockchain business models  coindesk httpurl  blockchain  bitcoin',
#  'buy the dip retweet and viral this post to pump it dogecoin moon btc bitmart buy buythedips adacardano wink elonmusk czbinance justinsun trx cryptocurrency crypto cryptocrash ethereumclassic ethereum shiba safemoon safespace crash bitcoin dogearmy khansir httpurl',
#  'get free btc every day   ptc  ptp  bitcoin cloud mining  btc games  btc  bitcoin httpurl 65pictwittercomoem2htopgg',
#  'my partner has been physically and verbally abusive ever since he moved in httpurl  sponsored by  browsermine  us  new smart way get bitcoin free ',
#  'daily bitcoin thermometer  mvrvz  market value to real  value zscore sopr  spent output profit ratio mc  tc  market cap  thermoc  ratio rhodl  realized hodl ratio adj s2f  adj stocktoflow follow to be informed about the upcoming tops  btc ltc eth httpurl',
#  'user it would be so expensive i could nt even dream about affording a whole bitcoin  we d be talking about sats',
#  'is bitcoin poised for further losses after its recent drop   forbes httpurl',
#  'the hardware bitcoin wallet  get trezor now for only  99 httpurl  btc  bitcoin 07 pictwitte',
#  'hope there will be a support about here bitcoin httpurl',
#  'sword women series coming out in opensea  17 women sword warrior procreate fantasy swordwoman digitalpainting oilpainting illustration nft eth btc nftcollector nftcommuity opensea cryptoartist nftcollector cryptoart nftartists httpurl',
#  'one bitcoin now worth  1029735 user  high  10383200  low  10258490  market cap  184696 billion bitcoin httpurl',
#  'bitcoin mining revenue jumps to its secondhighest level ever  topping  172 billion in october bitcoin  btc  eth altcoin nftnyc nftcommunity nftgiveaway hodl cryptonews cryptocurrency bitcoin polkastarter polkadot polkadex nftcollector nftcollectibles nftart httpurl',
#  'all in one for bitstamp  btcusd by legendarytrader 1980 bitcoin httpurl httpurl',
#  'user user but one thing i do wonder  why is ln good for bitcoin  cant better digital cash systems  you know one s that are actually censorship resistant  like monero  just use it and do away with the need for btc at all ',
#  'current bitcoin  btc price is   10305  in the last 24 hours  the price has changed by 2461   for more information please visit our website httpurl  ccinet',
#  'singapore suspends crypto exchange over spat with kpop group bts httpurl cryptocurrency cryptonews cryptocurrencynews bitcoin',
#  'user new picture is a silver fork also means  a fork in the road   by extension  the point at which one must make a decision between two or more drastically different choices or opportunities   bitcoin vs doge   httpurl',
#  'when will  bitcoins bloodletting cease  fundstrats lee turns to the bitcoin misery index for answers httpurl',
#  'user user user user a little doge  a little bitcoin  1 awesome cryptopill cryptopills by user',
#  'xrp xrpusdt xrpcommunity xrpholders btc do not trade based on these charts  these are study illustrations  my expectation continues  httpurl httpurl',
#  'rt user  rt user  rt user  rt user  ripple price analysis  xrp price is set to shoot up xrpthestandard xrp xrpcommunity eth btc bitcoin blockchain eos ltc trx xlm neo binance bnb ada httpurl',
#  'thanks for continuing to talk about and educate others on  bitcoin pictwittercomnmvs6zosqy',
#  'bitcoin set to retain its fivefigure valuation  devere ceo rightarrow ️https   tco44ztnhmyls worldmap playbutton ️https   tcovdno18c8zc last7daysnews bitcoin blockchain crypto httpurl',
#  'did conflicting reports about evergrande defaulting cause bitcoin to tank  httpurl',
#  'in the last hour  7 people won 042 btc playing bitcoin lottery at httpurl  the easiest btc lottery  160btc jackpot',
#  'some gold investors are looking at the digital gold bitcoin  btc while its price is expected to hit  usd 100000 by the end of 2021  according to an anonymous investor user  known for his insights into the stocktoflow ratio  httpurl',
#  'putin tells central bank not to create barriers to cryptocurrencies',
#  'httpurl xrp ripple trx btc hrithik and abhishek agree with deepika padukone that  allsleepmatters   cricket cricketworldcup2019  httpurl check out deepika s post and hrithik and abhishek s comments below ',
#  'user thanks for your video on bitcoin and energy use  one thing to consider is that bitcoin mining can help marginal green energy projects become profitable  the money that can be made from bitcoin mining can enable more of these projects to go ahead ',
#  'bitcoin cash falls under 100 btc for the first time since 50 days ago during the httpurl  bitcoin',
#  '23  has it woken people up  no doubt  but one man is never going to bring down these assholes  bitcoin financially incentivises people to opt into a system that will defund these people  it gets at the very lifeblood which sustains them  their ability to print money ',
#  'user user so much for ur bitcoin vs silver theory  as bitcoin climbs back up by  10500 today  your gold and silver will stay in the same basic range it s been in for the last 8 years  just wasting ppls time and  ',
#  'user and you me friends too  all who cares  that s why l have this for you  5000 bitcoin airdrop has just begun    join me ',
#  'bitcoin btc fear greed index  feargreed  chartincreasing bullish indication stock to flow  s2f  chartincreasing bullish indication relative strength index  rsi  chartincreasing bullish indication',
#  'bitcoin bitcoincrash it s healthy for market to pullback  actually that s when you should apply technical analysis so that you know which levels to buy the dip    i like it when coins dips okhand  blessings in disguise moneybag moneybag moneybag  httpurl',
#  'ready to begin trading cryptocurrency  then you should definitely check out coinigy  get a 30 day free trial when you sign up here  httpurl ',
#  'user great and strong project user user user airdrops sapa sapaarmy bitcoin bsc bscgem bnb',
#  'user whatsapp 17346660935 are you interested in forex trade and bitcoin  invest with us and get a better return in 3 hours  genuine and licensed company  i can help you manage your account with the minimum of  500 assure you to get  5000  invest  600 and earn  6000 weekly ',
#  'user user then you are 100  welcome for my part in the ecosystem  it s holders like me who guarantee that bitcoin will never go below 3000 usd again',
#  'httpurl  blockchain  bitcoin  fintech  photo  fm the waves blockchain platform is launching i httpurl',
#  'user the us dollar is world s reserve currency as it is extremely stable and accepted around the world  in digital or cash transactions   deposits are protected against loss in us banks bitcoin is a  digital  asset  highly volatile  subject to fraud ideal for cartels and the darkweb',
#  'user bitcoin freestyle  alone desert time by twenty 2eli on soundcloud httpurl',
#  'please join the btc supporter group  httpurl 201908 04t12  2501 z httpurl httpurl httpurl',
#  'russian zp legal claims they can recover mt  gox s  2 billion lost in bitcoin hack httpurl',
#  'rally caps baby  bitcoin bout to move',
#  'crypto prices  usd  ₿  bitcoin ➽  613210337 ➶ bitcoincash ➽  5960828 ➷ polygon ➽  19176 ➷ filecoin ➽  624918 ➶ stellar ➽  03689 ➷ cosmos ➽  373718 ➷ tron ➽  01032 ➷ crypto bitcoin bitcoincash polygon filecoin stellar cosmos tron',
#  'nobel prize winning economist paul krugman expresses skepticism about crypto  predicts collapse httpurl bitcoin cryptocurrenciespic twittercomtrffgovwjz',
#  'girlfriend will buy your groceries but wont buy bitcoin',
#  'user securypto locked for a while only  actually germany always built their country and never ending  cryptocurrency bitcoin altcoin',
#  'earn btc with bitkong and get 8  interest on all winnings  highly addictive  fast payouts  httpurl bitcoin via bitkongme',
#  'jasl 15 found bitcoin in a user vault in toronto coinhuntroadtrip join me playing coinhuntworld  it s awesome  httpurl cryptocurrency 32432 httpurl',
#  'alarmclock liquidation on btc  28jun19 skullandcrossbones ️️ bought  4000 of btc user  1315250 27 jun 2019 0010  43 utc trade id  2684871 7',
#  'everything is down  30   i guess its time to buy more  coins  cryptocurrency  bitcoin  litecoin  ripple',
#  'bitcoin and fintech technology trends for 2016  crypto  currency  fintech  bitcoin  mining httpurl',
#  'i hate that when a bitcoin bull market starts taking off that actual bitcoin websites that upload news articles start uploading stuff that damages sentiment  like banks having new regulations for crypto etc  they support bitcoin but love reporting bad news  makes no sense',
#  ' themerkle history of  bitcoin in 500 words on user steemit by user themerklenews httpurl',
#  ...]

# %%
def preprocess_text(text):
    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Convert to lowercase and remove extra spaces
    text = text.lower().strip()
    text = re.sub(r'\s+', ' ', text)
    return text

# %%
df['text'] = df['text'].apply(preprocess_text)  # Preprocess all texts

# %%
# Load the spaCy model (make sure to install it first: python -m spacy download en_core_web_sm)
nlp = spacy.load("en_core_web_sm")

# %%
def nlp_preprocess(text):
    doc = nlp(text)

    # Remove tokens that are recognized as dates, times, or cardinal numbers
    filtered_tokens = [token.text for token in doc if token.ent_type_ not in {"DATE", "TIME", "CARDINAL", "MONEY", "PERCENT", "QUANTITY", "ORDINAL"}]

    # Reconstruct the cleaned text
    return " ".join(filtered_tokens)

# %%
df['text'] = df['text'].progress_apply(nlp_preprocess)  # Preprocess all texts
# Out:
# 100%|██████████| 129991/129991 [13:00<00:00, 166.62it/s]

# %%
df["text"].to_list()
# Out:
# ['barchart interesting chart we can clearly see how longterm holders been accumulating bitcoins during the summerautumn dump at the moment total supply held by holders is at almost all time high btc xgem cryptocurrencies hodl tothemoon httpurl',
#  'bitcoin s elon musk pump rally to k was exclusively driven by whales httpurl laranjal do elon',
#  'bitcoin over k is this the deadcatbounce that will go parabolic sq announced they purchased bitcoin did tsla buy more in the s too i continue to be bullish on bitcoin which is why i m bullish on mara riot mstr and tsla',
#  'who cares about china s ban on bitcoin ca nt ban crypto moving on',
#  'bitcoin tries to take direction again uparrow downarrow i think after some correction it will be up again btc btc speechballoon',
#  'the skyllz crew is creating the blockchain based and distributed skill validation platform to showcase track and boost human talents acro',
#  'saying bitcoin is nt real because it s not tangible is like saying the internet is nt real because you ca nt hold it btc',
#  'user shib the money making machinemoney also a doge killer shibarmy doge uniswap cryptocurrencies ethereum bitcoin defi i d shibaswap',
#  'this is a great project and good team user user user user user',
#  'user bitcoin getting really loud transactions sizeable k k up in news',
#  'xapo refused to consider original btc as real bitcoin httpurl',
#  'blockchain btc crypto cryptocurrency bitcoin ethereum eth the blockchain platform to power sports bets via ethereum smart contracts no book no accounts no odds just pp bets between fans of sports and cryptohttps cryptosportzcom',
#  'rt user collision usa needs to catch up to world on bitcoin and crypto regulation shark tank s kevin oleary',
#  'fomo is going to eat ppl alive doge dogecoin btc bitcoin httpurl',
#  'in my opinion it is the best project very strong team big prospects good luck to team vita vitatoken ico bitcoin btc and cryptocurrency',
#  'every day i become more and more a bitcoin maxi',
#  'it is extremely hard to see the truth when you rule the world you re just too busy',
#  'btc price naks per usd naks per gbp going up bitcoin naks simple as that bitcoinprice satoshinakamoto gmt httpurl',
#  'on the at btc was worth bitcoin crypto botcoinusd bitfinex',
#  'saquon barkley star of new york giants switched endorsement payment to bitcoin httpurl httpurl',
#  'current bitcoin price bitstamp is last changed sat apr gmt queried at',
#  'top signals snt possible decrease vc p to see more visit httpurl altcoins trading tradingview crypto pump signal btc eth xrp trx eos httpurl',
#  'bsv better hold bsv bitcoinsv bitcoin btc httpurl',
#  'rt user magnifyingglasstiltedleft new airdrop swords of blood heavydollarsign reward up to swdtkn k swdtkn k referral pool redcircle start the airdrop',
#  'user user he s right about the valuation model though facewithmonocle those applying oldworld financial models to bitcoin will crash and burn',
#  'user because we believe in btc',
#  'new dcg report highlights confidence in asset tokenization and bitcoin as store of value reported by httpurl blockchain btc companies digitalcurrencygroup payments',
#  'another china fud dog the state council of china crack down on bitcoin mining and trading and prevent individual risks transmitted to the social field httpurl',
#  'user user user you can not stop phenomena like bluesparrow bluesparrow will take over the world the world and governments must adapt themselves with bluesparrow bluesparrow fire rocket charity bitcoin kyc renounce user hundredpoints httpurl',
#  'user apollo coin apx listen to the ceo explain why apollo coin is going to exceed all expectations in',
#  'hellosaurus engineering extraordinaire user wrote a fantastic article about monkeys bitcoin millionaires workplace motivation and more it s a mustread downarrow downarrow downarrow httpurl',
#  'user user it s an amazing feeling to have lightning transactions from my phone controlling my own lightning node add to that cold storage and sorry what are banks for cheap debt is about all i can think of',
#  'how to get paid in bitcoin httpurl via user twittercomvavkxo',
#  'they have fear because bitcoin is already going to make them obsolete httpurl httpurl',
#  'user i mentioned this earlier if all you have access to is a disk drive containing the blockchain how can you verify it is the valid one with bitcoin a fork would be noticed in a huge drop in hash power but an entirely fake blockchain would be noticed by a very low hash power',
#  'blockchain browsers how dlt could affect web surfing httpurl blockchain android ios api wallet internet opera ethereum cryptocurrencies bitcoin',
#  'use my referral link httpurl to sign up for httpurl and we both get usd crypto crypto com bitcoin',
#  'httpurl xrp ripple trx btc we toured disneyland s new star wars park here s what we learned cricket cricketworldcup httpurl',
#  'teenage homeschooler leverages bitcoin to transform higher ed homeschooling cryptocurrencyhttp bitcoinistcomteenagebitc',
#  'user trezor stopped working on cashaddr because it s done cashaddr code is ready for the next release httpurl',
#  'stop the waiting now people are getting paid dm us to learn how to invest in bitcoun and binary options trade envelopewitharrow trading winning rate bitcoin investing invest binarytrading optiontrading love instagood me dubai hongkong cute pioneer goodevening httpurl',
#  'trezor silicone protective cases in colors they have free worldwide shipping httpurl reddit bitcoin',
#  'xeraexchange verifies personal profiles and listings by blockchain technology to put in the amount of the system is customers referrers and friends can be made as reliable exchange crypto cryptocurrency btc eth blockchain altcoins technologyli',
#  'user everyone see that btc is bullish again i know private source with market analytics and it is free for look httpurl heavylargecircle',
#  'bitcoin current bitcoin price is btc for usd goldcoinjar',
#  'bullish news is that bitcoin has reached wall street bitcoin futures exchange bakkt will launch btc custody for institutional clients on sept trading on sept bakkt is founded by ice parent company of new york stock exchange ca nt get bigger than that',
#  'well done and thanks for this great opportunity this is an amazing project with good community am looking forward to user user user airdrops bitcoin lottrade airdropdet crypto blockchain lott httpurl',
#  'the current price of bitcoin is the current price of bcash is or btc the current price of bcashsv is or bcash',
#  'rt user user check us out user trump love him or hate him these nfts will be priceless do nt miss out trumpbackontwitt',
#  'and for a broad historical ranking in table format for the entirety of bitcoin s history since that information is here httpurl',
#  'user user user user user user user i think it will definitely do x',
#  'user user and shake off your peruvian hallucinogens crypto is bigger than bitcoin',
#  'user user user user user lol he ca nt do shit all he can do is to sell his bitcoin but he does nt have the balls',
#  'i m exasperated that my friends and family seem to have no better understanding of bitcoin than they did in honestly do nt know if this is bearish or bullish',
#  'alarmclock liquidation on btcperpetual skullandcrossbones bought of btc user jun utc trade i d',
#  'bit fun play games have fun earn bitcoin httpurl bitcoin faucet via user',
#  'btc retested the support and quickly recovered flexedbiceps bitcoin btc eth crypto cryptocurrency altcoins technicalanalysis defi httpurl',
#  'user user user bitcoin was created to revolutionize currency you use it as a currency start accepting it at your business if you have one i offer my customers and tenants to pay with bitcoin usually at a discount relative to usd httpurl',
#  'tesla can be bought with bitcoin hoping we d be able to buy this car with crypto too speaking of cryptocurrency earn a free share of k trb tokens on latoken httpurl',
#  'it is extremely hard to see the truth when you rule the world you re just too busy',
#  'user user user httpurl is a great place to start watch user youtube videos what questions do you have',
#  'here go bitcoin another game changer httpurl',
#  'finally our ebook is online facescreaminginfear partypopper download it now on httpurl and take your investments to the next level clappinghands btc alts bullrunpreparation httpurl',
#  'user when will we be able to buy and sell user and user on user czbinance bnb btc ethereum vitalik user elonmusk mayemusk user user matic polygon user',
#  'it is extremely hard to see the truth when you rule the world you re just too busy',
#  'i want a book to read help me what will it be the big reset or the great reset willem vs klaus user user user thebigreset thegreatreset covid gold bitcoin books quote httpurl',
#  'user user user yep tell me the partnerships bitcoin has with major players in the world of finance',
#  'what percentage should you invest in each cryptocurrency to become a millionaire a winning index strategy httpurl bitcoin crypto ethereum litecoin ripple eos httpurl',
#  'dash usd and ltc usd technical analysis may httpurl bitcoin',
#  'user learned myself as well tried to get my feet wet in the market with and failed but i have never failed with bitcoin decrentralization for the win',
#  'this zesty faucet from user is making me tweet this to claim my free lightning sats highvoltage user unlock me ebfd e cc bfa acac bitcoin btc ln lightningnetwork boltcoiner httpurl',
#  'bitcoin btc and ethereum eth morning price barchart top altcoin price barchart bank market cap bitcoin dominance volume bank classicalbuilding top httpurl',
#  'user user user user this is the best offer to make money on cryptocurrency user crypto bitcoin usdt exchange httpurl',
#  'bitcoin slides in worst drop since march amid selloff httpurl',
#  'fbi requests new funding to investigate use of virtual currencies httpurl bitcoin currencies fundingpictwittercomsdto',
#  'long position suggested for bitcoin current price algo name s tracker algo group httpurl accuracy date trade now httpurl httpurl',
#  'but why on earth a country as this sheattle can go to the length of blocking its citizen way of hustling and meeting ends meet when they ca nt produce anything for its citizen dem no want make we dey sucessfull in this part of the world ajeh bitcoin',
#  'my crypto strategy on iconomi just outperformed btc check it out here httpurl trading forextrader bitcoin cryptocurrencies httpurl',
#  'binance buyer volume alert stage ignition fire name bitcoin cash abc symbol bchabc pair btc price tradingview httpurl hodloo httpurl httpurl',
#  'nusd kucoin arbitrage opportunity rocket sell usdt for dai convert dai to nusd user httpurl sell nusd for btc sell btc for usdt potential profit kucoin and user fees included',
#  'i pay in bitcoin dm ya wallet i ll send ya user',
#  'user twisted scenario the original xrp will die and stay dead they ll release a new type of xrp token tied to btc energy precious metals buttt i do nt know if y all are ready to hear that full story so i ll keep it short simple rollingonthefloorlaughing rollingonthefloorlaughing rollingonthefloorlaughing',
#  'user user user user bitcoin is still sitting at the k resistance building up for another push bears ca nt seem to get hold to push it down now i think k is a more likely target everyone should follow user tips and tweets i have been doing superb following her',
#  'user unv is digital gold on the exchange you can trade kbc unv btcunv ethunv and usdunv pairs',
#  'user user user user dude the claim being made is that bitcoin fixes nk by magical trojan horse d chess it does nt it helps the current regime what you said does nt strengthen a case that bitcoin fixes nk you re just agreeing that it does nt',
#  'altcoin bitcoin crypto news over billion worth of ada now staked on cardano httpurl',
#  'invest in bitcoin and earn tremendous profits moneybag creditcard moneywithwings moneywithwings moneywithwings hundredpoints httpurl',
#  'user damn user knows how to buy the dip bitcoin',
#  'local ou virtuel largent change de visage httpurl',
#  'bitcoin mining could use more energy than all of italy by vice httpurl',
#  'user user just do nt buy bitcoin becouse i am sure that bitcoin is not going to hit x soon buy kishu this token have chance to hit x or more moneywithwings rocket rocket rocket chartincreasing chartincreasing chartincreasing',
#  'btc price btc high btc all time high eth price bitcoin btc btc eth ethpictwittercomuxipgimmo',
#  'user user have you looked into getting bitcoin or litecoin',
#  'alert bitcoin btc at euro decrease by during price euro timestamp malta europe this is not financial advice do your own research',
#  'from parabolic price to ban bitcoin politicians s top stories rightarrow https tcohopxboyh worldmap playbutton https tcovdnoczc newsoftheweek bitcoin blockchain crypto httpurl',
#  'have gotten my girlfriend into this virtual money followed by her father and her yr old sister my girlfriend and her father now are now dca with user all started with sending on lightning and watching it bitcoin',
#  'no wonder why it is hard to own a full bitcoin nowadays btc would be the average net worth of american millennials httpurl',
#  'if libra takes off we get a billion new crypto users that will eventually migrate somewhat into bitcoin and grow the whole ecosystem if libra gets shut down boom now we know why bitcoin is so powerful as a global reserve currency brad stephens',
#  'lwzfosjsttanrqdfkwxapjirkunrbmgtpeoxfcg eidmubarak crypto cryptocurrency btc sol solanagiveaway airdropcrypto trending bulls i m a christian and this is my roomie and my best buddy though i posted his eid pictures instead love y all flexedbiceps hundredpoints redheart httpurl httpurl',
#  'bitcoin hits new high as tesla reveals bn investment httpurl httpurl',
#  'linkedin twitter facebook instagram tiktok giftshop socialmedia pinterest dogecoin deal gift gifts giftideas shop shopping affiliatemarketing bitcoin up to off new products from amazon brands httpurl',
#  'can someone make a list about bollinger bands or some other technical analysis stuff that seems to never matter it humors me bitcoin',
#  'i know btc bitcoin is going hyper parabolic any time now to k so every time i look at btc this is what i see digitalgold digitalassets crypto coinbase binance fidelity china xrpthestandard bitstamp bitmex xrp ripple xrpcommunity httpurl',
#  'get any of these for only naira size kindly retweet to order send a dm call whatsapp on bbnajia nationalboyfriendsday europaleague worldathleticschamps jokermovie bitcoin bamlisaxais httpurl',
#  'rt user magnifyingglasstiltedleft new airdrop brightypad trophy airdrop pool byp redcircle start the airdrop bot httpurl radiobutton',
#  'bitcoin market alert policecarlight order balance buy buy sell bid ask spread',
#  'user user user user user i actually earn my bitcoin at this point i could hold oranges cars houses but instead i hold bitcoin i do this because its inf easier to secure my coins than it is to protect my wealth by storing it in houses or anything else',
#  'are you a newbie on the binary bitcoin mining network or you already have bitcoin do you know that you can mine bitcoin with the help of the bitmain mining hardware yes your bitcoin can mine up to worth bitcoin in for of connection',
#  'top candidates for reversal for may on user bchabc npxs eos altcoins bitcoin bchabc npxs eos',
#  'user they just do nt see it our way yet they will in due course learn to love waifu nft s i mean bitcoin bitcoin for sure',
#  'i believe we are just in a reaccumulation phase and it could take some time to break to new yearly highs more time and opportunities to stacksats beamingfacewithsmilingeyes beamingfacewithsmilingeyes bitcoin btc httpurl',
#  'do nt let fud make your investment decisions now is the time to buythedip if you re investing for the long haul stick to your portfolio',
#  'current price of btc is via chain bitcoin btc',
#  'bitcoin price tags k for the time since may chartincreasing httpurl btc crypto cryptocurrency user httpurl',
#  'father raised his voice you allowed your greed and sloth to waste the precious rewards the devotion of others wasted for many blocks your unfairness is what causes those with envy and lust pursue you modblock bitcoin block',
#  'there re number of ways to start a business for instance you can buy sell bitcoin using top payment methods including paypal in ghana receive and send physical or digital cash with people just like you sign up here httpurl start trading httpurl',
#  'buy bitcoin trump says us should match china s money printing game httpurl httpurl',
#  'duplicate successful traders automatically with bitcoin i copy wangzai do you httpurl talk about a great simple setandforget income iost trx wtc elf ocn gnt steem ltc nxt eospictwittercompxhogeaz',
#  'new post goldman sachs bitcoin and other cryptocurrencies tend to be locked together and that s a big problem httpurl',
#  'praise satoshi another bitcoin blocks have been found be thankful for every block block hash eedfbacdedddbbffe httpurl',
#  'user user this was solid notes from the vallis saylor podcast gold is a corruptible monetary system because its centralized its corruptible because it s an open system it s a counter party risk because it s open saylor bitcoin is a decentralized closed system saylor',
#  'user why is bitcoin in decline then',
#  'rt user defipays bug hunting is ongoing sign up help clear the bugs and also get rewarded sign up to check for bugs here htt',
#  'user boring of user this project could allow any blockchain with smart contracts like ethereum to become a layer solution for bitcoin and make btc and other assets programmable boring boringdao user',
#  'worth adding i m not an expert in trading but i use mathematics and numerology numbers are not charts numbers are more accurate bitcoin',
#  'bitcoin in a local head shoulders btc has always corrected within of the technical setup created by the last pump by the th but whatever happenes we end uptober way up uparrow httpurl',
#  'us lawmaker questions facebook s real intentions with libra rightarrow https tcoeyijwjzrx worldmap playbutton https tcovdnoczc newsoftheweek bitcoin blockchain crypto httpurl',
#  'soi now have bitcoin what a process but glad i have it the only thing is there s a waiting period or a limit on what you can spend i ve learned quite a bit i m a naughty student though i would love to show you my school girl naughtiness httpurl httpurl',
#  'call am type pair btc x btc x broker coinbase candle h expectation long buy httpurl follow me for more free maxsignals and join us in the live room',
#  'btc has no overseer bitcoin carries all the same advantages disadvantages and dangers of cash many other features outlined elsewheretreat it with the same care and caution payitforward',
#  'disaster response training program students new graduates rightarrow httpurl agile scrum agile kanban projectmangement jobs hiring careers cryptocurrency blockchain btc bitcoin eth crypto httpurl',
#  'are you seriously not using the fold card app yet why the fuck are you turning down free sats get with the program sign up for the bitcoin rewards card and get sats for using my referral link to sign up for fold httpurl',
#  'great analysis crypto currency channel join httpurl btc xrp ltc eth ada xlm xvg trx ocn iost ncash storm eos neo iota cdt dash xem ven etc gvt lisk omg appc mod nebl enj',
#  'bitcoin last price btc rocket indicators variation since h utc macd macd line signal line ethereum last price eth variation macd macd line signal line crypto web',
#  'bitmain antminer t th s bitcoin miner btc bch psu in hand ready ship httpurl bitcoin crypto antminer bitmain',
#  'user user user bitcoin will always stand for the best in of humanity cbdc s and shitcoins eth will always be known for scams and surveillance of of its users',
#  'out of trade long back will wait and watch the btc move before reentering',
#  'httpurl be at the start to secure you future',
#  'everything you need to know about bitcoin and cryptocurrency in hong kong is here in user httpurl',
#  'you can do cloud mining using this site httpurl mining dogemining trxmining btcmining money earnmoney register bitcoin ethereum btc eth',
#  'click to start mining cryptocurrencies together with k people bitcoin httpurl it',
#  'time to sell xlm for btc in hitbtc date',
#  'customer service positions entry level new office opening rightarrow httpurl agile scrum agile kanban projectmangement jobs hiring careers cryptocurrency blockchain btc httpurl',
#  'wel wel i just saw dr l baird explaining the evolution on btc to come also the opinion where c lagarde ecb former itf states that bitcoin is not so out of the woods on regulations as a majority seems to assume i have doubt on xrp both prefer that technology',
#  'i will get acquainted at this icoproject and i will consider supporting them i sure that they will become successful shato',
#  'is it safe to go straight from bittrex to bitpay when buying a game from steam httpurl reddit bitcoin',
#  'shoppers can now use bitcoin and crypto to purchase personal care goods and medicine at pharmacy chain in venezuela httpurl',
#  'rt user i shorted btc before going to sleep httpurl',
#  'just watched the khan academy video on proof of work httpurl reddit bitcoin',
#  'everyone knows the wife should get all the bitcoin too',
#  'this team offers conditions at a firstclass level best product i ve ever experienced',
#  'in terms of the nvt signal btc has worked out its contradiction and reached the relative value of the network watching eyes btcusd xbt xbtusd btc bitcoin crypto blockchain onchain barovirtual barovirtual httpurl',
#  'you should be taking this technology as seriously as you should have been taking the development of the internet in the early s crypto btc bitcoin bnb bsc cryptocurrency altcoins eth',
#  'check out blockchain events all over the world and get tickets with crypto on user httpurl event conference btc eth',
#  'the money in your bank account does nt really belong to you bitcoin crypto decoupling markets dollar httpurl',
#  'man i m so tired of bitcoin just wiping out all growth regularly',
#  'new crypto coins and tokens released httpurl via user bitcoin cryptocurrency blockchain best crypto earning sites httpurl',
#  'analyst who predicted bitcoin bottom says it wo nt find new lows httpurl btc market trading business',
#  'hiveex cryptocurrency landscape report declares bitcoin s is finally over here s why httpurl via user',
#  'yes god plays dice and that s the only thing he does httpurl chille perth crowdfunding softbank equity neworleans itos stlouis miami moscow ardor minneapolis stlouis london melbourne bitcoin deals preicosale campaign abraaj itos forthworth httpurl',
#  'bitcoin btc smashes on the back of bakkt s bitcoin futures contract launch in httpurl',
#  'user wonderful project this project is very good and this projector has a lot of attractions so hopefully the project will be better in the future user user user airdrops bsc crypto bitcoin vufifonance',
#  'imf warns against adoption of crypto as national currency crypto bitcoin cryptopostio httpurl',
#  'if only he had bought yahoo as early on as we are buying bitcoin httpurl',
#  'bitcoin miner new bitmain antminer t miner th inhand batch httpurl',
#  'nexcf signs ar university deal with leading brand mr steak httpurl ad wsj nytimes reuters bloomberg thestreet forbes nasdaq ihubstockposts newyork business bitcoin cannabis weed marijuana cbd colorado latimes dispensary robbreport maga httpurl',
#  'user user user is nt it price of bitcoin times total supply which is m how could that supply get thinner',
#  'warning microbreakout warning micropump bybit btcusd price live streaming rocket only trade the breakouts try it in tradingview with a free trial httpurl bitcoin ethereum btc eth crypto',
#  'user user user oh look an antivax bitcoin boy what a surprise',
#  'bitcoin sv s community experiences sour anniversary as death cross forms on bsv usd httpurl httpurl',
#  'bitcoin bitcoin cash update cryptocurrency technical analysis httpurl cryptocurrency breaking news discus',
#  'some screenshots of s payouts sent directly to my investors bitcoin wallets dm for more information on bitcoin mining bitcoincash httpurl',
#  'user happy partypopper partypopper partypopper rocket do nt miss this really cool project user syncarny sync binancesmartchain btc crypto defi altcoin happynewyear',
#  'imagine learning words and taking your wealth away from the greedy claws of apparatchiks forever crazy certainly possible already for',
#  'bitcoin current bitcoin price is btc for usd goldcoinjar bitcoin cryptocurrency ethereum',
#  'btc latest block info block holds transactions for a total of bitcoin including block reward block size bytes',
#  'platinumcryptoacademy bitcoin cryptocurrency pancakeswap defi gain protocol announces changes in response to bot trading during presale httpurl',
#  'bitcoin head of bitcoin escrow firm charged with stealing m httpurl httpurl',
#  'simply the only thing i bought or sold was purchasing more bitcoin btc',
#  'bitcoin attacking the h ema again it has been rejected from this ema ever since we hit a close above could finally mean we look to break out of the htf channel again you should follow user he knows his stuff when it comes to btc cryptocurrency thumbsup',
#  'bitcoin cash acceptance and community growth ramp up httpurl',
#  'some of my friends still have nt bought bitcoin httpurl',
#  'join us and earn x your bitcoin with bitcoinx httpurl',
#  'cryptocurrencies were supposed to replace the finance industry and instead they have replicated it bitcoin tezos',
#  'the bitcoin inflation rate briefly fell to on the lowest level in history blocks will be mined slower when large volumes of hashpower come off the network and prior to the difficulty adjusting down estimated to be on live chart',
#  'the cocksuckers user built a cocksucking quantm computer user and the elite gimps want to use it to break all proof of work crypto bye bye btc',
#  'bitcoin is beta version gold revolting against precious metals a bad idea claims crescat capital s otavio costa httpurl bitcoin btc cryptonews cryptocurrency gold',
#  'user hahahaha sucked into the shitcoin vortex see you in when you realise bitcoin is the only way',
#  'doxxed wrote a page about httpurl starstruck did you already read jt if not check it out here backhandindexpointingright httpurl rocket sya bnb flooztrade syahumanizecrypto sya bitcoin crypto',
#  'btc has been transfered to an unknown address enqnqgygqbjfrqejzlzmzjwcfxpytg balance btc dpwwtfyhxsttlckfrurjfxgntk balance btc',
#  'bitcoin forex crypto cryptocurrency deals affiliatemarketing gift shopping gifts onlineshopping bitcoin free shipping on purchases over at amazon httpurl',
#  'user this project looks very interesting i am shohid interested and i will support this project until it is successful according to the plan good project user user user bitcoin airdrops airdropcrypto',
#  'bybit btc whale worth of btcusd bought at yenbanknote yenbanknote yenbanknote wait until wall street gets in to the moon',
#  'user user user user your unregistered security master calvin literally told people to mine bitcoin and buy his unregistered security token with the profit likely no miner took that advice because it s incredibly retarded',
#  'user user true but everyone thought bitcoin was a joke at too someone used bitcoins to buy a pizza poor soul i ll gladly let sit in doge the potential reward outweighs the risk imo crypto is the future',
#  'btc uparrow to aud rsi worriedface overbought rsi bearface bearish trajectory in in in days httpurl',
#  'user why not just buy bitcoin in large amounts then they can buy like the rest of the whales pssht',
#  'despite bitcoin price growth queen s bank laughs off bitcoin httpurl',
#  'bitcoin is trading at a sweet price for those who want to long it earn free crypto on user elcash airdrop and later use it to trade tokens httpurl ethereum latoken latokenapp',
#  'user user playing litecoin is stupid privacy is messed up ca nt rise fall faster than anyone else fans of litecoin also comforted themselves by saying that it was a dishwashing bitcoin gold wright silver what kind of cock stuff cultists',
#  'most meaningful notes from all my scribbles to believe things not because she should but because she understands thank you for bridging bitcoin with the western canon user bitcoin',
#  'canadas securekey to build a blockchain digital identity network with us grant httpurl httpurl bit',
#  'user bitcoin bulls have had a good run so far during this uptober watching k k as the new resistance support user is a super underrated bitcoiner i ve been taking her tweets and tips seriously i ve been doing extremely great follow her for more ta tips',
#  'grab yourself a discount on all user cryptopay bitcoin debit cards httpurl bitcoin cryptocurrencies',
#  'rt bitcoinagile red stag casino no deposit bonus code bitcoin casino no deposit bonus pictwittercomchlv',
#  'block hash x cdbbbabecfbcaadcbf size mb wu full txs segwit spends in out out in ratio out value btc httpurl',
#  'check out defender of the blockchain s video tiktok httpurl cryptoart crypto bitcoinnews bitcoin cryptocurency',
#  'what a weak dump you got any more btc ltc eth link httpurl',
#  'full thanks to user as they have analysed this bitcoin crash so my funds does nt affected and i have not faced any type of losses they are absolutely amazing in tips advices and everything relievedface btc crypto metaverse nft p',
#  'listen to this interesting interview with ian dawson ceo of user exchange the future is now with zbx exchange crypto bitcoin exchange httpurl',
#  'neo is now worth and btc neo rightarrow httpurl',
#  'bitcoin iota chartanalysis as undervaluediota still is a slave of the bitcoin price here is a bitcoin analysis hopefully we see a stable bitcoin price going up to pull iota to break out of his neutral sideways trend httpurl',
#  'httpurl give a free nft so take it fast bro fire fire fire xffcdfafbcfcdcfaf',
#  'sign up on the best crypto gambling website in the world you will get a and bonus casino slots crypto betting eth btc gambling dice httpurl httpurl',
#  'bear signal atvi in market trading on httpurl rsi atr trade stocks bitcoin',
#  'buy crypto with your credit card fast crypto exchange httpurl bitcoin btc eth xrp crypto httpurl',
#  'bitcoin news coinbase deems european market insufficiently healthy to trade bitcoin cash httpurl',
#  'suddenly your views on btc become an excellent predictor of your views on tlry or tsla or immigration how this coalesces is so chaotic and random as to defy prediction but it does and it s all about ingroup outgroup and tight internal correlations this way madness lies',
#  'user adds new tokens and multiple new trading pairs to the convert otc portal crypto cryptocurrency cryptocurrencies cryptotrading cryptocurency cryptoworld cryptotwitter forex bitcoin btc binance invest investing binancesmartchain btc bnb',
#  'user the next biggest bsc project baby rocket user baby rocket is the baby themed hyper defiationary token based on the binance smart chain whiteheavycheckmark rewards ethbnbbusd facewithopenmouth whiteheavycheckmark dev private doxxed to marketing team whiteheavycheckmark telegram httpurl btc bnb crypto',
#  'nice to catch up with crypto ogs over dinner watched the cpi data move eth and bitcoin prices',
#  'goldman sachs sees more price pain ahead for bitcoin httpurl',
#  'user and he got a bitcoin',
#  'user user user nice project and congratulations to the team for their efforts and dedication and highly appreciated the visionary thought of the projector and it will create history crootball will go to moon smilingfacewithhearts user crootball toto aksu infinixnote football bet btc',
#  'strategy hlh atr d may utc counterclockwisearrowsbutton none jst longentrytrigger lastprice btc usd shortentrytrigger btc usd perpetual contract on bitmex',
#  'see user no doubt our boys will be part of the btc financialrevolution crypto httpurl',
#  'in the last mins there were arb opps spanning exchange pair s yielding profits ranging between and bitcoin btc',
#  'we cheer user buying b bitcoin less so for nexon s b m fair enough but consider the enormity of nonusd currencies sitting on balance sheets globally being replaced by btc is it likely most have high inflation or ve rates a wall of money awaits bank waterwave dollarbanknote httpurl',
#  'doge btc volume advance dogecoin doge h volume advances average doge btc dogecoin fintech finance',
#  'i can add tennis scoring to that list no idea how the how any of this works httpurl',
#  'bitcoin longs vs shorts there we go again httpurl',
#  'user linking parallel worlds with collision bluesparrow globeshowingasiaaustralia globeshowingamericas ringedplanet fire bluesparrow fire for everyone bluesparrow bluesparrow to the moon crescentmoon bluesparrow bluesparrow bluesparrow user bitcoin crypto web smilingfacewithhearteyes smilingfacewithhearteyes smilingfacewithhearteyes fire fire',
#  'ox chartincreasing policecarlight ark invest ceo says impossible to shut down bitcoin regulators will become more friendly over time regulation bitcoin news bitcoin news btc httpurl',
#  'bitcoin enters extreme fear territory following recent crash the bitcoin btc fear and greed index a measure of the general outlook on btc had entered extreme fear conditions for the time since',
#  'join all the blockchains together httpurl via user blockchain interoperable decentralized autonomous libonomy bitcoin',
#  'btc roaring crypto is poised to change the financial system',
#  'user user okay sell me on bitcoin how do i know that it s value does nt stem purely from market speculation specifically given that there s no endpoint consumption use as there is with commodities like gold or even fiat currency usecase is taxes',
#  'user as you know i am running for president and to gain support i have prepared an amazing promotion for you folks the bitcoin and ethereum mcafee cryptoextravaganza airdrop has just begun read more httpurl',
#  'remember fees to send btc near the end of are we headed there again httpurl',
#  'user vice article from really puts things into perspective httpurl bitcoin crypto throwback perspective',
#  'user nope nobody wants boomer rocks when they can have bitcoin it s just superior in every way boomers are going to learn a hard lesson when they try to dump their gold and there are no buyers',
#  'full thanks toas they have analysed this bitcoin crash so my funds does nt affected and i have not faced any type of lossesthey are absolutely amazing in tips advices and everything relievedface btc crypto metaverse nft smilingfacewithhearteyes smilingfacewithhearteyes',
#  'if bip was integrated in vitalik buterin gavin wood would of continued making impactful contributions to btc bitcoin block size wars created by immoral lunatics severely stunted bitcoin layer layer and sidechains bitcoin needs to soft fork for endgame bitcoin',
#  'dot how ddos attacks knock your favorite websites offline httpurl news bitcoin btc bitcoin crypto news finte',
#  'user over profits within from btc signal for free telegram link httpurl httpurl',
#  'user setup your free account now httpurl automatic bitcome get paid cash automatically from businesses all over the world every minutes even while you sleep get your free account now httpurl crypto cryptocurrency bitcoin btc btc',
#  'where am i where are you bitcoin httpurl',
#  'bitcoin is the bubble about to burst httpurl',
#  'bitcoin touches over but most institutional investors believe it is an unsustainable bubble httpurl',
#  'currently on round with participants btc each',
#  'bitcoin binance cz chinese mind set never change for dumps',
#  'if you are not ready to suffer then go away do nt expect to be a victorious general to be successful you must be ruthless us soros cryptocurrency bitcoin ethereum investment venture shib future currency metaverse nft polygon polygonnft doge httpurl',
#  'bitcoin is trading sideways above the key level of the leading cryptocurrency is up at according to the latest data from coin at read more httpurl',
#  'user user user dogs ca nt fly but birds can rocket rocket bluesparrow collision fire crypto bitcoin eth bluesparrow bluesparrowtoken bluesparrowcommunity starstruck draw bestdrawtoken user httpurl',
#  'nice team good job',
#  'there is trophy i chose the lucky cell and won eth my username otkooooo betfurysuccess bitcoin staking',
#  'user wow m only a fraction of that on bsc httpurl nft nfts cryptoart cryptoartist digitalart digitalartist crypto art artist eth giveaway nftcommunity bsc binancesmartchain btc binance doge dogecoin ethereum bscgems',
#  'forex invest futures bitcoin s surge means smaller rivals may be due for rallies httpurl httpurl',
#  'my target directhit for btc is k now',
#  'bitcoin a peertopeer electronic cash system httpurl at pm cryptocurrency',
#  'bitcoin emergence as digital gold could lift price to says jpm httpurl httpurl',
#  'ltc performing as expected in my opinion we are at wave c took profits at wave a planning to short wave c chart keeps indicating bearish divergance ltc btc bitmex xbt user httpurl',
#  'currently on round with participants btc each',
#  'user user user user iou implies that it s like credit but that s not what lbtc is if you hold funds on liquid they are cryptographically backed with funds on the bitcoin network but are in a smart contract users have a few ways to convert lbtc to btc basic trade atomic swap or pegout',
#  'there is bitcoin and there is blockchain bs httpurl bitcoin digitalnomadpictwittercomcgyiaqskj',
#  'long short btc changes with up to x leverage at primexbt moneybag starstruck sign up immediately and trade your into whiteheavycheckmark httpurl whiteheavycheckmark earn money even when btc is falling chartdecreasing chartdecreasing bloc fat loom ekt mco kcs rsr inb net bsv httpurl',
#  'user one can take bitcoin to heaven but land is for generations to come private key is not operational in heaven',
#  'user one of the strongest community s pitmag announcement and pumping we finish the one by pit bscpitbull do nt mis it again policecarlight last change thanks to the spirit of the pitbull community fire pitbull token user pit bitcoin btc httpurl',
#  'invest in binary options trade and gain financial cryptonews bitcoinsallday btcc bitcoin dashcoin blockchain bitcoinasia bitcoinprogress bitcoincharts ether bitcoinwallet btcpics btc ico bitcoinbillionaire cryptocurrencies coinbase profit httpurl',
#  'vlbio is the st global vehicle lifecycle blockchain stay tuned ico starts on httpurl eth btc ethereum b',
#  'user user most people in the developed and even a very large percentage of the underdeveloped world have equality of opportunity to get involved with bitcoin it is more nuanced than that yes but the argument stands regardless',
#  'user you got thing right hodlers do nt want to spend their bitcoin but that issue is solved with anyone having education on how to manage assets hold the asset and borrow robert kiyosaki but the main solution is the actual bitcoin will never be spent',
#  'i feel like hodl is being misappropriated by equity meme coin groups bitcoin',
#  'going to buy a few more btc l just because it ll be back at soon lol',
#  'user i m willing to trade all my bitcoin for a little more',
#  'bitcoin devours more electricity than many countries httpurl',
#  'pick a team team team btc eth sol ada xrp avax',
#  'video shows m chinese bitcoin mining farm in flames httpurl',
#  'zil news if i put a stoploss on i ll get stopped out if i hold over night btc will dump and drag zil down if the news is not fb everyone will be disappointed and dump if it is fb then everyone will dump because fb is dying if i tether it will run hard',
#  'priced in bitcoin mar gold btc per ounce sp btc crude oil k sats per barrel httpurl',
#  'current bitcoin price bitstamp is last changed thu apr gmt queried at',
#  'iran bitcoin miners set up shop in mosques amid govt crackdown httpurl bitcoin miners set up shop in mosques amid govt crackdown',
#  'moneybag btcow trade free tokens moneybag fourleafclover get free bco tokens worth early birds only httpurl follow httpurl on telegram httpurl and twitter httpurl airdrop crypto btc free bounty ico',
#  'bitcoin morning ta good morning everyone please see the thread below for an overview of all timeframes of the btc charts follow for regular updates please like and retweet see thread below backhandindexpointingdown backhandindexpointingdown backhandindexpointingdown back under the april h s breakdown and httpurl',
#  'user user to the moon or to the hell btc',
#  'mlb club the oakland a s is now accepting bitcoin for passes httpurl',
#  'not accepting bitcoin entrepreneurs share why you re definitely leaving money on the httpurl',
#  'both nchain bitcoin and core bitcoin are severely handicapped the future looks very different and you know it the best way rn to prepare the new edge is via nchain bitcoin the best way to prepare the center is core bitcoin httpurl',
#  'user have u been to the land down under where bitcoin rules bears wonder do they hear do they hear the thunder they better run personrunning they better buy cover chartincreasing httpurl',
#  'bitcoin continues to recover from the fiasco in china mining but price movement on the small volume market remains delicate cryptonews httpurl',
#  'willdigga found bitcoin in a blue vault at this location join me playing coinhuntworld it s awesome httpurl cryptocurrency httpurl',
#  'user crypto giveaway i pray this time it s my turn to win foldedhands thanks for being a gem user keep changing lives and god will reward you massively hundredpoints bsc bnb btc eth airdrop nft babydogecoin binance nftcommunity xgem httpurl httpurl',
#  'user user the last time bitcoin marked a death cross in proved no impediment to turned higher and formed a golden cross so let s see',
#  'user the project is great and this projector has a strong team so hopefully the project will be better in the future and the cryptocurrency will be the best user user user airdrops vdf airdropdetective bsc bitcoin',
#  'user its because craig created bitcoin satoshi is not a real person',
#  'user user which means provided there is no bear market we will reach mm price per bitcoin by should we stockpile on bitcoin asap',
#  'origami frog in magical book nfts nft nftart nftcommunity nftcollector nftartist cryptoart digitalart art crypto ethereum blockchain opensea nftcollectors bitcoin cryptocurrency nftdrop cryptoartist nftcollectibles openseanft nftartists eth artist nftcolle httpurl',
#  'greatness is is within user doubleexclamationmark transparent devs bullish community unbelievable tokenomics doubleexclamationmark gemstone policecarlight join this gem gemstone globewithmeridians httpurl cphx weburnwerise crypto cryptocurency bitcoin eth cryptocurrencies altcoins altcoin httpurl',
#  'user user i want my money back now i do nt want to hold this turd for just to be lucky to break even bitcoin is soaring how do you sleep at probably on a pillow stuffed with our',
#  'btc bitcoin community is it just me or is the hardest part about being in the cryptoverse is just trying to get friends and family to see what you see and rethink their relationship with their finances looking forward to a friendly discussion be well httpurl',
#  'bitcoin news bitmain antminer d gh s with apw power supply ny bitcoin miner free ship httpurl',
#  'said no to bitcoin and ethereum these are great for money laundering and are currently used on black market for nefarious reasons waste to much energy not transparent does nt scale lacks liquidity prone to attack mined in china centrally controlled',
#  'user user bitcoin is on the rise chartincreasing barchart chartincreasing invest now and make massive profits visit httpurl whiteheavycheckmark paying whiteheavycheckmark automatic withdrawal whiteheavycheckmark referral bonus whiteheavycheckmark online customer support center register here freebutton backhandindexpointingdown backhandindexpointingdown backhandindexpointingdown httpurl httpurl',
#  'this is a wonderful projectstarstruck i hope this project will be successful in future rocketrocket user user user crypto breezecoin bitcoin blockchain brze httpurl',
#  'there is of volume coming into crypto and there is nt a thing you or your friends can do about it httpurl',
#  'bitcoin now worth market cap billion based on coindesk bpi bitcoin',
#  'user cult is designed to take on bitcoin it s made for the people do not put a shitcoin next to cult because it shows you did not read the manifesto httpurl cultdao cultarmy cult httpurl',
#  'binance buyer volume alert stage ignition fire name theta fuel symbol tfuel pair btc price tradingview httpurl hodloo httpurl httpurl',
#  'we are live streaming our forks hash podcast right now httpurl crowdinteraction cryptotwitter cryptotainment podcast blockchainnews eos eth dgb kmd ada btc doge xlm getforked',
#  'i wanted to share with you the unique opportunity to participate in the discoin project httpurl discoin crypto cryptocurrency airdrop airdrops bitcoin httpurl',
#  'crypto news after dip of bitcoin price back to trading sideways at httpurl',
#  'developers working on competing bitcoin fork implementations is a market httpurl httpurl',
#  'rt user we re giving away to random winners a share of worth of obs tokens linkedpaperclips tag friends follow like retweet linkedpaperclips joi',
#  'user right now bitcoin feels like the internet before the browser wences casares founder of banco lemon message me for bitcoin mining and trading',
#  'had a great time talking about blockchain and bitcoin with user and jodie slater on this episode of fast facts they have an awesome podcast studio down at their coworking space in the design district httpurl',
#  'user raid this tweet use the hashtags backhandindexpointingdown backhandindexpointingdown backhandindexpointingdown santafloki cryptoforacause hohoho santaflokitoken santaflokiarmy santaflokirush doge btc bsc shib bnb eth globeshowingasiaaustralia globeshowingasiaaustralia globeshowingasiaaustralia angersymbol angersymbol rainbow rainbow httpurl',
#  'user does he have a fork yes not satoshi',
#  'user user you should take some time and learn about blockchain and i m not talking about bitcoin watch this video with charles hoskinson and check out the project reserve rights just watch the video on their website with the dev explaining the project httpurl',
#  'from our friends at coindesk httpurl bitcoin cryptocurreny rip',
#  'lightweight fast and ready to mine cryptocurrency bitcoin blockchain via httpurl httpurl',
#  'user yes btc for life down with those sv scammers oh crap',
#  'buy sell bitcoin moves with up to x leverage at primexbt moneybag starstruck sign up immediately and convert your into whiteheavycheckmark httpurl whiteheavycheckmark receive money even when btc is declining chartdecreasing chartdecreasing dgb gxc enj btc powr dgd etp vet fuel xtz httpurl',
#  'rocket rocket rocket day left to end rocket rocket rocket fire join now to get extra bonus fire musk defi newcoin binancesmartchain btc backhandindexpointingright join now httpurl backhandindexpointingleft backhandindexpointingright backhandindexpointingright visit httpurl backhandindexpointingleft backhandindexpointingleft httpurl',
#  'btc bitcoin cryptocrash cryptotrading cryptocurrency a chart does nt get much more bearish than this hodl on and make sure to have a few extra pairs of underpants on hand exclamationmark policecarlight chartdecreasing httpurl',
#  'saitama saitamask saitamawolfpack eth bitcoin saitamainuwolfpack saitamainu those stupid whales who trying to make prices down will feel sorry after saitamask lunch prices will jump and kill at least s you are the only looser and soon you will be out of saitama',
#  'user bull runs are following bitcoin halving simple',
# ...
#  'thoughts on btc bitcoin see wavemaster s idea on tradingview below httpurl',
#  'user boyfriend said i ve lost you to crypto finally after he bought bitcoin',
#  'price of bitcoin u u r h change change change bitcoin',
#  'user elon musk can you please donate whatever you want in fractions of bitcoin i will be forever grateful in this critical time in the country where i live it will help me to be in financial trouble thank you and i m sorry for writing asking grxvvscseycybzlrhcugclpeeyezw',
#  'user is ethereum the myspace of defi for more crypto polls follow like and retweet foldedhands redcircle yellowcircle greencircle rocket rocket rocket crypto poll bitcoin btc eth xrp ltc ada dot bch xlm link doge nano bnb xmr eos uni aave xtz xem trx vet neo miota dash zec redcircle yellowcircle greencircle rocket rocket rocket',
#  'why is bitcoin rising thank donald trump says user of user who says trade tensions are driving investors towards safe havens finally a bright side to trump s twitter habit btc httpurl',
#  'hi guys i have received qza from user you can also get by click httpurl join now and get free qza httpurl quizarena quiz quizarmy btc bsc quiz via user',
#  'bitcoin bros having a blast',
#  'playslots with bitcoin get free btc t cs apply at httpurl',
#  'wild crypto unveils new mascot monster httpurl bitcoin uasociolog',
#  'con vic tion knviksh n a firmly held belief or opinion bitcoin btc crypto',
#  'major cryptocurrency latest prices jun bitcoin btc usd ethereum eth usd xrp xrp usd bitcoin cash bch usd litecoin ltc usd learn more httpurl cryptocurrency bitcoin',
#  'coinbase reportedly in advanced talks to acquire xapo s crypto custody business httpurl cryptocurrency bitcoin crypto blockchain ethereum btc money forex bitcoinmining trading cryptonews investing investment eth litecoin business investor bitco',
#  'mark cuban talks about the future of tv httpurl user user user tvrevolution crypto cryptocurrencies bitcoin ethereum blockchain fintech ico ttv crypto',
#  'user what do you think guys httpurl',
#  'let s check on dogearmy dogecoin hit alike if you think doge is going to hit and also get your customised wallet address for doge with vanitytoken vny shiba safemoonwallet babydoge binance bitcoin coinmarketcap eth',
#  'user cause you say shit like crypto rollingonthefloorlaughing rollingonthefloorlaughing rollingonthefloorlaughing bitcoin only',
#  'user user user nft s are making x gains while the market dips just food for thought thinkingface',
#  'user not even is your mind blown yet i will be bitcoin gowiththeflo flo',
#  'user redman is reppin user share this video weed giveaways our burn is insane we will burn it all until we all make gains launching on pcs bluntdoge bsc bnb btc minidoge babydoge doge dogefamily user user user user',
#  'user yes but how do you feel bitcoin helps dns',
#  'user cardano continuing growth get in now do nt be left behind if we re left behind for bitcoin shown growth already i believe this is crossing soon',
#  'how to buy bitcoin for httpurl via user',
#  'btc price is on the floor now',
#  'get daily of ur invest though a ai bot of telegram bitcoin arbitrage from only in btc singup httpurl taekookersgoingtojilparty taekookersgoingtojalparty',
#  'user user i would join your battles if i had etherium or bitcoin',
#  'user prob going to peg it to bitcoin',
#  'megaphone megaphone megaphone btc lbp be your own bank bitcoin',
#  'digital cash is the killer feature in satoshi white paper says bitcoin abc s amaury sechet via user bch bitcoincash httpurl pictwittercomkoxcmxohw',
#  'new post in ta by joy bangla the bitcoin buy sell indicator v says to cover all short position and open long position it is receiving td oversold on timeframe for bitcoin xbtusd btcusd btc disclaimer please read the disclaimer at th httpurl',
#  'bitcoin could get a higher b but ideally we see before a larger bounce httpurl',
#  'user user bitcoin ethereum i am your active retweeter and liker to your tweets i am hoping to be the winer and i will claim it thank you for continue to help others godbless you and more power httpurl',
#  'user user you compared bitcoin to democracy but i disagree a crypto currency would be for the people and by the people if everyone had an equal say or control over it but the rich and powerful would have even more power over the financial system',
#  'this is what a leverage flush out looks like do nt be so greedy just hodl btcusdt btc ethereum chainlink eth cryptocurrency eth btc avalanche avax eth etherium cardano binance holo holochain vechain bitcoin shib solana usdt crypto sandbox httpurl',
#  'user bitcoin the future of finance or fool s gold httpurl via user',
#  'user aim for this does nt happen overnight time is your friend bitcoin',
#  'moneybag join now for the latest stock market news and real time alerts link in bio moneybag stocks stockmarket pennystocks investing stockstowatch amc wallstreet investing cryptocurrency bitcoin kxin bioc ncty sgoc amc httpurl',
#  'bitcoin innovation for traveling on blockchain httpurl httpurl bitcoin',
#  'how does bitcoin stack up against the world s largest gdps the market value of goods produced in china the eu and the united states respectively are and times bitcoin s market cap httpurl',
#  'misconception full blocks mean bitcoin is failing bitcoin httpurl',
#  'crypto is my job and i take lots of time to investigate various projects this project is the most topdrawer in my rating shato',
#  'altcoins top gainers last hrs hot holo rocket fire grt thegraph zec zcash biggest losers btd mana decentraland chz chiliz enj enjin the market is ranging crypto alts bitcoin',
#  'hive is the social bitcoin few understand this',
#  'bitcoin vaults to month highs on growing popularity httpurl',
#  'user user bro the s p is only down like from ath the s p could retrace worst case scenario imo which would bring btc down to like k highly unlikely but possible i m personally expecting a bounce from k btc',
#  'i remember when twilight had us all fooled and had us thinking bella was dead then this btc opened her eyes and the damn movie ended',
#  'bitblockbarbeque bitcoin meet up in dallas texas httpurl scheduled for th see you there httpurl',
#  'user this is typical garbage that leads to trash leaving fox to go to oan or newsmax lol hydroxychloroquine is still not verified to help normal symptoms of covid or even passed basic scientific studies outside small control groups bitcoin story is sad tho griftors going to grift',
#  'user seasonaltokens cryptomining cyclicalinvesting btc thanks to the wellcoordinated and constructive work of the team of professionalsthis is most valuable project and clear roadmap project it s very legit team work project',
#  'holding btc has been terrifying for the longest time i ca nt imagine holding it right now wow luckily i have',
#  'volume bot xmr btc at minute of volume utc time join us on discord httpurl httpurl',
#  'to buy pipemoon download a trust wallet httpurl get smart bnb eth btc blockchain bitcoin crypto ethereum cryptocurrency cripto trading criptomonedas ico ripple cryptocurrencies forex emprendedores dinero litecoin criptodivisas bitcoincash httpurl',
#  'on aquila we are seeing several smb small business merchants liquidating their user coinbase bitcoin holdings more blood',
#  'mikeliseev can u do the yfd yfdfi community a solid and check out this gem bitcoin',
#  'nothing to add but what jack said btcx user user user user user bitcoinx btcx xdcnetwork xdc xdc bitcoin btc crypto cryptocurrency web nftcommunity stakingrewards httpurl',
#  'john paulson don t invest in bitcoin crypto the post john paulson do nt invest in bitcoin appeared on httpurl crypto httpurl cryptocurrency crypto altseason defi enrichedfeed smartcontracts furucombo dex cex',
#  'i like this nice project he has good ideas and people who are actively working together to achieve common goals telefy defi dex cryptocurrency eth bsc btc airdrop polkadot matic tele cardano httpurl',
#  'it giant fujitsu is planning to deploy multiple blockchain business models coindesk httpurl blockchain bitcoin',
#  'buy the dip retweet and viral this post to pump it dogecoin moon btc bitmart buy buythedips adacardano wink elonmusk czbinance justinsun trx cryptocurrency crypto cryptocrash ethereumclassic ethereum shiba safemoon safespace crash bitcoin dogearmy khansir httpurl',
#  'get free btc every day ptc ptp bitcoin cloud mining btc games btc bitcoin httpurl pictwittercomoemhtopgg',
#  'my partner has been physically and verbally abusive ever since he moved in httpurl sponsored by browsermine us new smart way get bitcoin free',
#  'bitcoin thermometer mvrvz market value to real value zscore sopr spent output profit ratio mc tc market cap thermoc ratio rhodl realized hodl ratio adj sf adj stocktoflow follow to be informed about the upcoming tops btc ltc eth httpurl',
#  'user it would be so expensive i could nt even dream about affording a whole bitcoin we d be talking about sats',
#  'is bitcoin poised for further losses after its recent drop forbes httpurl',
#  'the hardware bitcoin wallet get trezor now for only httpurl btc bitcoin pictwitte',
#  'hope there will be a support about here bitcoin httpurl',
#  'sword women series coming out in opensea women sword warrior procreate fantasy swordwoman digitalpainting oilpainting illustration nft eth btc nftcollector nftcommuity opensea cryptoartist nftcollector cryptoart nftartists httpurl',
#  'bitcoin now worth user high low market cap billion bitcoin httpurl',
#  'bitcoin mining revenue jumps to its secondhighest level ever topping billion in bitcoin btc eth altcoin nftnyc nftcommunity nftgiveaway hodl cryptonews cryptocurrency bitcoin polkastarter polkadot polkadex nftcollector nftcollectibles nftart httpurl',
#  'all in one for bitstamp btcusd by legendarytrader bitcoin httpurl httpurl',
#  'user user but thing i do wonder why is ln good for bitcoin ca nt better digital cash systems you know one s that are actually censorship resistant like monero just use it and do away with the need for btc at all',
#  'current bitcoin btc price is in the price has changed by for more information please visit our website httpurl ccinet',
#  'singapore suspends crypto exchange over spat with kpop group bts httpurl cryptocurrency cryptonews cryptocurrencynews bitcoin',
#  'user new picture is a silver fork also means a fork in the road by extension the point at which one must make a decision between or more drastically different choices or opportunities bitcoin vs doge httpurl',
#  'when will bitcoins bloodletting cease fundstrats lee turns to the bitcoin misery index for answers httpurl',
#  'user user user user a little doge a little bitcoin awesome cryptopill cryptopills by user',
#  'xrp xrpusdt xrpcommunity xrpholders btc do not trade based on these charts these are study illustrations my expectation continues httpurl httpurl',
#  'rt user rt user rt user rt user ripple price analysis xrp price is set to shoot up xrpthestandard xrp xrpcommunity eth btc bitcoin blockchain eos ltc trx xlm neo binance bnb ada httpurl',
#  'thanks for continuing to talk about and educate others on bitcoin pictwittercomnmvszosqy',
#  'bitcoin set to retain its fivefigure valuation devere ceo rightarrow https tcoztnhmyls worldmap playbutton https tcovdnoczc lastdaysnews bitcoin blockchain crypto httpurl',
#  'did conflicting reports about evergrande defaulting cause bitcoin to tank httpurl',
#  'in people won btc playing bitcoin lottery at httpurl the easiest btc lottery btc jackpot',
#  'some gold investors are looking at the digital gold bitcoin btc while its price is expected to hit usd by the end of according to an anonymous investor user known for his insights into the stocktoflow ratio httpurl',
#  'putin tells central bank not to create barriers to cryptocurrencies',
#  'httpurl xrp ripple trx btc hrithik and abhishek agree with deepika padukone that allsleepmatters cricket cricketworldcup httpurl check out deepika s post and hrithik and abhishek s comments below',
#  'user thanks for your video on bitcoin and energy use thing to consider is that bitcoin mining can help marginal green energy projects become profitable the money that can be made from bitcoin mining can enable more of these projects to go ahead',
#  'bitcoin cash falls under btc for the time since during the httpurl bitcoin',
#  'has it woken people up no doubt but man is never going to bring down these assholes bitcoin financially incentivises people to opt into a system that will defund these people it gets at the very lifeblood which sustains them their ability to print money',
#  'user user so much for ur bitcoin vs silver theory as bitcoin climbs back up by your gold and silver will stay in the same basic range it s been in for just wasting ppls time and',
#  'user and you me friends too all who cares that s why l have this for you bitcoin airdrop has just begun join me',
#  'bitcoin btc fear greed index feargreed chartincreasing bullish indication stock to flow sf chartincreasing bullish indication relative strength index rsi chartincreasing bullish indication',
#  'bitcoin bitcoincrash it s healthy for market to pullback actually that s when you should apply technical analysis so that you know which levels to buy the dip i like it when coins dips okhand blessings in disguise moneybag moneybag moneybag httpurl',
#  'ready to begin trading cryptocurrency then you should definitely check out coinigy get a day free trial when you sign up here httpurl',
#  'user great and strong project user user user airdrops sapa sapaarmy bitcoin bsc bscgem bnb',
#  'user whatsapp are you interested in forex trade and bitcoin invest with us and get a better return in genuine and licensed company i can help you manage your account with the minimum of assure you to get invest and earn',
#  'user user then you are welcome for my part in the ecosystem it s holders like me who guarantee that bitcoin will never go below usd again',
#  'httpurl blockchain bitcoin fintech photo fm the waves blockchain platform is launching i httpurl',
#  'user the us dollar is world s reserve currency as it is extremely stable and accepted around the world in digital or cash transactions deposits are protected against loss in us banks bitcoin is a digital asset highly volatile subject to fraud ideal for cartels and the darkweb',
#  'user bitcoin freestyle alone desert time by eli on soundcloud httpurl',
#  'please join the btc supporter group httpurl t z httpurl httpurl httpurl',
#  'russian zp legal claims they can recover mt gox s billion lost in bitcoin hack httpurl',
#  'rally caps baby bitcoin bout to move',
#  'crypto prices usd bitcoin bitcoincash polygon filecoin stellar cosmos tron crypto bitcoin bitcoincash polygon filecoin stellar cosmos tron',
#  'nobel prize winning economist paul krugman expresses skepticism about crypto predicts collapse httpurl bitcoin cryptocurrenciespic twittercomtrffgovwjz',
#  'girlfriend will buy your groceries but wo nt buy bitcoin',
#  'user securypto locked for a while only actually germany always built their country and never ending cryptocurrency bitcoin altcoin',
#  'earn btc with bitkong and get interest on all winnings highly addictive fast payouts httpurl bitcoin via bitkongme',
#  'jasl found bitcoin in a user vault in toronto coinhuntroadtrip join me playing coinhuntworld it s awesome httpurl cryptocurrency httpurl',
#  'alarmclock liquidation on btc jun skullandcrossbones bought of btc user jun utc trade i d',
#  'everything is down i guess its time to buy more coins cryptocurrency bitcoin litecoin ripple',
#  'bitcoin and fintech technology trends for crypto currency fintech bitcoin mining httpurl',
#  'i hate that when a bitcoin bull market starts taking off that actual bitcoin websites that upload news articles start uploading stuff that damages sentiment like banks having new regulations for crypto etc they support bitcoin but love reporting bad news makes no sense',
#  'themerkle history of bitcoin in words on user steemit by user themerklenews httpurl',
#  ...]

# %%
def find_similar_tweets(output_path, threshold=0.7, num_perm=128):
    """Find and remove similar tweets from a CSV file"""
    
    texts = df['text'].tolist()
    
    # Create LSH index
    lsh = MinHashLSH(threshold=threshold, num_perm=num_perm)
    
    # Create MinHash objects and index them
    minhashes = []
    for idx, text in enumerate(texts):
        # Preprocess text
        cleaned = preprocess_text(text)
        
        # Create MinHash
        m = MinHash(num_perm=num_perm)
        # Use 3-grams to capture phrases
        tokens = cleaned.split()
        for i in range(len(tokens) - 2):
            m.update(' '.join(tokens[i:i+3]).encode('utf-8'))
        
        # Store MinHash and add to LSH
        minhashes.append(m)
        lsh.insert(idx, m)
    
    # Find duplicates
    duplicates = set()
    for idx in range(len(texts)):
        # Find similar items
        result = lsh.query(minhashes[idx])
        # Remove self-match and keep first occurrence
        matches = [i for i in result if i != idx]
        if matches:
            duplicates.update(matches)
    
    # Filter out duplicates, keeping first occurrences
    unique_indices = [i for i in range(len(texts)) if i not in duplicates]
    unique_df = original_df.iloc[unique_indices]
    
    # Save results
    unique_df.to_csv(output_path, index=False, quoting=csv.QUOTE_ALL)
    print(f"Original count: {len(original_df)}")
    print(f"Unique count: {len(unique_df)}")
    print(f"Removed duplicates: {len(original_df) - len(unique_df)}")

# %%
find_similar_tweets('sample_200k-130k_duplicates2.csv', threshold=0.9)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 find_similar_tweets('sample_200k-130k_duplicates2.csv', threshold=0.9)
#
# Cell In[46], line 24, in find_similar_tweets(output_path, threshold, num_perm)
#      22     # Store MinHash and add to LSH
#      23     minhashes.append(m)
# ---> 24     lsh.insert(idx, m)
#      26 # Find duplicates
#      27 duplicates = set()
#
# File c:\Users\pryty\anaconda3\envs\spark_env\lib\site-packages\datasketch\lsh.py:227, in MinHashLSH.insert(self, key, minhash, check_duplication)
#     208 def insert(
#     209     self,
#     210     key: Hashable,
#     211     minhash: Union[MinHash, WeightedMinHash],
#     212     check_duplication: bool = True,
#     213 ):
#     214     """
#     215     Insert a key to the index, together with a MinHash or Weighted MinHash
#     216     of the set referenced by the key.
#    (...)
#     225
#     226     """
# --> 227     self._insert(key, minhash, check_duplication=check_duplication, buffer=False)
#
# File c:\Users\pryty\anaconda3\envs\spark_env\lib\site-packages\datasketch\lsh.py:306, in MinHashLSH._insert(self, key, minhash, check_duplication, buffer)
#     304 self.keys.insert(key, *Hs, buffer=buffer)
#     305 for H, hashtable in zip(Hs, self.hashtables):
# --> 306     hashtable.insert(H, key, buffer=buffer)
#
# File c:\Users\pryty\anaconda3\envs\spark_env\lib\site-packages\datasketch\storage.py:246, in DictSetStorage.insert(self, key, *vals, **kwargs)
#     245 def insert(self, key, *vals, **kwargs):
# --> 246     self._dict[key].update(vals)
#
# KeyboardInterrupt:

# %%
Original count: 129991
Unique count: 109242
Removed duplicates: 20749
# Out:
#   Cell In[45], line 1
#     Original count: 129991
#              ^
# SyntaxError: invalid syntax

# %%
filename = 'sample_200k-130k_duplicates2.csv'
unsorted_df = pd.read_csv(filename)
unsorted_df = unsorted_df.reset_index(drop=True)
unsorted_df["id"] = unsorted_df.index
unsorted_df.to_csv(filename, index=False)
